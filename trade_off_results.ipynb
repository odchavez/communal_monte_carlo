# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
names_part_num_20 = [
    '20_S=3',
    '20_S=6',
    '20_S=10',
    '20_S=15',
    '20_S=30',
    '20_S=60',
]
names_part_num_100 = [
    '100_S=3',
    '100_S=6',
    '100_S=10',
    '100_S=15',
    '100_S=30',
    '100_S=60',
]
names_part_num_1000 = [
    '1000_S=3',
    '1000_S=6',
    '1000_S=10',
    '1000_S=15',
    '1000_S=30',
    '1000_S=60',
]

# %%
diffs_32 = pd.read_csv('experiment_results/heat_map_data/full_heat_map_mean_like_diff_p=32.csv').set_index('index')
rt_32    = pd.read_csv('experiment_results/heat_map_data/full_heat_map_mean_run_time_p=32.csv').set_index('index')
diffs_16 = pd.read_csv('experiment_results/heat_map_data/full_heat_map_mean_like_diff_p=16.csv').set_index('index')
rt_16 = pd.read_csv('experiment_results/heat_map_data/full_heat_map_mean_run_time_p=16.csv').set_index('index')
diffs_8 = pd.read_csv('experiment_results/heat_map_data/full_heat_map_mean_like_diff_p=8.csv').set_index('index')
rt_8 = pd.read_csv('experiment_results/heat_map_data/full_heat_map_mean_run_time_p=8.csv').set_index('index')
diffs_2 = pd.read_csv('experiment_results/heat_map_data/full_heat_map_mean_like_diff_p=2.csv').set_index('index')
rt_2 = pd.read_csv('experiment_results/heat_map_data/full_heat_map_mean_run_time_p=2.csv').set_index('index')

# %%
diffs_2
# Out:
#          20_S=3   100_S=3  1000_S=3    20_S=6   100_S=6  1000_S=6   20_S=10  \
# index
# 30     0.006717  0.010397  0.007507  0.026215  0.030063  0.026527  0.047886
# 150   -0.002406  0.000577  0.001092  0.006021  0.002108 -0.003372  0.007113
# 300    0.002367  0.002092  0.001031  0.003346  0.001339  0.000669  0.006835
# 600   -0.002911  0.001017  0.000302  0.001825  0.002277  0.000585  0.001853
# 1200  -0.002118  0.001150  0.000152 -0.001619 -0.003257 -0.000164 -0.001529
#
#        100_S=10  1000_S=10   20_S=15  100_S=15  1000_S=15   20_S=30  100_S=30  \
# index
# 30     0.054168   0.060281  0.042854  0.052285   0.059405  0.029565  0.032599
# 150    0.008837   0.009191  0.016031  0.018554   0.018126  0.018472  0.014200
# 300    0.005525   0.005048  0.008181  0.009827   0.009703  0.020342  0.026430
# 600   -0.000033  -0.000635  0.003124  0.001396   0.000906  0.005378  0.010825
# 1200   0.001481   0.000647  0.000416  0.001292   0.000101  0.002698  0.002692
#
# ...

# %%
rt_2
# Out:
#           20_S=3     100_S=3     1000_S=3     20_S=6     100_S=6     1000_S=6  \
# index
# 30     68.315241  194.270942  1779.902960  76.320875  234.729084  2202.638790
# 150    36.551969  121.896313  1181.958754  38.100613  128.215810  1292.661273
# 300    32.751440  111.496158  1115.082502  33.668942  114.623254  1167.447727
# 600    30.708850  106.890632  1069.952596  30.889636  107.457970  1106.182171
# 1200   30.195991  106.061274  1069.154895  30.053404  108.143670  1086.971082
#
#          20_S=10    100_S=10    1000_S=10     20_S=15    100_S=15  \
# index
# 30     89.208766  292.008877  2764.595810  105.809995  358.631743
# 150    40.789532  138.206477  1412.158872   43.998239  153.385989
# 300    35.103343  120.099102  1237.654357   36.358680  127.482433
# 600    31.868663  111.303251  1166.447282   32.687935  115.115356
# 1200   30.254186  106.123956  1106.519055   30.495210  107.837701
#
#          1000_S=15     20_S=30    100_S=30    1000_S=30     20_S=60  \
# index
# ...

# %%
symbols_6 = [':o',':<', ':>', ':v', ':x', ':+']

index = rt_2.index.values

fig = plt.figure(figsize=(20,10))
ax1 = fig.add_subplot(3, 2, 1)
for i in range(len(index)):
    plt.plot(
        np.log(rt_2.loc[index[i], names_part_num_20]/3600), 
        diffs_2.loc[index[i], names_part_num_20],
        symbols_6[i],
        label=str(index[i]),
        
    )
plt.axhline(y=0, color='black', linestyle='-')
_=plt.legend(loc='lower right')
_=plt.title("lik vs. log(run time), p=2, pn=20")

ax1 = fig.add_subplot(3, 2, 2)
for i in range(len(names_part_num_20)):
    plt.plot(
        np.log(rt_2.loc[:, names_part_num_20[i]]/3600), 
        diffs_2.loc[:, names_part_num_20[i]],
        symbols_6[i],
        label=str(names_part_num_20[i])
    )
plt.axhline(y=0, color='black', linestyle='-')
_=plt.legend(loc='lower right')
_=plt.title("lik vs. log(run time), p=2, pn=20")

ax1 = fig.add_subplot(3, 2, 3)
for i in range(len(index)):
    plt.plot(
        np.log(rt_2.loc[index[i], names_part_num_100]/3600), 
        diffs_2.loc[index[i], names_part_num_100],
        symbols_6[i],
        label=str(index[i])
    )
plt.axhline(y=0, color='black', linestyle='-')
_=plt.legend(loc='lower right')
_=plt.title("lik vs. log(run time), p=2, pn=100")

ax1 = fig.add_subplot(3, 2, 4)
for i in range(len(names_part_num_100)):
    plt.plot(
        np.log(rt_2.loc[:, names_part_num_100[i]]/3600), 
        diffs_2.loc[:, names_part_num_100[i]],
        symbols_6[i],
        label=str(names_part_num_100[i])
    )
plt.axhline(y=0, color='black', linestyle='-')
_=plt.legend(loc='lower right')
_=plt.title("lik vs. log(run time), p=2, pn=100")

ax1 = fig.add_subplot(3, 2, 5)
for i in range(len(index)):
    plt.plot(
        np.log(rt_2.loc[index[i], names_part_num_1000]/3600), 
        diffs_2.loc[index[i], names_part_num_1000],
        symbols_6[i],
        label=str(index[i])
    )
plt.axhline(y=0, color='black', linestyle='-')
_=plt.legend(loc='lower right')
_=plt.title("lik vs. log(run time), p=2, pn=1000")

ax1 = fig.add_subplot(3, 2, 6)
for i in range(len(names_part_num_1000)):
    plt.plot(
        np.log(rt_2.loc[:, names_part_num_1000[i]]/3600), 
        diffs_2.loc[:, names_part_num_1000[i]],
        symbols_6[i],
        label=str(names_part_num_1000[i])
    )
plt.axhline(y=0, color='black', linestyle='-')
_=plt.legend(loc='lower right')
_=plt.title("lik vs. log(run time), p=2, pn=1000")

# %%
symbols_6 = [':o',':<', ':>', ':v', ':x', ':+']
index = rt_8.index.values

fig = plt.figure(figsize=(20,10))
ax1 = fig.add_subplot(3, 2, 1)
for i in range(len(index)):
    plt.plot(
        np.log(rt_8.loc[index[i], names_part_num_20]/3600), 
        diffs_8.loc[index[i], names_part_num_20],
        symbols_6[i],
        label=str(index[i])
    )
plt.axhline(y=0, color='black', linestyle='-')
_=plt.legend(loc='lower right')
_=plt.title("lik vs. log(run time) by comm freq., p=8, pn=20")

ax1 = fig.add_subplot(3, 2, 2)
for i in range(len(names_part_num_20)):
    plt.plot(
        np.log(rt_8.loc[:, names_part_num_20[i]]/3600), 
        diffs_8.loc[:, names_part_num_20[i]],
        symbols_6[i],
        label=str(names_part_num_20[i])
    )
plt.axhline(y=0, color='black', linestyle='-')
_=plt.legend(loc='lower right')
_=plt.title("lik vs. log(run time) by shard count, p=8, pn=20")

ax1 = fig.add_subplot(3, 2, 3)
for i in range(len(index)):
    plt.plot(
        np.log(rt_8.loc[index[i], names_part_num_100]/3600), 
        diffs_8.loc[index[i], names_part_num_100],
        symbols_6[i],
        label=str(index[i])
    )
plt.axhline(y=0, color='black', linestyle='-')
_=plt.legend(loc='lower right')
_=plt.title("lik vs. log(run time) by comm freq., p=8, pn=100")

ax1 = fig.add_subplot(3, 2, 4)
for i in range(len(names_part_num_100)):
    plt.plot(
        np.log(rt_8.loc[:, names_part_num_100[i]]/3600), 
        diffs_8.loc[:, names_part_num_100[i]],
        symbols_6[i],
        label=str(names_part_num_100[i])
    )
plt.axhline(y=0, color='black', linestyle='-')
_=plt.legend(loc='lower right')
_=plt.title("lik vs. log(run time) by shard count, p=8, pn=100")

ax1 = fig.add_subplot(3, 2, 5)
for i in range(len(index)):
    plt.plot(
        np.log(rt_8.loc[index[i], names_part_num_1000]/3600), 
        diffs_8.loc[index[i], names_part_num_1000],
        symbols_6[i],
        label=str(index[i])
    )
plt.axhline(y=0, color='black', linestyle='-')
_=plt.legend(loc='lower right')
_=plt.title("lik vs. log(run time) by comm freq., p=8, pn=1000")

ax1 = fig.add_subplot(3, 2, 6)
for i in range(len(names_part_num_1000)):
    plt.plot(
        np.log(rt_8.loc[:, names_part_num_1000[i]]/3600), 
        diffs_8.loc[:, names_part_num_1000[i]],
        symbols_6[i],
        label=str(names_part_num_1000[i])
    )
plt.axhline(y=0, color='black', linestyle='-')
_=plt.legend(loc='lower right')
_=plt.title("lik vs. log(run time) by shard count, p=8, pn=1000")

# %%
symbols_6 = [':o',':<', ':>', ':v', ':x', ':+']

index = rt_16.index.values

fig = plt.figure(figsize=(20,10))
ax1 = fig.add_subplot(3, 2, 1)
for i in range(len(index)):
    plt.plot(
        np.log(rt_16.loc[index[i], names_part_num_20]/3600), 
        diffs_16.loc[index[i], names_part_num_20],
        symbols_6[i],
        label=str(index[i])
    )
plt.axhline(y=0, color='black', linestyle='-')
_=plt.legend(loc='lower right')
_=plt.title("lik vs. log(run time) by comm freq., p=16, pn=20")

ax1 = fig.add_subplot(3, 2, 2)
for i in range(len(names_part_num_20)):
    plt.plot(
        np.log(rt_16.loc[:, names_part_num_20[i]]/3600), 
        diffs_16.loc[:, names_part_num_20[i]],
        symbols_6[i],
        label=str(names_part_num_20[i])
    )
plt.axhline(y=0, color='black', linestyle='-')
_=plt.legend(loc='lower right')
_=plt.title("lik vs. log(run time) by shard count, p=16, pn=20")

ax1 = fig.add_subplot(3, 2, 3)
for i in range(len(index)):
    plt.plot(
        np.log(rt_16.loc[index[i], names_part_num_100]/3600), 
        diffs_16.loc[index[i], names_part_num_100],
        symbols_6[i],
        label=str(index[i])
    )
plt.axhline(y=0, color='black', linestyle='-')
_=plt.legend(loc='lower right')
_=plt.title("lik vs. log(run time) by comm freq., p=16, pn=100")

ax1 = fig.add_subplot(3, 2, 4)
for i in range(len(names_part_num_100)):
    plt.plot(
        np.log(rt_16.loc[:, names_part_num_100[i]]/3600), 
        diffs_16.loc[:, names_part_num_100[i]],
        symbols_6[i],
        label=str(names_part_num_100[i])
    )
plt.axhline(y=0, color='black', linestyle='-')
_=plt.legend(loc='lower right')
_=plt.title("lik vs. log(run time) by shard count, p=16, pn=100")

ax1 = fig.add_subplot(3, 2, 5)
for i in range(len(index)):
    plt.plot(
        np.log(rt_16.loc[index[i], names_part_num_1000]/3600), 
        diffs_16.loc[index[i], names_part_num_1000],
        symbols_6[i],
        label=str(index[i])
    )
plt.axhline(y=0, color='black', linestyle='-')
_=plt.legend(loc='lower right')
_=plt.title("lik vs. log(run time) by comm freq., p=16, pn=1000")

ax1 = fig.add_subplot(3, 2, 6)
for i in range(len(names_part_num_1000)):
    plt.plot(
        np.log(rt_16.loc[:, names_part_num_1000[i]]/3600), 
        diffs_16.loc[:, names_part_num_1000[i]],
        symbols_6[i],
        label=str(names_part_num_1000[i])
    )
plt.axhline(y=0, color='black', linestyle='-')
_=plt.legend(loc='lower right')
_=plt.title("lik vs. log(run time) by shard count, p=16, pn=1000")

# %%
symbols_6 = [':o',':<', ':>', ':v', ':x', ':+']

index = rt_32.index.values

fig = plt.figure(figsize=(20,10))
ax1 = fig.add_subplot(3, 2, 1)
for i in range(len(index)):
    plt.plot(
        np.log(rt_32.loc[index[i], names_part_num_20]/3600), 
        diffs_32.loc[index[i], names_part_num_20],
        symbols_6[i],
        label=str(index[i])
    )
plt.axhline(y=0, color='black', linestyle='-')
_=plt.legend(loc='lower right')
_=plt.title("lik vs. log(run time) by comm freq., p=32, pn=20")

ax1 = fig.add_subplot(3, 2, 2)
for i in range(len(names_part_num_20)):
    plt.plot(
        np.log(rt_32.loc[:, names_part_num_20[i]]/3600), 
        diffs_32.loc[:, names_part_num_20[i]],
        symbols_6[i],
        label=str(names_part_num_20[i])
    )
plt.axhline(y=0, color='black', linestyle='-')
_=plt.legend(loc='lower right')
_=plt.title("lik vs. log(run time) by shard count, p=32, pn=20")

ax1 = fig.add_subplot(3, 2, 3)
for i in range(len(index)):
    plt.plot(
        np.log(rt_32.loc[index[i], names_part_num_100]/3600), 
        diffs_32.loc[index[i], names_part_num_100],
        symbols_6[i],
        label=str(index[i])
    )
plt.axhline(y=0, color='black', linestyle='-')
_=plt.legend(loc='lower right')
_=plt.title("lik vs. log(run time) by comm freq., p=32, pn=100")

ax1 = fig.add_subplot(3, 2, 4)
for i in range(len(names_part_num_100)):
    plt.plot(
        np.log(rt_32.loc[:, names_part_num_100[i]]/3600), 
        diffs_32.loc[:, names_part_num_100[i]],
        symbols_6[i],
        label=str(names_part_num_100[i])
    )
plt.axhline(y=0, color='black', linestyle='-')
_=plt.legend(loc='lower right')
_=plt.title("lik vs. log(run time) by shard count, p=32, pn=100")

ax1 = fig.add_subplot(3, 2, 5)
for i in range(len(index)):
    plt.plot(
        np.log(rt_32.loc[index[i], names_part_num_1000]/3600), 
        diffs_32.loc[index[i], names_part_num_1000],
        symbols_6[i],
        label=str(index[i])
    )
plt.axhline(y=0, color='black', linestyle='-')
_=plt.legend(loc='lower right')
_=plt.title("lik vs. log(run time) by comm freq., p=32, pn=1000")

ax1 = fig.add_subplot(3, 2, 6)
for i in range(len(names_part_num_1000)):
    plt.plot(
        np.log(rt_32.loc[:, names_part_num_1000[i]]/3600), 
        diffs_32.loc[:, names_part_num_1000[i]],
        symbols_6[i],
        label=str(names_part_num_1000[i])
    )
plt.axhline(y=0, color='black', linestyle='-')
_=plt.legend(loc='lower right')
_=plt.title("lik vs. log(run time) by shard count, p=32, pn=1000")

# %%
def plot_lik_vs_log_run_time(rt, diffs, column_names, p='9999999999', pn="9999999999"):
    symbols_6 = ['o','v', 's', 'p', 'D', '+']
    symbols_conect = ['-.','-.', '-.', '-.', '-.', '-.']
    
    for i in range(len(index)):
        plt.errorbar(
            np.log(rt.loc[index[i], column_names]/3600), 
            diffs.loc[index[i], column_names],
            yerr=0.01,
            capsize=5,
            capthick=2,
            fmt=symbols_6[i],
            markersize=8,
            label=str(index[i])
        )
    plt.axhline(y=0, color='black', linestyle='-')
    
    for i in range(len(column_names)):
        plt.plot(
            np.log(rt.loc[:, column_names[i]]/3600), 
            diffs.loc[:, column_names[i]],
            symbols_conect[i],
            label=str(column_names[i])
        )
    plt.axhline(y=0, color='black', linestyle='-')
    _=plt.title("lik vs. log(run time) by shard count and obs/epoch, p="+p+", pn="+pn)

# %%
fig = plt.figure(figsize=(20,10))
ax1 = fig.add_subplot(2, 2, 1)
plot_lik_vs_log_run_time(rt_2, diffs_2, column_names=names_part_num_1000, p='2', pn="1000")
ax1 = fig.add_subplot(2, 2, 2)
plot_lik_vs_log_run_time(rt_8, diffs_8, column_names=names_part_num_1000,p='8', pn="1000")
ax1 = fig.add_subplot(2, 2, 3)
plot_lik_vs_log_run_time(rt_16, diffs_16, column_names=names_part_num_1000,p='16', pn="1000")
ax1 = fig.add_subplot(2, 2, 4)
plot_lik_vs_log_run_time(rt_32, diffs_32, column_names=names_part_num_1000,p='32', pn="1000")
legend = plt.legend(loc='upper left', shadow=True, fontsize='x-large', bbox_to_anchor=(1, 0, 5, 2.23))
# Put a nicer background color on the legend.
legend.get_frame()#.set_facecolor('C0')
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
fig = plt.figure(figsize=(20,10))
ax1 = fig.add_subplot(2, 2, 1)
plot_lik_vs_log_run_time(rt_2, diffs_2, column_names=names_part_num_100, p='2', pn="100")
ax1 = fig.add_subplot(2, 2, 2)
plot_lik_vs_log_run_time(rt_8, diffs_8, column_names=names_part_num_100,p='8', pn="100")
ax1 = fig.add_subplot(2, 2, 3)
plot_lik_vs_log_run_time(rt_16, diffs_16, column_names=names_part_num_100,p='16', pn="100")
ax1 = fig.add_subplot(2, 2, 4)
plot_lik_vs_log_run_time(rt_32, diffs_32, column_names=names_part_num_100,p='32', pn="100")

legend = plt.legend(loc='upper left', shadow=True, fontsize='x-large', bbox_to_anchor=(1, 0, 5, 2.23))
# Put a nicer background color on the legend.
legend.get_frame()#.set_facecolor('C0')
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
fig = plt.figure(figsize=(20,10))
ax1 = fig.add_subplot(2, 2, 1)
plot_lik_vs_log_run_time(rt_2, diffs_2, column_names=names_part_num_20, p='2', pn="20")
ax1 = fig.add_subplot(2, 2, 2)
plot_lik_vs_log_run_time(rt_8, diffs_8, column_names=names_part_num_20,p='8', pn="20")
ax1 = fig.add_subplot(2, 2, 3)
plot_lik_vs_log_run_time(rt_16, diffs_16, column_names=names_part_num_20,p='16', pn="20")
ax1 = fig.add_subplot(2, 2, 4)
plot_lik_vs_log_run_time(rt_32, diffs_32, column_names=names_part_num_20,p='32', pn="20")

legend = plt.legend(loc='upper left', shadow=True, fontsize='x-large', bbox_to_anchor=(1, 0, 5, 2.23))
# Put a nicer background color on the legend.
legend.get_frame()#.set_facecolor('C0')
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
def lik_vs_pred_num(column_names, pn):
    colors = ['y','g','r','c','m','b','k',]
    symbols = ['o','<', '>', 'D', 'x', '+']
    shards = [3,6,10,15,30,60]
    
        
    diffs_list = [diffs_2, diffs_8, diffs_16, diffs_32]
    rt_list=[rt_2, rt_8, rt_16, rt_32]
    
    fig = plt.figure(figsize=(20,10))
    #array([  30,  150,  300,  600, 1200])
    index = diffs_2.index.values
    for cn in range(len(column_names)):
        ax1 = fig.add_subplot(2, 3, cn+1)

        for ind in range(len(index)):
            by_pred = np.zeros(4)
            for bp in range( len(diffs_list)):
                
                by_pred[bp] = diffs_list[bp].loc[index[ind], column_names[cn]]
            
            plt.plot(
                by_pred,
                '-.'+symbols[ind],
                color=colors[cn],
                markersize=8,
                label = column_names[cn] + ', obs/epoch=' + str(index[ind])
            )
        plt.legend(fontsize='small')
        _=plt.title("lik vs. #P by obs/epoch for shard="+str(shards[cn]) +", pn="+pn)
        
        plt.axhline(y=0, color='black', linestyle='-')
        pred_num = [2,8,16,32]
        ind = np.arange(len(pred_num))
        plt.xticks(ind, pred_num)
        plt.ylim((-.04, .07))
        #legend = plt.legend(loc='upper left', shadow=True, fontsize='medium', bbox_to_anchor=(1, 0, 5, 1))

# %%
lik_vs_pred_num(column_names=names_part_num_1000, pn="1000")
lik_vs_pred_num(column_names=names_part_num_100, pn="100")
lik_vs_pred_num(column_names=names_part_num_20, pn="20")

# %%
def plot_log_run_time_vs_comm_by_shard(rt, column_names, p='9999999999', pn="9999999999"):
    symbols_6 = [':o',':v', ':s', ':p', ':D', ':+']
    symbols_conect = ['-.','-.', '-.', '-.', '-.', '-.']
    
    for i in range(len(index)):
        plt.plot(
            [3,6,10,15,30,60],
            np.log(rt.loc[index[i], column_names]/3600), 
            #diffs.loc[index[i], column_names],
            #yerr=0.01,
            #capsize=5,
            #capthick=2,
            symbols_6[i],
            markersize=8,
            label=str(index[i])+" obs./epoch"
        )
    plt.xticks([3,6,10,15,30,60])
    #plt.axhline(y=0, color='black', linestyle='-')
    _=plt.title("log(run time) vs. number of shards\n by obs/epoch, p="+p+", pn="+pn)
    plt.legend(fontsize='small')

# %%
fig = plt.figure(figsize=(20,60))
ax1 = fig.add_subplot(12, 3, 1)
plot_log_run_time_vs_comm_by_shard(rt_2, column_names=names_part_num_20,p='2', pn="20")
ax1 = fig.add_subplot(12, 3, 2)
plot_log_run_time_vs_comm_by_shard(rt_2, column_names=names_part_num_100,p='2', pn="100")
ax1 = fig.add_subplot(12, 3, 3)
plot_log_run_time_vs_comm_by_shard(rt_2, column_names=names_part_num_1000,p='2', pn="1000")

#fig = plt.figure(figsize=(20,5))
ax1 = fig.add_subplot(12, 3, 4)
plot_log_run_time_vs_comm_by_shard(rt_8, column_names=names_part_num_20,p='8', pn="20")
ax1 = fig.add_subplot(12, 3, 5)
plot_log_run_time_vs_comm_by_shard(rt_8, column_names=names_part_num_100,p='8', pn="100")
ax1 = fig.add_subplot(12, 3, 6)
plot_log_run_time_vs_comm_by_shard(rt_8, column_names=names_part_num_1000,p='8', pn="1000")

#fig = plt.figure(figsize=(20,5))
ax1 = fig.add_subplot(12, 3, 7)
plot_log_run_time_vs_comm_by_shard(rt_16, column_names=names_part_num_20,p='16', pn="20")
ax1 = fig.add_subplot(12, 3, 8)
plot_log_run_time_vs_comm_by_shard(rt_16, column_names=names_part_num_100,p='16', pn="100")
ax1 = fig.add_subplot(12, 3, 9)
plot_log_run_time_vs_comm_by_shard(rt_16, column_names=names_part_num_1000,p='16', pn="1000")

#fig = plt.figure(figsize=(20,5))
ax1 = fig.add_subplot(12, 3, 10)
plot_log_run_time_vs_comm_by_shard(rt_32, column_names=names_part_num_20,p='32', pn="20")
ax1 = fig.add_subplot(12, 3, 11)
plot_log_run_time_vs_comm_by_shard(rt_32, column_names=names_part_num_100,p='32', pn="100")
ax1 = fig.add_subplot(12, 3, 12)
plot_log_run_time_vs_comm_by_shard(rt_32, column_names=names_part_num_1000,p='32', pn="1000")
