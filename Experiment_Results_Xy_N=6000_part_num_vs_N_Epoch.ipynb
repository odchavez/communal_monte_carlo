# %%
import analysis_functions as af
import pandas as pd
import numpy as np
import re
import pickle
import matplotlib.pyplot as plt
import seaborn as sns

# %%
old_names = [
    '20',
    '100',
    '1000',
    '20_S=6',
    '100_S=6',
    '1000_S=6',
    '20_S=10',
    '100_S=10',
    '1000_S=10',
    '20_S=15',
    '100_S=15',
    '1000_S=15',
    '20_S=30',
    '100_S=30',
    '1000_S=30',
]
new_names = [
    '20_S=3',
    '100_S=3',
    '1000_S=3',
    '20_S=6',
    '100_S=6',
    '1000_S=6',
    '20_S=10',
    '100_S=10',
    '1000_S=10',
    '20_S=15',
    '100_S=15',
    '1000_S=15',
    '20_S=30',
    '100_S=30',
    '1000_S=30',
]
names_part_num_20 = [
    '20_S=3',
    '20_S=6',
    '20_S=10',
    '20_S=15',
    '20_S=30',
    '20_S=60',
]
names_part_num_100 = [
    '100_S=3',
    '100_S=6',
    '100_S=10',
    '100_S=15',
    '100_S=30',
    '100_S=60',
]
names_part_num_1000 = [
    '1000_S=3',
    '1000_S=6',
    '1000_S=10',
    '1000_S=15',
    '1000_S=30',
    '1000_S=60',
]

# %% [markdown]
# ### p = 2

# %%
################################
#            Mean
################################
Xy_N_6000_hm_mean_plot_data_2_x_20_1000_x_30_x_3_30 = pd.DataFrame([np.zeros(15)], index = [30])
Xy_N_6000_hm_mean_plot_data_2_x_20_1000_x_30_x_3_30.columns = new_names

path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_plot_data_2_x_20_x_30_x_3.csv"
Xy_N_6000_hm_mean_plot_data_2_x_20_1000_x_30_x_3_30.loc[30,['20_S=3']]=pd.read_csv(path).loc[0,'20']
path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_plot_data_2_x_20_x_30_x_6.csv"
Xy_N_6000_hm_mean_plot_data_2_x_20_1000_x_30_x_3_30.loc[30,['20_S=6']]=pd.read_csv(path).loc[0,'20']
path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_plot_data_2_x_20_x_30_x_10.csv"
Xy_N_6000_hm_mean_plot_data_2_x_20_1000_x_30_x_3_30.loc[30,['20_S=10']]=pd.read_csv(path).loc[0,'20']
path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_plot_data_2_x_20_x_30_x_15.csv"
Xy_N_6000_hm_mean_plot_data_2_x_20_1000_x_30_x_3_30.loc[30,['20_S=15']]=pd.read_csv(path).loc[0,'20']
path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_plot_data_2_x_20_x_30_x_30.csv"
Xy_N_6000_hm_mean_plot_data_2_x_20_1000_x_30_x_3_30.loc[30,['20_S=30']]=pd.read_csv(path).loc[0,'20']

path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_plot_data_2_x_100_x_30_x_3.csv"
Xy_N_6000_hm_mean_plot_data_2_x_20_1000_x_30_x_3_30.loc[30,['100_S=3']]=pd.read_csv(path).loc[0,'100']
path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_plot_data_2_x_100_x_30_x_6.csv"
Xy_N_6000_hm_mean_plot_data_2_x_20_1000_x_30_x_3_30.loc[30,['100_S=6']]=pd.read_csv(path).loc[0,'100']
path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_plot_data_2_x_100_x_30_x_10.csv"
Xy_N_6000_hm_mean_plot_data_2_x_20_1000_x_30_x_3_30.loc[30,['100_S=10']]=pd.read_csv(path).loc[0,'100']
path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_plot_data_2_x_100_x_30_x_15.csv"
Xy_N_6000_hm_mean_plot_data_2_x_20_1000_x_30_x_3_30.loc[30,['100_S=15']]=pd.read_csv(path).loc[0,'100']
path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_plot_data_2_x_100_x_30_x_30.csv"
Xy_N_6000_hm_mean_plot_data_2_x_20_1000_x_30_x_3_30.loc[30,['100_S=30']]=pd.read_csv(path).loc[0,'100']

path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_plot_data_2_x_1000_x_30_x_3.csv"
Xy_N_6000_hm_mean_plot_data_2_x_20_1000_x_30_x_3_30.loc[30,['1000_S=3']]=pd.read_csv(path).loc[0,'1000']
path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_plot_data_2_x_1000_x_30_x_6.csv"
Xy_N_6000_hm_mean_plot_data_2_x_20_1000_x_30_x_3_30.loc[30,['1000_S=6']]=pd.read_csv(path).loc[0,'1000']
path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_plot_data_2_x_1000_x_30_x_10.csv"
Xy_N_6000_hm_mean_plot_data_2_x_20_1000_x_30_x_3_30.loc[30,['1000_S=10']]=pd.read_csv(path).loc[0,'1000']
path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_plot_data_2_x_1000_x_30_x_15.csv"
Xy_N_6000_hm_mean_plot_data_2_x_20_1000_x_30_x_3_30.loc[30,['1000_S=15']]=pd.read_csv(path).loc[0,'1000']
path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_plot_data_2_x_1000_x_30_x_30.csv"
Xy_N_6000_hm_mean_plot_data_2_x_20_1000_x_30_x_3_30.loc[30,['1000_S=30']]=pd.read_csv(path).loc[0,'1000']

path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_plot_data_2_x_20_1000_x_150_1200_x_3.csv"
Xy_N_6000_hm_mean_plot_data_2_x_20_1000_x_150_1200_x_3=pd.read_csv(path)

path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_plot_data_2_x_20_1000_x_150_1200_x_6.csv"
Xy_N_6000_hm_mean_plot_data_2_x_20_1000_x_150_1200_x_6=pd.read_csv(path)

path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_plot_data_2_x_20_1000_x_150_1200_x_10.csv"
Xy_N_6000_hm_mean_plot_data_2_x_20_1000_x_150_1200_x_10=pd.read_csv(path)

path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_plot_data_2_x_20_1000_x_150_1200_x_15.csv"
Xy_N_6000_hm_mean_plot_data_2_x_20_1000_x_150_1200_x_15=pd.read_csv(path)

path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_plot_data_2_x_20_1000_x_150_1200_x_30.csv"
Xy_N_6000_hm_mean_plot_data_2_x_20_1000_x_150_1200_x_30=pd.read_csv(path)

path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_plot_data_2_x_20_1000_x_30_1200_x_60.csv"
Xy_N_6000_hm_mean_plot_data_2_x_20_1000_x_30_1200_x_60=pd.read_csv(path)
Xy_N_6000_hm_mean_plot_data_2_x_20_1000_x_30_1200_x_60.set_index("index", inplace=True)
Xy_N_6000_hm_mean_plot_data_2_x_20_1000_x_30_1200_x_60.columns = ['20_S=60','100_S=60','1000_S=60']

joined_mean = Xy_N_6000_hm_mean_plot_data_2_x_20_1000_x_150_1200_x_3.join(
    Xy_N_6000_hm_mean_plot_data_2_x_20_1000_x_150_1200_x_6, how='left',  rsuffix='_S=6').join(
    Xy_N_6000_hm_mean_plot_data_2_x_20_1000_x_150_1200_x_10, how='left', rsuffix='_S=10').join(
    Xy_N_6000_hm_mean_plot_data_2_x_20_1000_x_150_1200_x_15, how='left', rsuffix='_S=15').join(
    Xy_N_6000_hm_mean_plot_data_2_x_20_1000_x_150_1200_x_30, how='left', rsuffix='_S=30'
)
joined_mean.set_index("index", inplace=True)
to_plot_mean = joined_mean[old_names]
to_plot_mean.columns = new_names
to_plot_mean = pd.concat([Xy_N_6000_hm_mean_plot_data_2_x_20_1000_x_30_x_3_30, to_plot_mean])

to_plot_mean = to_plot_mean.join(Xy_N_6000_hm_mean_plot_data_2_x_20_1000_x_30_1200_x_60,  how='left')
to_plot_mean.to_csv('experiment_results/heat_map_data/full_heat_map_mean_like_diff_p=2.csv', index=True, index_label='index')

plt.figure(figsize=(20,5))
sns.heatmap(
    to_plot_mean, #[new_names], 
    cmap=sns.color_palette("bone"),  
    annot=True
)
plt.ylabel("Observations Per Epoch")
plt.xlabel("particle_count_Shard_count=S")
plt.title('Mean')

plt.show()

################################
#            Std
################################
Xy_N_6000_hm_std_plot_data_2_x_20_1000_x_30_x_3_30 = pd.DataFrame([np.zeros(15)], index = [30])
Xy_N_6000_hm_std_plot_data_2_x_20_1000_x_30_x_3_30.columns = new_names

#path = "experiment_results/heat_map_data/Xy_N_6000_hm_std_plot_data_2_x_20_x_30_x_3.csv"
#Xy_N_6000_hm_std_plot_data_2_x_20_1000_x_30_x_3_30.loc[30,['20_S=3']]=pd.read_csv(path).loc[0,'20']
#path = "experiment_results/heat_map_data/Xy_N_6000_hm_std_plot_data_2_x_20_x_30_x_6.csv"
#Xy_N_6000_hm_std_plot_data_2_x_20_1000_x_30_x_3_30.loc[30,['20_S=6']]=pd.read_csv(path).loc[0,'20']
#path = "experiment_results/heat_map_data/Xy_N_6000_hm_std_plot_data_2_x_20_x_30_x_10.csv"
#Xy_N_6000_hm_std_plot_data_2_x_20_1000_x_30_x_3_30.loc[30,['20_S=10']]=pd.read_csv(path).loc[0,'20']
#path = "experiment_results/heat_map_data/Xy_N_6000_hm_std_plot_data_2_x_20_x_30_x_15.csv"
#Xy_N_6000_hm_std_plot_data_2_x_20_1000_x_30_x_3_30.loc[30,['20_S=15']]=pd.read_csv(path).loc[0,'20']
#path = "experiment_results/heat_map_data/Xy_N_6000_hm_std_plot_data_2_x_20_x_30_x_30.csv"
#Xy_N_6000_hm_std_plot_data_2_x_20_1000_x_30_x_3_30.loc[30,['20_S=30']]=pd.read_csv(path).loc[0,'20']

#path = "experiment_results/heat_map_data/Xy_N_6000_hm_std_plot_data_2_x_100_x_30_x_3.csv"
#Xy_N_6000_hm_std_plot_data_2_x_20_1000_x_30_x_3_30.loc[30,['100_S=3']]=pd.read_csv(path).loc[0,'100']
#path = "experiment_results/heat_map_data/Xy_N_6000_hm_std_plot_data_2_x_100_x_30_x_6.csv"
#Xy_N_6000_hm_std_plot_data_2_x_20_1000_x_30_x_3_30.loc[30,['100_S=6']]=pd.read_csv(path).loc[0,'100']
#path = "experiment_results/heat_map_data/Xy_N_6000_hm_std_plot_data_2_x_100_x_30_x_10.csv"
#Xy_N_6000_hm_std_plot_data_2_x_20_1000_x_30_x_3_30.loc[30,['100_S=10']]=pd.read_csv(path).loc[0,'100']
#path = "experiment_results/heat_map_data/Xy_N_6000_hm_std_plot_data_2_x_100_x_30_x_15.csv"
#Xy_N_6000_hm_std_plot_data_2_x_20_1000_x_30_x_3_30.loc[30,['100_S=15']]=pd.read_csv(path).loc[0,'100']
#path = "experiment_results/heat_map_data/Xy_N_6000_hm_std_plot_data_2_x_100_x_30_x_30.csv"
#Xy_N_6000_hm_std_plot_data_2_x_20_1000_x_30_x_3_30.loc[30,['100_S=30']]=pd.read_csv(path).loc[0,'100']
#
#path = "experiment_results/heat_map_data/Xy_N_6000_hm_std_plot_data_2_x_1000_x_30_x_3.csv"
#Xy_N_6000_hm_std_plot_data_2_x_20_1000_x_30_x_3_30.loc[30,['1000_S=3']]=pd.read_csv(path).loc[0,'1000']
#path = "experiment_results/heat_map_data/Xy_N_6000_hm_std_plot_data_2_x_1000_x_30_x_6.csv"
#Xy_N_6000_hm_std_plot_data_2_x_20_1000_x_30_x_3_30.loc[30,['1000_S=6']]=pd.read_csv(path).loc[0,'1000']
#path = "experiment_results/heat_map_data/Xy_N_6000_hm_std_plot_data_2_x_1000_x_30_x_10.csv"
#Xy_N_6000_hm_std_plot_data_2_x_20_1000_x_30_x_3_30.loc[30,['1000_S=10']]=pd.read_csv(path).loc[0,'1000']
#path = "experiment_results/heat_map_data/Xy_N_6000_hm_std_plot_data_2_x_1000_x_30_x_15.csv"
#Xy_N_6000_hm_std_plot_data_2_x_20_1000_x_30_x_3_30.loc[30,['1000_S=15']]=pd.read_csv(path).loc[0,'1000']
#path = "experiment_results/heat_map_data/Xy_N_6000_hm_std_plot_data_2_x_1000_x_30_x_30.csv"
#Xy_N_6000_hm_std_plot_data_2_x_20_1000_x_30_x_3_30.loc[30,['1000_S=30']]=pd.read_csv(path).loc[0,'1000']

#path = "experiment_results/heat_map_data/Xy_N_6000_hm_std_plot_data_2_x_20_1000_x_30_x_6.csv"
#Xy_N_6000_hm_std_plot_data_2_x_20_1000_x_30_x_6=pd.read_csv(path)
#
#path = "experiment_results/heat_map_data/Xy_N_6000_hm_std_plot_data_2_x_20_1000_x_30_x_10.csv"
#Xy_N_6000_hm_std_plot_data_2_x_20_1000_x_30_x_10=pd.read_csv(path)
#
#path = "experiment_results/heat_map_data/Xy_N_6000_hm_std_plot_data_2_x_20_1000_x_30_x_15.csv"
#Xy_N_6000_hm_std_plot_data_2_x_20_1000_x_30_x_15=pd.read_csv(path)
#
#path = "experiment_results/heat_map_data/Xy_N_6000_hm_std_plot_data_2_x_20_1000_x_30_x_30.csv"
#Xy_N_6000_hm_std_plot_data_2_x_20_1000_x_30_x_30=pd.read_csv(path)

path = "experiment_results/heat_map_data/Xy_N_6000_hm_std_plot_data_2_x_20_1000_x_30_1200_x_60.csv"
Xy_N_6000_hm_std_plot_data_2_x_20_1000_x_30_1200_x_60=pd.read_csv(path)
Xy_N_6000_hm_std_plot_data_2_x_20_1000_x_30_1200_x_60.set_index("index", inplace=True)
Xy_N_6000_hm_std_plot_data_2_x_20_1000_x_30_1200_x_60.columns = ['20_S=60','100_S=60','1000_S=60']

#Xy_N_6000_hm_std_plot_data_2_x_20_1000_x_30_x_3_30 = Xy_N_6000_hm_std_plot_data_2_x_20_1000_x_30_x_3.join(
#    Xy_N_6000_hm_std_plot_data_2_x_20_1000_x_30_x_6, how='left',  rsuffix='_S=6').join(
#    Xy_N_6000_hm_std_plot_data_2_x_20_1000_x_30_x_10, how='left', rsuffix='_S=10').join(
#    Xy_N_6000_hm_std_plot_data_2_x_20_1000_x_30_x_15, how='left', rsuffix='_S=15').join(
#    Xy_N_6000_hm_std_plot_data_2_x_20_1000_x_30_x_30, how='left', rsuffix='_S=30'
#)

path = "experiment_results/heat_map_data/Xy_N_6000_hm_std_plot_data_2_x_20_1000_x_150_1200_x_3.csv"
Xy_N_6000_hm_std_plot_data_2_x_20_1000_x_150_1200_x_3=pd.read_csv(path)

path = "experiment_results/heat_map_data/Xy_N_6000_hm_std_plot_data_2_x_20_1000_x_150_1200_x_6.csv"
Xy_N_6000_hm_std_plot_data_2_x_20_1000_x_150_1200_x_6=pd.read_csv(path)

path = "experiment_results/heat_map_data/Xy_N_6000_hm_std_plot_data_2_x_20_1000_x_150_1200_x_10.csv"
Xy_N_6000_hm_std_plot_data_2_x_20_1000_x_150_1200_x_10=pd.read_csv(path)

path = "experiment_results/heat_map_data/Xy_N_6000_hm_std_plot_data_2_x_20_1000_x_150_1200_x_15.csv"
Xy_N_6000_hm_std_plot_data_2_x_20_1000_x_150_1200_x_15=pd.read_csv(path)

path = "experiment_results/heat_map_data/Xy_N_6000_hm_std_plot_data_2_x_20_1000_x_150_1200_x_30.csv"
Xy_N_6000_hm_std_plot_data_2_x_20_1000_x_150_1200_x_30=pd.read_csv(path)

joined_std_err = Xy_N_6000_hm_std_plot_data_2_x_20_1000_x_150_1200_x_3.join(
    Xy_N_6000_hm_std_plot_data_2_x_20_1000_x_150_1200_x_6, how='left',  rsuffix='_S=6').join(
    Xy_N_6000_hm_std_plot_data_2_x_20_1000_x_150_1200_x_10, how='left', rsuffix='_S=10').join(
    Xy_N_6000_hm_std_plot_data_2_x_20_1000_x_150_1200_x_15, how='left', rsuffix='_S=15').join(
    Xy_N_6000_hm_std_plot_data_2_x_20_1000_x_150_1200_x_30, how='left', rsuffix='_S=30'
)

joined_std_err = pd.concat([Xy_N_6000_hm_std_plot_data_2_x_20_1000_x_30_x_3_30, joined_std_err])
joined_std_err.set_index("index", inplace=True)
to_plot_std_err = joined_std_err[old_names]
to_plot_std_err.columns = new_names

#to_plot_mean = pd.concat([Xy_N_6000_hm_mean_plot_data_2_x_20_1000_x_30_x_3_30, to_plot_mean])
#to_plot_mean = to_plot_mean.join(Xy_N_6000_hm_mean_plot_data_2_x_20_1000_x_30_1200_x_60,  how='left')

plt.figure(figsize=(20,5))

sns.heatmap(to_plot_std_err[new_names], cmap=sns.color_palette("bone"),  annot=True)
plt.ylabel("Observations Per Epoch")
plt.xlabel("particle_count_Shard_count=S")
plt.title('Standard Error')
plt.show()

fig = plt.figure(figsize=(20,5))
ax1 = fig.add_subplot(1, 3, 1)
ax2 = fig.add_subplot(1, 3, 2)
ax3 = fig.add_subplot(1, 3, 3)

sns.heatmap(to_plot_mean[names_part_num_20], cmap=sns.color_palette("bone"),  annot=True, ax=ax1, vmin=-0.01, vmax=0.06)
plt.ylabel("Observations Per Epoch")
plt.xlabel("particle_count_Shard_count=S")

sns.heatmap(to_plot_mean[names_part_num_100], cmap=sns.color_palette("bone"),  annot=True, ax=ax2, vmin=-0.01, vmax=0.06)
plt.ylabel("Observations Per Epoch")
plt.xlabel("particle_count_Shard_count=S")

sns.heatmap(to_plot_mean[names_part_num_1000], cmap=sns.color_palette("bone"),  annot=True, ax=ax3, vmin=-0.01, vmax=0.06)
plt.ylabel("Observations Per Epoch")
plt.xlabel("particle_count_Shard_count=S")

plt.show()

for i in range(len(names_part_num_1000)):
    plt.errorbar(
        [30,150,300,600,1200], 
        to_plot_mean[names_part_num_1000[i]],
        yerr=.001, 
        xlolims=True, 
        #label='xlolims=True'
    )


#fig = plt.figure(figsize=(20,5))
#ax1 = fig.add_subplot(1, 3, 1)
#ax2 = fig.add_subplot(1, 3, 2)
#ax3 = fig.add_subplot(1, 3, 3)
#
#sns.heatmap(to_plot_std_err[names_part_num_20], cmap=sns.color_palette("bone"),  annot=True, ax=ax1, vmin=0.001, vmax=0.01)
#plt.ylabel("Observations Per Epoch")
#plt.xlabel("particle_count_Shard_count=S")
#
#sns.heatmap(to_plot_std_err[names_part_num_100], cmap=sns.color_palette("bone"),  annot=True, ax=ax2, vmin=0.001, vmax=0.01)
#plt.ylabel("Observations Per Epoch")
#plt.xlabel("particle_count_Shard_count=S")
#
#sns.heatmap(to_plot_std_err[names_part_num_1000], cmap=sns.color_palette("bone"),  annot=True, ax=ax3, vmin=0.001, vmax=0.01)
#plt.ylabel("Observations Per Epoch")
#plt.xlabel("particle_count_Shard_count=S")
#
#plt.show()
plt.show()

# %%
symbols = ['--o','--<', '-->', '--v', '--x','--^']

comm_point = [30,150,300,600,1200]
yerr = np.ones(len(comm_point))*0.01
ind = np.arange(len(comm_point))

#fig = plt.figure(figsize=(7,7))
fig = plt.figure(figsize=(25,9))
ax1 = fig.add_subplot(1, 3, 1)
for i in range(len(names_part_num_20)):
    plt.errorbar(
        ind, 
        y=to_plot_mean[names_part_num_20[i]],
        yerr=[yerr, yerr],
        capsize=5,
        capthick=2,
        fmt=symbols[i],
        xlolims=True, 
        label=names_part_num_20[i]
    )
plt.axhline(y=0, color='black', linestyle='-')
_=plt.legend(loc='upper right')
plt.title('Simulated Data: p=2, particles=20')
plt.ylabel('Difference in Average Likelihood')
plt.xlabel('Observations Processed per Epoch')
plt.xticks(ind, comm_point)
plt.ylim((-.02, .08))

ax2 = fig.add_subplot(1, 3, 2)

for i in range(len(names_part_num_100)):
    plt.errorbar(
        ind, 
        y=to_plot_mean[names_part_num_100[i]],
        yerr=[yerr, yerr],
        capsize=5,
        capthick=2,
        fmt=symbols[i],
        xlolims=True, 
        label=names_part_num_100[i]
    )
plt.axhline(y=0, color='black', linestyle='-')
_=plt.legend(loc='upper right')
plt.title('Simulated Data: p=2, particles=100')
plt.ylabel('Difference in Average Likelihood')
plt.xlabel('Observations Processed per Epoch')
plt.xticks(ind, comm_point)
plt.ylim((-.02, .08))

ax3 = fig.add_subplot(1, 3, 3)

for i in range(len(names_part_num_1000)):
    plt.errorbar(
        ind, 
        y=to_plot_mean[names_part_num_1000[i]],
        yerr=[yerr, yerr],
        capsize=5,
        capthick=2,
        fmt=symbols[i],
        xlolims=True, 
        label=names_part_num_1000[i]
    )
plt.axhline(y=0, color='black', linestyle='-')
_=plt.legend(loc='upper right')
plt.title('Simulated Data: p=2, particles=1000')
plt.ylabel('Difference in Average Likelihood')
plt.xlabel('Observations Processed per Epoch')
plt.xticks(ind, comm_point)
plt.ylim((-.02, .08))

plt.show()

########################################################################
symbols = ['--o','--<', '-->', '--v', '--x']
shard_count = [3,6,10,15,30, 60]
yerr = np.ones(len(shard_count))*0.01
ind = np.arange(len(shard_count))
index = to_plot_mean.index.values

fig = plt.figure(figsize=(20,6))
ax1 = fig.add_subplot(1, 3, 1)
for i in range(len(index)):
    plt.errorbar(
        ind, 
        y=to_plot_mean.loc[index[i], names_part_num_20],
        yerr=0.01, #[yerr, yerr],
        capsize=5,
        capthick=2,
        fmt=symbols[i],
        #xlolims=True, 
        label=str(index[i])
    )
plt.axhline(y=0, color='black', linestyle='-')
_=plt.legend(loc='upper left')
plt.title('Simulated Data: p=2, particles=20')
plt.ylabel('Difference in Average Likelihood')
plt.xlabel('Shard Count')
plt.xticks(ind,shard_count)
plt.ylim((-.02, .08))

ax1 = fig.add_subplot(1, 3, 2)
for i in range(len(index)):
    plt.errorbar(
        ind, 
        y=to_plot_mean.loc[index[i], names_part_num_100],
        yerr=0.01, #[yerr, yerr],
        capsize=5,
        capthick=2,
        fmt=symbols[i],
        #xlolims=True, 
        label=str(index[i])
    )
plt.axhline(y=0, color='black', linestyle='-')
_=plt.legend(loc='upper left')
plt.title('Simulated Data: p=2, particles=100')
plt.ylabel('Difference in Average Likelihood')
plt.xlabel('Shard Count')
plt.xticks(ind,shard_count)
plt.ylim((-.02, .08))

ax1 = fig.add_subplot(1, 3, 3)
for i in range(len(index)):
    plt.errorbar(
        ind, 
        y=to_plot_mean.loc[index[i], names_part_num_1000],
        yerr=0.01, #[yerr, yerr],
        capsize=5,
        capthick=2,
        fmt=symbols[i],
        #xlolims=True, 
        label=str(index[i])
    )
plt.axhline(y=0, color='black', linestyle='-')
_=plt.legend(loc='upper left')
plt.title('Simulated Data: p=2, particles=1000')
plt.ylabel('Difference in Average Likelihood')
plt.xlabel('Shard Count')
plt.xticks(ind,shard_count)
plt.ylim((-.02, .08))

plt.show()

# %% [markdown]
# ### p = 8

# %%
################################
#            Mean
################################
Xy_N_6000_hm_mean_plot_data_8_x_20_1000_x_30_x_3_30 = pd.DataFrame([np.zeros(15)], index = [30])
Xy_N_6000_hm_mean_plot_data_8_x_20_1000_x_30_x_3_30.columns = new_names

path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_plot_data_8_x_20_x_30_x_3.csv"
Xy_N_6000_hm_mean_plot_data_8_x_20_1000_x_30_x_3_30.loc[30,['20_S=3']]=pd.read_csv(path).loc[0,'20']
path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_plot_data_8_x_20_x_30_x_6.csv"
Xy_N_6000_hm_mean_plot_data_8_x_20_1000_x_30_x_3_30.loc[30,['20_S=6']]=pd.read_csv(path).loc[0,'20']
path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_plot_data_8_x_20_x_30_x_10.csv"
Xy_N_6000_hm_mean_plot_data_8_x_20_1000_x_30_x_3_30.loc[30,['20_S=10']]=pd.read_csv(path).loc[0,'20']
path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_plot_data_8_x_20_x_30_x_15.csv"
Xy_N_6000_hm_mean_plot_data_8_x_20_1000_x_30_x_3_30.loc[30,['20_S=15']]=pd.read_csv(path).loc[0,'20']
path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_plot_data_8_x_20_x_30_x_30.csv"
Xy_N_6000_hm_mean_plot_data_8_x_20_1000_x_30_x_3_30.loc[30,['20_S=30']]=pd.read_csv(path).loc[0,'20']

path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_plot_data_8_x_100_x_30_x_3.csv"
Xy_N_6000_hm_mean_plot_data_8_x_20_1000_x_30_x_3_30.loc[30,['100_S=3']]=pd.read_csv(path).loc[0,'100']
path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_plot_data_8_x_100_x_30_x_6.csv"
Xy_N_6000_hm_mean_plot_data_8_x_20_1000_x_30_x_3_30.loc[30,['100_S=6']]=pd.read_csv(path).loc[0,'100']
path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_plot_data_8_x_100_x_30_x_10.csv"
Xy_N_6000_hm_mean_plot_data_8_x_20_1000_x_30_x_3_30.loc[30,['100_S=10']]=pd.read_csv(path).loc[0,'100']
path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_plot_data_8_x_100_x_30_x_15.csv"
Xy_N_6000_hm_mean_plot_data_8_x_20_1000_x_30_x_3_30.loc[30,['100_S=15']]=pd.read_csv(path).loc[0,'100']
path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_plot_data_8_x_100_x_30_x_30.csv"
Xy_N_6000_hm_mean_plot_data_8_x_20_1000_x_30_x_3_30.loc[30,['100_S=30']]=pd.read_csv(path).loc[0,'100']

path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_plot_data_8_x_1000_x_30_x_3.csv"
Xy_N_6000_hm_mean_plot_data_8_x_20_1000_x_30_x_3_30.loc[30,['1000_S=3']]=pd.read_csv(path).loc[0,'1000']
path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_plot_data_8_x_1000_x_30_x_6.csv"
Xy_N_6000_hm_mean_plot_data_8_x_20_1000_x_30_x_3_30.loc[30,['1000_S=6']]=pd.read_csv(path).loc[0,'1000']
path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_plot_data_8_x_1000_x_30_x_10.csv"
Xy_N_6000_hm_mean_plot_data_8_x_20_1000_x_30_x_3_30.loc[30,['1000_S=10']]=pd.read_csv(path).loc[0,'1000']
path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_plot_data_8_x_1000_x_30_x_15.csv"
Xy_N_6000_hm_mean_plot_data_8_x_20_1000_x_30_x_3_30.loc[30,['1000_S=15']]=pd.read_csv(path).loc[0,'1000']
path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_plot_data_8_x_1000_x_30_x_30.csv"
Xy_N_6000_hm_mean_plot_data_8_x_20_1000_x_30_x_3_30.loc[30,['1000_S=30']]=pd.read_csv(path).loc[0,'1000']

path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_plot_data_8_x_20_1000_x_150_1200_x_3.csv"
Xy_N_6000_hm_mean_plot_data_8_x_20_1000_x_150_1200_x_3=pd.read_csv(path)

path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_plot_data_8_x_20_1000_x_150_1200_x_6.csv"
Xy_N_6000_hm_mean_plot_data_8_x_20_1000_x_150_1200_x_6=pd.read_csv(path)

path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_plot_data_8_x_20_1000_x_150_1200_x_10.csv"
Xy_N_6000_hm_mean_plot_data_8_x_20_1000_x_150_1200_x_10=pd.read_csv(path)

path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_plot_data_8_x_20_1000_x_150_1200_x_15.csv"
Xy_N_6000_hm_mean_plot_data_8_x_20_1000_x_150_1200_x_15=pd.read_csv(path)

path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_plot_data_8_x_20_1000_x_150_1200_x_30.csv"
Xy_N_6000_hm_mean_plot_data_8_x_20_1000_x_150_1200_x_30=pd.read_csv(path)

path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_plot_data_8_x_20_1000_x_30_1200_x_60.csv"
Xy_N_6000_hm_mean_plot_data_8_x_20_1000_x_30_1200_x_60=pd.read_csv(path)
Xy_N_6000_hm_mean_plot_data_8_x_20_1000_x_30_1200_x_60.set_index("index", inplace=True)
Xy_N_6000_hm_mean_plot_data_8_x_20_1000_x_30_1200_x_60.columns = ['20_S=60','100_S=60','1000_S=60']

joined_mean = Xy_N_6000_hm_mean_plot_data_8_x_20_1000_x_150_1200_x_3.join(
    Xy_N_6000_hm_mean_plot_data_8_x_20_1000_x_150_1200_x_6, how='left',  rsuffix='_S=6').join(
    Xy_N_6000_hm_mean_plot_data_8_x_20_1000_x_150_1200_x_10, how='left', rsuffix='_S=10').join(
    Xy_N_6000_hm_mean_plot_data_8_x_20_1000_x_150_1200_x_15, how='left', rsuffix='_S=15').join(
    Xy_N_6000_hm_mean_plot_data_8_x_20_1000_x_150_1200_x_30, how='left', rsuffix='_S=30'
)
joined_mean.set_index("index", inplace=True)
to_plot_mean = joined_mean[old_names]
to_plot_mean.columns = new_names
to_plot_mean = pd.concat([Xy_N_6000_hm_mean_plot_data_8_x_20_1000_x_30_x_3_30, to_plot_mean])

print(Xy_N_6000_hm_mean_plot_data_8_x_20_1000_x_30_1200_x_60)
to_plot_mean = to_plot_mean.join(Xy_N_6000_hm_mean_plot_data_8_x_20_1000_x_30_1200_x_60,  how='left')
to_plot_mean.to_csv('experiment_results/heat_map_data/full_heat_map_mean_like_diff_p=8.csv', index=True, index_label='index')

plt.figure(figsize=(20,5))
sns.heatmap(
    to_plot_mean,#[new_names], 
    cmap=sns.color_palette("bone"),  
    annot=True
)
plt.ylabel("Observations Per Epoch")
plt.xlabel("particle_count_Shard_count=S")
plt.title('Mean')

plt.show()

#################################
##            Std
#################################
#
#path = "experiment_results/heat_map_data/Xy_N_6000_hm_std_plot_data_8_x_20_1000_x_150_1200_x_3.csv"
#Xy_N_6000_hm_std_plot_data_8_x_20_1000_x_150_1200_x_3=pd.read_csv(path)
#
#path = "experiment_results/heat_map_data/Xy_N_6000_hm_std_plot_data_8_x_20_1000_x_150_1200_x_6.csv"
#Xy_N_6000_hm_std_plot_data_8_x_20_1000_x_150_1200_x_6=pd.read_csv(path)
#
#path = "experiment_results/heat_map_data/Xy_N_6000_hm_std_plot_data_8_x_20_1000_x_150_1200_x_10.csv"
#Xy_N_6000_hm_std_plot_data_8_x_20_1000_x_150_1200_x_10=pd.read_csv(path)
#
#path = "experiment_results/heat_map_data/Xy_N_6000_hm_std_plot_data_8_x_20_1000_x_150_1200_x_15.csv"
#Xy_N_6000_hm_std_plot_data_8_x_20_1000_x_150_1200_x_15=pd.read_csv(path)
#
#path = "experiment_results/heat_map_data/Xy_N_6000_hm_std_plot_data_8_x_20_1000_x_150_1200_x_30.csv"
#Xy_N_6000_hm_std_plot_data_8_x_20_1000_x_150_1200_x_30=pd.read_csv(path)
#
#joined_std_err = Xy_N_6000_hm_std_plot_data_8_x_20_1000_x_150_1200_x_3.join(
#    Xy_N_6000_hm_std_plot_data_8_x_20_1000_x_150_1200_x_6, how='left',  rsuffix='_S=6').join(
#    Xy_N_6000_hm_std_plot_data_8_x_20_1000_x_150_1200_x_10, how='left', rsuffix='_S=10').join(
#    Xy_N_6000_hm_std_plot_data_8_x_20_1000_x_150_1200_x_15, how='left', rsuffix='_S=15').join(
#    Xy_N_6000_hm_std_plot_data_8_x_20_1000_x_150_1200_x_30, how='left', rsuffix='_S=30'
#)
#joined_std_err.set_index("index", inplace=True)
#to_plot_std_err = joined_std_err[old_names]
#to_plot_std_err.columns = new_names
#plt.figure(figsize=(20,5))
#
#sns.heatmap(to_plot_std_err[new_names], cmap=sns.color_palette("bone"),  annot=True)
#plt.ylabel("Observations Per Epoch")
#plt.xlabel("particle_count_Shard_count=S")
#plt.title('Standard Error')
#plt.show()

fig = plt.figure(figsize=(20,5))
ax1 = fig.add_subplot(1, 3, 1)
ax2 = fig.add_subplot(1, 3, 2)
ax3 = fig.add_subplot(1, 3, 3)

sns.heatmap(to_plot_mean[names_part_num_20], cmap=sns.color_palette("bone"),  annot=True, ax=ax1)
plt.ylabel("Observations Per Epoch")
plt.xlabel("particle_count_Shard_count=S")

sns.heatmap(to_plot_mean[names_part_num_100], cmap=sns.color_palette("bone"),  annot=True, ax=ax2)
plt.ylabel("Observations Per Epoch")
plt.xlabel("particle_count_Shard_count=S")

sns.heatmap(to_plot_mean[names_part_num_1000], cmap=sns.color_palette("bone"),  annot=True, ax=ax3)
plt.ylabel("Observations Per Epoch")
plt.xlabel("particle_count_Shard_count=S")

plt.show()

#fig = plt.figure(figsize=(20,5))
#ax1 = fig.add_subplot(1, 3, 1)
#ax2 = fig.add_subplot(1, 3, 2)
#ax3 = fig.add_subplot(1, 3, 3)
#
#sns.heatmap(to_plot_std_err[names_part_num_20], cmap=sns.color_palette("bone"),  annot=True, ax=ax1, vmin=0.001, vmax=0.01)
#plt.ylabel("Observations Per Epoch")
#plt.xlabel("particle_count_Shard_count=S")
#
#sns.heatmap(to_plot_std_err[names_part_num_100], cmap=sns.color_palette("bone"),  annot=True, ax=ax2, vmin=0.001, vmax=0.01)
#plt.ylabel("Observations Per Epoch")
#plt.xlabel("particle_count_Shard_count=S")
#
#sns.heatmap(to_plot_std_err[names_part_num_1000], cmap=sns.color_palette("bone"),  annot=True, ax=ax3, vmin=0.001, vmax=0.01)
#plt.ylabel("Observations Per Epoch")
#plt.xlabel("particle_count_Shard_count=S")
#
#plt.show()
# Out:
#         20_S=60  100_S=60  1000_S=60
# index
# 30     0.032692  0.045043   0.051394
# 150    0.052363  0.047248   0.041411
# 300    0.052206  0.045969   0.042530
# 600    0.038708  0.031319   0.026367
# 1200   0.013536  0.018543   0.014442

# %%
symbols = ['--o','--<', '-->', '--v', '--x','--^']

comm_point = [30,150,300,600,1200]
yerr = np.ones(len(comm_point))*0.01
ind = np.arange(len(comm_point))

#fig = plt.figure(figsize=(7,7))
fig = plt.figure(figsize=(25,9))
ax1 = fig.add_subplot(1, 3, 1)
for i in range(len(names_part_num_20)):
    plt.errorbar(
        ind, 
        y=to_plot_mean[names_part_num_20[i]],
        yerr=[yerr, yerr],
        capsize=5,
        capthick=2,
        fmt=symbols[i],
        xlolims=True, 
        label=names_part_num_20[i]
    )
plt.axhline(y=0, color='black', linestyle='-')
_=plt.legend(loc='upper right')
plt.title('Simulated Data: p=8, particles=20')
plt.ylabel('Difference in Average Likelihood')
plt.xlabel('Observations Processed per Epoch')
plt.xticks(ind, comm_point)
plt.ylim((-.02, .08))

ax2 = fig.add_subplot(1, 3, 2)

for i in range(len(names_part_num_100)):
    plt.errorbar(
        ind, 
        y=to_plot_mean[names_part_num_100[i]],
        yerr=[yerr, yerr],
        capsize=5,
        capthick=2,
        fmt=symbols[i],
        xlolims=True, 
        label=names_part_num_100[i]
    )
plt.axhline(y=0, color='black', linestyle='-')
_=plt.legend(loc='upper right')
plt.title('Simulated Data: p=8, particles=100')
plt.ylabel('Difference in Average Likelihood')
plt.xlabel('Observations Processed per Epoch')
plt.xticks(ind, comm_point)
plt.ylim((-.02, .08))

ax3 = fig.add_subplot(1, 3, 3)

for i in range(len(names_part_num_1000)):
    plt.errorbar(
        ind, 
        y=to_plot_mean[names_part_num_1000[i]],
        yerr=[yerr, yerr],
        capsize=5,
        capthick=2,
        fmt=symbols[i],
        xlolims=True, 
        label=names_part_num_1000[i]
    )
plt.axhline(y=0, color='black', linestyle='-')
_=plt.legend(loc='upper right')
plt.title('Simulated Data: p=8, particles=1000')
plt.ylabel('Difference in Average Likelihood')
plt.xlabel('Observations Processed per Epoch')
plt.xticks(ind, comm_point)
plt.ylim((-.02, .08))

plt.show()

########################################################################
symbols = ['--o','--<', '-->', '--v', '--x']
shard_count = [3,6,10,15,30, 60]
yerr = np.ones(len(shard_count))*0.01
ind = np.arange(len(shard_count))
index = to_plot_mean.index.values

fig = plt.figure(figsize=(20,6))
ax1 = fig.add_subplot(1, 3, 1)
for i in range(len(index)):
    plt.errorbar(
        ind, 
        y=to_plot_mean.loc[index[i], names_part_num_20],
        yerr=0.01, #[yerr, yerr],
        capsize=5,
        capthick=2,
        fmt=symbols[i],
        #xlolims=True, 
        label=str(index[i])
    )
plt.axhline(y=0, color='black', linestyle='-')
_=plt.legend(loc='upper left')
plt.title('Simulated Data: p=8, particles=20')
plt.ylabel('Difference in Average Likelihood')
plt.xlabel('Shard Count')
plt.xticks(ind,shard_count)
plt.ylim((-.02, .08))

ax1 = fig.add_subplot(1, 3, 2)
for i in range(len(index)):
    plt.errorbar(
        ind, 
        y=to_plot_mean.loc[index[i], names_part_num_100],
        yerr=0.01, #[yerr, yerr],
        capsize=5,
        capthick=2,
        fmt=symbols[i],
        #xlolims=True, 
        label=str(index[i])
    )
plt.axhline(y=0, color='black', linestyle='-')
_=plt.legend(loc='upper left')
plt.title('Simulated Data: p=8, particles=100')
plt.ylabel('Difference in Average Likelihood')
plt.xlabel('Shard Count')
plt.xticks(ind,shard_count)
plt.ylim((-.02, .08))

ax1 = fig.add_subplot(1, 3, 3)
for i in range(len(index)):
    plt.errorbar(
        ind, 
        y=to_plot_mean.loc[index[i], names_part_num_1000],
        yerr=0.01, #[yerr, yerr],
        capsize=5,
        capthick=2,
        fmt=symbols[i],
        #xlolims=True, 
        label=str(index[i])
    )
plt.axhline(y=0, color='black', linestyle='-')
_=plt.legend(loc='upper left')
plt.title('Simulated Data: p=8, particles=1000')
plt.ylabel('Difference in Average Likelihood')
plt.xlabel('Shard Count')
plt.xticks(ind,shard_count)
plt.ylim((-.02, .08))

plt.show()

# %% [markdown]
# ### p = 16

# %%
################################
#            Mean
################################
Xy_N_6000_hm_mean_plot_data_16_x_20_1000_x_30_x_3_30 = pd.DataFrame([np.zeros(15)], index = [30])
Xy_N_6000_hm_mean_plot_data_16_x_20_1000_x_30_x_3_30.columns = new_names

path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_plot_data_16_x_20_x_30_x_3.csv"
Xy_N_6000_hm_mean_plot_data_16_x_20_1000_x_30_x_3_30.loc[30,['20_S=3']]=pd.read_csv(path).loc[0,'20']
path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_plot_data_16_x_20_x_30_x_6.csv"
Xy_N_6000_hm_mean_plot_data_16_x_20_1000_x_30_x_3_30.loc[30,['20_S=6']]=pd.read_csv(path).loc[0,'20']
path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_plot_data_16_x_20_x_30_x_10.csv"
Xy_N_6000_hm_mean_plot_data_16_x_20_1000_x_30_x_3_30.loc[30,['20_S=10']]=pd.read_csv(path).loc[0,'20']
path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_plot_data_16_x_20_x_30_x_15.csv"
Xy_N_6000_hm_mean_plot_data_16_x_20_1000_x_30_x_3_30.loc[30,['20_S=15']]=pd.read_csv(path).loc[0,'20']
path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_plot_data_16_x_20_x_30_x_30.csv"
Xy_N_6000_hm_mean_plot_data_16_x_20_1000_x_30_x_3_30.loc[30,['20_S=30']]=pd.read_csv(path).loc[0,'20']

path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_plot_data_16_x_100_x_30_x_3.csv"
Xy_N_6000_hm_mean_plot_data_16_x_20_1000_x_30_x_3_30.loc[30,['100_S=3']]=pd.read_csv(path).loc[0,'100']
path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_plot_data_16_x_100_x_30_x_6.csv"
Xy_N_6000_hm_mean_plot_data_16_x_20_1000_x_30_x_3_30.loc[30,['100_S=6']]=pd.read_csv(path).loc[0,'100']
path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_plot_data_16_x_100_x_30_x_10.csv"
Xy_N_6000_hm_mean_plot_data_16_x_20_1000_x_30_x_3_30.loc[30,['100_S=10']]=pd.read_csv(path).loc[0,'100']
path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_plot_data_16_x_100_x_30_x_15.csv"
Xy_N_6000_hm_mean_plot_data_16_x_20_1000_x_30_x_3_30.loc[30,['100_S=15']]=pd.read_csv(path).loc[0,'100']
path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_plot_data_16_x_100_x_30_x_30.csv"
Xy_N_6000_hm_mean_plot_data_16_x_20_1000_x_30_x_3_30.loc[30,['100_S=30']]=pd.read_csv(path).loc[0,'100']

path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_plot_data_16_x_1000_x_30_x_3.csv"
Xy_N_6000_hm_mean_plot_data_16_x_20_1000_x_30_x_3_30.loc[30,['1000_S=3']]=pd.read_csv(path).loc[0,'1000']
path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_plot_data_16_x_1000_x_30_x_6.csv"
Xy_N_6000_hm_mean_plot_data_16_x_20_1000_x_30_x_3_30.loc[30,['1000_S=6']]=pd.read_csv(path).loc[0,'1000']
path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_plot_data_16_x_1000_x_30_x_10.csv"
Xy_N_6000_hm_mean_plot_data_16_x_20_1000_x_30_x_3_30.loc[30,['1000_S=10']]=pd.read_csv(path).loc[0,'1000']
path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_plot_data_16_x_1000_x_30_x_15.csv"
Xy_N_6000_hm_mean_plot_data_16_x_20_1000_x_30_x_3_30.loc[30,['1000_S=15']]=pd.read_csv(path).loc[0,'1000']
path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_plot_data_16_x_1000_x_30_x_30.csv"
Xy_N_6000_hm_mean_plot_data_16_x_20_1000_x_30_x_3_30.loc[30,['1000_S=30']]=pd.read_csv(path).loc[0,'1000']

path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_plot_data_16_x_20_1000_x_150_1200_x_3.csv"
Xy_N_6000_hm_mean_plot_data_16_x_20_1000_x_150_1200_x_3=pd.read_csv(path)

path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_plot_data_16_x_20_1000_x_150_1200_x_6.csv"
Xy_N_6000_hm_mean_plot_data_16_x_20_1000_x_150_1200_x_6=pd.read_csv(path)

path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_plot_data_16_x_20_1000_x_150_1200_x_10.csv"
Xy_N_6000_hm_mean_plot_data_16_x_20_1000_x_150_1200_x_10=pd.read_csv(path)

path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_plot_data_16_x_20_1000_x_150_1200_x_15.csv"
Xy_N_6000_hm_mean_plot_data_16_x_20_1000_x_150_1200_x_15=pd.read_csv(path)

path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_plot_data_16_x_20_1000_x_150_1200_x_30.csv"
Xy_N_6000_hm_mean_plot_data_16_x_20_1000_x_150_1200_x_30=pd.read_csv(path)

path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_plot_data_16_x_20_1000_x_30_1200_x_60.csv"
Xy_N_6000_hm_mean_plot_data_16_x_20_1000_x_30_1200_x_60=pd.read_csv(path)
Xy_N_6000_hm_mean_plot_data_16_x_20_1000_x_30_1200_x_60.set_index("index", inplace=True)
Xy_N_6000_hm_mean_plot_data_16_x_20_1000_x_30_1200_x_60.columns = ['20_S=60','100_S=60','1000_S=60']

joined_mean = Xy_N_6000_hm_mean_plot_data_16_x_20_1000_x_150_1200_x_3.join(
    Xy_N_6000_hm_mean_plot_data_16_x_20_1000_x_150_1200_x_6, how='left',  rsuffix='_S=6').join(
    Xy_N_6000_hm_mean_plot_data_16_x_20_1000_x_150_1200_x_10, how='left', rsuffix='_S=10').join(
    Xy_N_6000_hm_mean_plot_data_16_x_20_1000_x_150_1200_x_15, how='left', rsuffix='_S=15').join(
    Xy_N_6000_hm_mean_plot_data_16_x_20_1000_x_150_1200_x_30, how='left', rsuffix='_S=30'
)
joined_mean.set_index("index", inplace=True)
to_plot_mean = joined_mean[old_names]
to_plot_mean.columns = new_names
to_plot_mean = pd.concat([Xy_N_6000_hm_mean_plot_data_16_x_20_1000_x_30_x_3_30, to_plot_mean])

to_plot_mean = to_plot_mean.join(Xy_N_6000_hm_mean_plot_data_16_x_20_1000_x_30_1200_x_60,  how='left')
to_plot_mean.to_csv('experiment_results/heat_map_data/full_heat_map_mean_like_diff_p=16.csv', index=True, index_label='index')


plt.figure(figsize=(20,5))
sns.heatmap(
    to_plot_mean,#[new_names], 
    cmap=sns.color_palette("bone"),  
    annot=True
)
plt.ylabel("Observations Per Epoch")
plt.xlabel("particle_count_Shard_count=S")
plt.title('Mean')

plt.show()

#################################
##            Std
#################################
#
#path = "experiment_results/heat_map_data/Xy_N_6000_hm_std_plot_data_16_x_20_1000_x_150_1200_x_3.csv"
#Xy_N_6000_hm_std_plot_data_16_x_20_1000_x_150_1200_x_3=pd.read_csv(path)
#
#path = "experiment_results/heat_map_data/Xy_N_6000_hm_std_plot_data_16_x_20_1000_x_150_1200_x_6.csv"
#Xy_N_6000_hm_std_plot_data_16_x_20_1000_x_150_1200_x_6=pd.read_csv(path)
#
#path = "experiment_results/heat_map_data/Xy_N_6000_hm_std_plot_data_16_x_20_1000_x_150_1200_x_10.csv"
#Xy_N_6000_hm_std_plot_data_16_x_20_1000_x_150_1200_x_10=pd.read_csv(path)
#
#path = "experiment_results/heat_map_data/Xy_N_6000_hm_std_plot_data_16_x_20_1000_x_150_1200_x_15.csv"
#Xy_N_6000_hm_std_plot_data_16_x_20_1000_x_150_1200_x_15=pd.read_csv(path)
#
#path = "experiment_results/heat_map_data/Xy_N_6000_hm_std_plot_data_16_x_20_1000_x_150_1200_x_30.csv"
#Xy_N_6000_hm_std_plot_data_16_x_20_1000_x_150_1200_x_30=pd.read_csv(path)
#
#joined_std_err = Xy_N_6000_hm_std_plot_data_16_x_20_1000_x_150_1200_x_3.join(
#    Xy_N_6000_hm_std_plot_data_16_x_20_1000_x_150_1200_x_6, how='left',  rsuffix='_S=6').join(
#    Xy_N_6000_hm_std_plot_data_16_x_20_1000_x_150_1200_x_10, how='left', rsuffix='_S=10').join(
#    Xy_N_6000_hm_std_plot_data_16_x_20_1000_x_150_1200_x_15, how='left', rsuffix='_S=15').join(
#    Xy_N_6000_hm_std_plot_data_16_x_20_1000_x_150_1200_x_30, how='left', rsuffix='_S=30'
#)
#joined_std_err.set_index("index", inplace=True)
#to_plot_std_err = joined_std_err[old_names]
#to_plot_std_err.columns = new_names
#plt.figure(figsize=(20,5))
#
#sns.heatmap(to_plot_std_err[new_names], cmap=sns.color_palette("bone"),  annot=True)
#plt.ylabel("Observations Per Epoch")
#plt.xlabel("particle_count_Shard_count=S")
#plt.title('Standard Error')
#plt.show()
#
fig = plt.figure(figsize=(20,5))
ax1 = fig.add_subplot(1, 3, 1)
ax2 = fig.add_subplot(1, 3, 2)
ax3 = fig.add_subplot(1, 3, 3)

sns.heatmap(to_plot_mean[names_part_num_20], cmap=sns.color_palette("bone"),  annot=True, ax=ax1, vmin=-0.01, vmax=0.06)
plt.ylabel("Observations Per Epoch")
plt.xlabel("particle_count_Shard_count=S")

sns.heatmap(to_plot_mean[names_part_num_100], cmap=sns.color_palette("bone"),  annot=True, ax=ax2, vmin=-0.01, vmax=0.06)
plt.ylabel("Observations Per Epoch")
plt.xlabel("particle_count_Shard_count=S")

sns.heatmap(to_plot_mean[names_part_num_1000], cmap=sns.color_palette("bone"),  annot=True, ax=ax3, vmin=-0.01, vmax=0.06)
plt.ylabel("Observations Per Epoch")
plt.xlabel("particle_count_Shard_count=S")

plt.show()
#
#fig = plt.figure(figsize=(20,5))
#ax1 = fig.add_subplot(1, 3, 1)
#ax2 = fig.add_subplot(1, 3, 2)
#ax3 = fig.add_subplot(1, 3, 3)
#
#sns.heatmap(to_plot_std_err[names_part_num_20], cmap=sns.color_palette("bone"),  annot=True, ax=ax1, vmin=0.001, vmax=0.01)
#plt.ylabel("Observations Per Epoch")
#plt.xlabel("particle_count_Shard_count=S")
#
#sns.heatmap(to_plot_std_err[names_part_num_100], cmap=sns.color_palette("bone"),  annot=True, ax=ax2, vmin=0.001, vmax=0.01)
#plt.ylabel("Observations Per Epoch")
#plt.xlabel("particle_count_Shard_count=S")
#
#sns.heatmap(to_plot_std_err[names_part_num_1000], cmap=sns.color_palette("bone"),  annot=True, ax=ax3, vmin=0.001, vmax=0.01)
#plt.ylabel("Observations Per Epoch")
#plt.xlabel("particle_count_Shard_count=S")
#
#plt.show()

# %%
symbols = ['--o','--<', '-->', '--v', '--x','--^']

comm_point = [30,150,300,600,1200]
yerr = np.ones(len(comm_point))*0.01
ind = np.arange(len(comm_point))

#fig = plt.figure(figsize=(7,7))
fig = plt.figure(figsize=(25,9))
ax1 = fig.add_subplot(1, 3, 1)
for i in range(len(names_part_num_20)):
    plt.errorbar(
        ind, 
        y=to_plot_mean[names_part_num_20[i]],
        yerr=[yerr, yerr],
        capsize=5,
        capthick=2,
        fmt=symbols[i],
        xlolims=True, 
        label=names_part_num_20[i]
    )
plt.axhline(y=0, color='black', linestyle='-')
_=plt.legend(loc='upper right')
plt.title('Simulated Data: p=16, particles=20')
plt.ylabel('Difference in Average Likelihood')
plt.xlabel('Observations Processed per Epoch')
plt.xticks(ind, comm_point)
plt.ylim((-.02, .08))

ax2 = fig.add_subplot(1, 3, 2)

for i in range(len(names_part_num_100)):
    plt.errorbar(
        ind, 
        y=to_plot_mean[names_part_num_100[i]],
        yerr=[yerr, yerr],
        capsize=5,
        capthick=2,
        fmt=symbols[i],
        xlolims=True, 
        label=names_part_num_100[i]
    )
plt.axhline(y=0, color='black', linestyle='-')
_=plt.legend(loc='upper right')
plt.title('Simulated Data: p=16, particles=100')
plt.ylabel('Difference in Average Likelihood')
plt.xlabel('Observations Processed per Epoch')
plt.xticks(ind, comm_point)
plt.ylim((-.02, .08))

ax3 = fig.add_subplot(1, 3, 3)

for i in range(len(names_part_num_1000)):
    plt.errorbar(
        ind, 
        y=to_plot_mean[names_part_num_1000[i]],
        yerr=[yerr, yerr],
        capsize=5,
        capthick=2,
        fmt=symbols[i],
        xlolims=True, 
        label=names_part_num_1000[i]
    )
plt.axhline(y=0, color='black', linestyle='-')
_=plt.legend(loc='upper right')
plt.title('Simulated Data: p=16, particles=1000')
plt.ylabel('Difference in Average Likelihood')
plt.xlabel('Observations Processed per Epoch')
plt.xticks(ind, comm_point)
plt.ylim((-.02, .08))

plt.show()

########################################################################
symbols = ['--o','--<', '-->', '--v', '--x']
shard_count = [3,6,10,15,30, 60]
yerr = np.ones(len(shard_count))*0.01
ind = np.arange(len(shard_count))
index = to_plot_mean.index.values

fig = plt.figure(figsize=(20,6))
ax1 = fig.add_subplot(1, 3, 1)
for i in range(len(index)):
    plt.errorbar(
        ind, 
        y=to_plot_mean.loc[index[i], names_part_num_20],
        yerr=0.01, #[yerr, yerr],
        capsize=5,
        capthick=2,
        fmt=symbols[i],
        #xlolims=True, 
        label=str(index[i])
    )
plt.axhline(y=0, color='black', linestyle='-')
_=plt.legend(loc='upper left')
plt.title('Simulated Data: p=16, particles=20')
plt.ylabel('Difference in Average Likelihood')
plt.xlabel('Shard Count')
plt.xticks(ind,shard_count)
plt.ylim((-.02, .08))

ax1 = fig.add_subplot(1, 3, 2)
for i in range(len(index)):
    plt.errorbar(
        ind, 
        y=to_plot_mean.loc[index[i], names_part_num_100],
        yerr=0.01, #[yerr, yerr],
        capsize=5,
        capthick=2,
        fmt=symbols[i],
        #xlolims=True, 
        label=str(index[i])
    )
plt.axhline(y=0, color='black', linestyle='-')
_=plt.legend(loc='upper left')
plt.title('Simulated Data: p=16, particles=100')
plt.ylabel('Difference in Average Likelihood')
plt.xlabel('Shard Count')
plt.xticks(ind,shard_count)
plt.ylim((-.02, .08))

ax1 = fig.add_subplot(1, 3, 3)
for i in range(len(index)):
    plt.errorbar(
        ind, 
        y=to_plot_mean.loc[index[i], names_part_num_1000],
        yerr=0.01, #[yerr, yerr],
        capsize=5,
        capthick=2,
        fmt=symbols[i],
        #xlolims=True, 
        label=str(index[i])
    )
plt.axhline(y=0, color='black', linestyle='-')
_=plt.legend(loc='upper left')
plt.title('Simulated Data: p=16, particles=1000')
plt.ylabel('Difference in Average Likelihood')
plt.xlabel('Shard Count')
plt.xticks(ind,shard_count)
plt.ylim((-.02, .08))

plt.show()

# %% [markdown]
# ### p = 32

# %%
################################
#            Mean
################################
Xy_N_6000_hm_mean_plot_data_32_x_20_1000_x_30_x_3_30 = pd.DataFrame([np.zeros(15)], index = [30])
Xy_N_6000_hm_mean_plot_data_32_x_20_1000_x_30_x_3_30.columns = new_names

path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_plot_data_32_x_20_x_30_x_3.csv"
Xy_N_6000_hm_mean_plot_data_32_x_20_1000_x_30_x_3_30.loc[30,['20_S=3']]=pd.read_csv(path).loc[0,'20']
path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_plot_data_32_x_20_x_30_x_6.csv"
Xy_N_6000_hm_mean_plot_data_32_x_20_1000_x_30_x_3_30.loc[30,['20_S=6']]=pd.read_csv(path).loc[0,'20']
path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_plot_data_32_x_20_x_30_x_10.csv"
Xy_N_6000_hm_mean_plot_data_32_x_20_1000_x_30_x_3_30.loc[30,['20_S=10']]=pd.read_csv(path).loc[0,'20']
path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_plot_data_32_x_20_x_30_x_15.csv"
Xy_N_6000_hm_mean_plot_data_32_x_20_1000_x_30_x_3_30.loc[30,['20_S=15']]=pd.read_csv(path).loc[0,'20']
path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_plot_data_32_x_20_x_30_x_30.csv"
Xy_N_6000_hm_mean_plot_data_32_x_20_1000_x_30_x_3_30.loc[30,['20_S=30']]=pd.read_csv(path).loc[0,'20']

path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_plot_data_32_x_100_x_30_x_3.csv"
Xy_N_6000_hm_mean_plot_data_32_x_20_1000_x_30_x_3_30.loc[30,['100_S=3']]=pd.read_csv(path).loc[0,'100']
path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_plot_data_32_x_100_x_30_x_6.csv"
Xy_N_6000_hm_mean_plot_data_32_x_20_1000_x_30_x_3_30.loc[30,['100_S=6']]=pd.read_csv(path).loc[0,'100']
path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_plot_data_32_x_100_x_30_x_10.csv"
Xy_N_6000_hm_mean_plot_data_32_x_20_1000_x_30_x_3_30.loc[30,['100_S=10']]=pd.read_csv(path).loc[0,'100']
path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_plot_data_32_x_100_x_30_x_15.csv"
Xy_N_6000_hm_mean_plot_data_32_x_20_1000_x_30_x_3_30.loc[30,['100_S=15']]=pd.read_csv(path).loc[0,'100']
path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_plot_data_32_x_100_x_30_x_30.csv"
Xy_N_6000_hm_mean_plot_data_32_x_20_1000_x_30_x_3_30.loc[30,['100_S=30']]=pd.read_csv(path).loc[0,'100']

path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_plot_data_32_x_1000_x_30_x_3.csv"
Xy_N_6000_hm_mean_plot_data_32_x_20_1000_x_30_x_3_30.loc[30,['1000_S=3']]=pd.read_csv(path).loc[0,'1000']
path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_plot_data_32_x_1000_x_30_x_6.csv"
Xy_N_6000_hm_mean_plot_data_32_x_20_1000_x_30_x_3_30.loc[30,['1000_S=6']]=pd.read_csv(path).loc[0,'1000']
path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_plot_data_32_x_1000_x_30_x_10.csv"
Xy_N_6000_hm_mean_plot_data_32_x_20_1000_x_30_x_3_30.loc[30,['1000_S=10']]=pd.read_csv(path).loc[0,'1000']
path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_plot_data_32_x_1000_x_30_x_15.csv"
Xy_N_6000_hm_mean_plot_data_32_x_20_1000_x_30_x_3_30.loc[30,['1000_S=15']]=pd.read_csv(path).loc[0,'1000']
path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_plot_data_32_x_1000_x_30_x_30.csv"
Xy_N_6000_hm_mean_plot_data_32_x_20_1000_x_30_x_3_30.loc[30,['1000_S=30']]=pd.read_csv(path).loc[0,'1000']

path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_plot_data_32_x_20_1000_x_150_1200_x_3.csv"
Xy_N_6000_hm_mean_plot_data_32_x_20_1000_x_150_1200_x_3=pd.read_csv(path)

path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_plot_data_32_x_20_1000_x_150_1200_x_6.csv"
Xy_N_6000_hm_mean_plot_data_32_x_20_1000_x_150_1200_x_6=pd.read_csv(path)

path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_plot_data_32_x_20_1000_x_150_1200_x_10.csv"
Xy_N_6000_hm_mean_plot_data_32_x_20_1000_x_150_1200_x_10=pd.read_csv(path)

path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_plot_data_32_x_20_1000_x_150_1200_x_15.csv"
Xy_N_6000_hm_mean_plot_data_32_x_20_1000_x_150_1200_x_15=pd.read_csv(path)

path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_plot_data_32_x_20_1000_x_150_1200_x_30.csv"
Xy_N_6000_hm_mean_plot_data_32_x_20_1000_x_150_1200_x_30=pd.read_csv(path)

path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_plot_data_32_x_20_1000_x_30_1200_x_60.csv"
Xy_N_6000_hm_mean_plot_data_32_x_20_1000_x_30_1200_x_60=pd.read_csv(path)
Xy_N_6000_hm_mean_plot_data_32_x_20_1000_x_30_1200_x_60.set_index("index", inplace=True)
Xy_N_6000_hm_mean_plot_data_32_x_20_1000_x_30_1200_x_60.columns = ['20_S=60','100_S=60','1000_S=60']

joined_mean = Xy_N_6000_hm_mean_plot_data_32_x_20_1000_x_150_1200_x_3.join(
    Xy_N_6000_hm_mean_plot_data_32_x_20_1000_x_150_1200_x_6, how='left',  rsuffix='_S=6').join(
    Xy_N_6000_hm_mean_plot_data_32_x_20_1000_x_150_1200_x_10, how='left', rsuffix='_S=10').join(
    Xy_N_6000_hm_mean_plot_data_32_x_20_1000_x_150_1200_x_15, how='left', rsuffix='_S=15').join(
    Xy_N_6000_hm_mean_plot_data_32_x_20_1000_x_150_1200_x_30, how='left', rsuffix='_S=30'
)
joined_mean.set_index("index", inplace=True)
to_plot_mean = joined_mean[old_names]
to_plot_mean.columns = new_names
to_plot_mean = pd.concat([Xy_N_6000_hm_mean_plot_data_32_x_20_1000_x_30_x_3_30, to_plot_mean])

to_plot_mean = to_plot_mean.join(Xy_N_6000_hm_mean_plot_data_32_x_20_1000_x_30_1200_x_60,  how='left')

plt.figure(figsize=(20,5))
sns.heatmap(to_plot_mean, cmap=sns.color_palette("bone"),  annot=True)
plt.ylabel("Observations Per Epoch")
plt.xlabel("particle_count_Shard_count=S")
plt.title('Mean')
plt.show()


to_plot_mean.to_csv('experiment_results/heat_map_data/full_heat_map_mean_like_diff_p=32.csv', index=True, index_label='index')

#################################
##            Std
#################################
#
path = "experiment_results/heat_map_data/Xy_N_6000_hm_std_plot_data_32_x_20_1000_x_150_1200_x_3.csv"
Xy_N_6000_hm_std_plot_data_32_x_20_1000_x_150_1200_x_3=pd.read_csv(path)

path = "experiment_results/heat_map_data/Xy_N_6000_hm_std_plot_data_32_x_20_1000_x_150_1200_x_6.csv"
Xy_N_6000_hm_std_plot_data_32_x_20_1000_x_150_1200_x_6=pd.read_csv(path)

path = "experiment_results/heat_map_data/Xy_N_6000_hm_std_plot_data_32_x_20_1000_x_150_1200_x_10.csv"
Xy_N_6000_hm_std_plot_data_32_x_20_1000_x_150_1200_x_10=pd.read_csv(path)

path = "experiment_results/heat_map_data/Xy_N_6000_hm_std_plot_data_32_x_20_1000_x_150_1200_x_15.csv"
Xy_N_6000_hm_std_plot_data_32_x_20_1000_x_150_1200_x_15=pd.read_csv(path)

path = "experiment_results/heat_map_data/Xy_N_6000_hm_std_plot_data_32_x_20_1000_x_150_1200_x_30.csv"
Xy_N_6000_hm_std_plot_data_32_x_20_1000_x_150_1200_x_30=pd.read_csv(path)

#path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_plot_data_32_x_20_1000_x_30_1200_x_60.csv"
#Xy_N_6000_hm_mean_plot_data_32_x_20_1000_x_30_1200_x_60=pd.read_csv(path)
#Xy_N_6000_hm_mean_plot_data_32_x_20_1000_x_30_1200_x_60.set_index("index", inplace=True)
#Xy_N_6000_hm_mean_plot_data_32_x_20_1000_x_30_1200_x_60.columns = ['20_S=60','100_S=60','1000_S=60']
#
joined_std_err = Xy_N_6000_hm_std_plot_data_32_x_20_1000_x_150_1200_x_3.join(
    Xy_N_6000_hm_std_plot_data_32_x_20_1000_x_150_1200_x_6, how='left',  rsuffix='_S=6').join(
    Xy_N_6000_hm_std_plot_data_32_x_20_1000_x_150_1200_x_10, how='left', rsuffix='_S=10').join(
    Xy_N_6000_hm_std_plot_data_32_x_20_1000_x_150_1200_x_15, how='left', rsuffix='_S=15').join(
    Xy_N_6000_hm_std_plot_data_32_x_20_1000_x_150_1200_x_30, how='left', rsuffix='_S=30'
)
joined_std_err.set_index("index", inplace=True)
to_plot_std_err = joined_std_err[old_names]
to_plot_std_err.columns = new_names
plt.figure(figsize=(20,5))

sns.heatmap(to_plot_std_err[new_names], cmap=sns.color_palette("bone"),  annot=True)
plt.ylabel("Observations Per Epoch")
plt.xlabel("particle_count_Shard_count=S")
plt.title('Standard Error')
plt.show()

fig = plt.figure(figsize=(20,5))
ax1 = fig.add_subplot(1, 3, 1)
ax2 = fig.add_subplot(1, 3, 2)
ax3 = fig.add_subplot(1, 3, 3)

sns.heatmap(to_plot_mean[names_part_num_20], cmap=sns.color_palette("bone"),  annot=True, ax=ax1)
plt.ylabel("Observations Per Epoch")
plt.xlabel("particle_count_Shard_count=S")

sns.heatmap(to_plot_mean[names_part_num_100], cmap=sns.color_palette("bone"),  annot=True, ax=ax2)
plt.ylabel("Observations Per Epoch")
plt.xlabel("particle_count_Shard_count=S")

sns.heatmap(to_plot_mean[names_part_num_1000], cmap=sns.color_palette("bone"),  annot=True, ax=ax3)
plt.ylabel("Observations Per Epoch")
plt.xlabel("particle_count_Shard_count=S")

plt.show()


#
#fig = plt.figure(figsize=(20,5))
#ax1 = fig.add_subplot(1, 3, 1)
#ax2 = fig.add_subplot(1, 3, 2)
#ax3 = fig.add_subplot(1, 3, 3)
#
#sns.heatmap(to_plot_std_err[names_part_num_20], cmap=sns.color_palette("bone"),  annot=True, ax=ax1, vmin=0.001, vmax=0.01)
#plt.ylabel("Observations Per Epoch")
#plt.xlabel("particle_count_Shard_count=S")
#
#sns.heatmap(to_plot_std_err[names_part_num_100], cmap=sns.color_palette("bone"),  annot=True, ax=ax2, vmin=0.001, vmax=0.01)
#plt.ylabel("Observations Per Epoch")
#plt.xlabel("particle_count_Shard_count=S")
#
#sns.heatmap(to_plot_std_err[names_part_num_1000], cmap=sns.color_palette("bone"),  annot=True, ax=ax3, vmin=0.001, vmax=0.01)
#plt.ylabel("Observations Per Epoch")
#plt.xlabel("particle_count_Shard_count=S")
#
#plt.show()

# %%
symbols = ['--o','--<', '-->', '--v', '--x','--^']

comm_point = [30,150,300,600,1200]
yerr = np.ones(len(comm_point))*0.01
ind = np.arange(len(comm_point))

#fig = plt.figure(figsize=(7,7))
fig = plt.figure(figsize=(25,9))
ax1 = fig.add_subplot(1, 3, 1)
for i in range(len(names_part_num_20)):
    plt.errorbar(
        ind, 
        y=to_plot_mean[names_part_num_20[i]],
        yerr=[yerr, yerr],
        capsize=5,
        capthick=2,
        fmt=symbols[i],
        xlolims=True, 
        label=names_part_num_20[i]
    )
plt.axhline(y=0, color='black', linestyle='-')
_=plt.legend(loc='upper right')
plt.title('Simulated Data: p=32, particles=20')
plt.ylabel('Difference in Average Likelihood')
plt.xlabel('Observations Processed per Epoch')
plt.xticks(ind, comm_point)
plt.ylim((-.04, .09))

ax2 = fig.add_subplot(1, 3, 2)

for i in range(len(names_part_num_100)):
    plt.errorbar(
        ind, 
        y=to_plot_mean[names_part_num_100[i]],
        yerr=[yerr, yerr],
        capsize=5,
        capthick=2,
        fmt=symbols[i],
        xlolims=True, 
        label=names_part_num_100[i]
    )
plt.axhline(y=0, color='black', linestyle='-')
_=plt.legend(loc='upper right')
plt.title('Simulated Data: p=32, particles=100')
plt.ylabel('Difference in Average Likelihood')
plt.xlabel('Observations Processed per Epoch')
plt.xticks(ind, comm_point)
plt.ylim((-.04, .09))

ax3 = fig.add_subplot(1, 3, 3)

for i in range(len(names_part_num_1000)):
    plt.errorbar(
        ind, 
        y=to_plot_mean[names_part_num_1000[i]],
        yerr=[yerr, yerr],
        capsize=5,
        capthick=2,
        fmt=symbols[i],
        xlolims=True, 
        label=names_part_num_1000[i]
    )
plt.axhline(y=0, color='black', linestyle='-')
_=plt.legend(loc='upper right')
plt.title('Simulated Data: p=32, particles=1000')
plt.ylabel('Difference in Average Likelihood')
plt.xlabel('Observations Processed per Epoch')
plt.xticks(ind, comm_point)
plt.ylim((-.04, .09))

plt.show()

########################################################################
symbols = ['--o','--<', '-->', '--v', '--x']
shard_count = [3,6,10,15,30, 60]
yerr = np.ones(len(shard_count))*0.01
ind = np.arange(len(shard_count))
index = to_plot_mean.index.values

fig = plt.figure(figsize=(20,6))
ax1 = fig.add_subplot(1, 3, 1)
for i in range(len(index)):
    plt.errorbar(
        ind, 
        y=to_plot_mean.loc[index[i], names_part_num_20],
        yerr=0.01, #[yerr, yerr],
        capsize=5,
        capthick=2,
        fmt=symbols[i],
        #xlolims=True, 
        label=str(index[i])
    )
plt.axhline(y=0, color='black', linestyle='-')
_=plt.legend(loc='upper left')
plt.title('Simulated Data: p=32, particles=100')
plt.ylabel('Difference in Average Likelihood')
plt.xlabel('Shard Count')
plt.xticks(ind,shard_count)
plt.ylim((-.04, .09))

ax1 = fig.add_subplot(1, 3, 2)
for i in range(len(index)):
    plt.errorbar(
        ind, 
        y=to_plot_mean.loc[index[i], names_part_num_100],
        yerr=0.01, #[yerr, yerr],
        capsize=5,
        capthick=2,
        fmt=symbols[i],
        #xlolims=True, 
        label=str(index[i])
    )
plt.axhline(y=0, color='black', linestyle='-')
_=plt.legend(loc='upper left')
plt.title('Simulated Data: p=32, particles=100')
plt.ylabel('Difference in Average Likelihood')
plt.xlabel('Shard Count')
plt.xticks(ind,shard_count)
plt.ylim((-.04, .09))

ax1 = fig.add_subplot(1, 3, 3)
for i in range(len(index)):
    plt.errorbar(
        ind, 
        y=to_plot_mean.loc[index[i], names_part_num_1000],
        yerr=0.01, #[yerr, yerr],
        capsize=5,
        capthick=2,
        fmt=symbols[i],
        #xlolims=True, 
        label=str(index[i])
    )
plt.axhline(y=0, color='black', linestyle='-')
_=plt.legend(loc='upper left')
plt.title('Simulated Data: p=32, particles=1000')
plt.ylabel('Difference in Average Likelihood')
plt.xlabel('Shard Count')
plt.xticks(ind,shard_count)
plt.ylim((-.04, .09))

plt.show()
