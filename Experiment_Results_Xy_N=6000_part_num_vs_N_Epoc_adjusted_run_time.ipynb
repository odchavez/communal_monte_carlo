# %%
import analysis_functions as af
import pandas as pd
import numpy as np
import re
import pickle
import matplotlib.pyplot as plt
import seaborn as sns

# %%
old_names = [
    '20',
    '100',
    '1000',
    '20_S=6',
    '100_S=6',
    '1000_S=6',
    '20_S=10',
    '100_S=10',
    '1000_S=10',
    '20_S=15',
    '100_S=15',
    '1000_S=15',
    '20_S=30',
    '100_S=30',
    '1000_S=30',
]
new_names = [
    '20_S=3',
    '100_S=3',
    '1000_S=3',
    '20_S=6',
    '100_S=6',
    '1000_S=6',
    '20_S=10',
    '100_S=10',
    '1000_S=10',
    '20_S=15',
    '100_S=15',
    '1000_S=15',
    '20_S=30',
    '100_S=30',
    '1000_S=30',
]
names_part_num_20 = [
    '20_S=3',
    '20_S=6',
    '20_S=10',
    '20_S=15',
    '20_S=30',
]
names_part_num_100 = [
    '100_S=3',
    '100_S=6',
    '100_S=10',
    '100_S=15',
    '100_S=30',
]
names_part_num_1000 = [
    '1000_S=3',
    '1000_S=6',
    '1000_S=10',
    '1000_S=15',
    '1000_S=30',
]

# %% [markdown]
# ### p = 2

# %%
################################
#            Mean
################################

path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_adjusted_run_time_plot_data_2_x_20_1000_x_150_1200_x_3.csv"
Xy_N_6000_hm_mean_adjusted_run_time_plot_data_2_x_20_1000_x_150_1200_x_3=pd.read_csv(path)

path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_adjusted_run_time_plot_data_2_x_20_1000_x_150_1200_x_6.csv"
Xy_N_6000_hm_mean_adjusted_run_time_plot_data_2_x_20_1000_x_150_1200_x_6=pd.read_csv(path)


path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_adjusted_run_time_plot_data_2_x_20_1000_x_150_1200_x_10.csv"
Xy_N_6000_hm_mean_adjusted_run_time_plot_data_2_x_20_1000_x_150_1200_x_10=pd.read_csv(path)


path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_adjusted_run_time_plot_data_2_x_20_1000_x_150_1200_x_15.csv"
Xy_N_6000_hm_mean_adjusted_run_time_plot_data_2_x_20_1000_x_150_1200_x_15=pd.read_csv(path)


path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_adjusted_run_time_plot_data_2_x_20_1000_x_150_1200_x_30.csv"
Xy_N_6000_hm_mean_adjusted_run_time_plot_data_2_x_20_1000_x_150_1200_x_30=pd.read_csv(path)

joined_mean_adjusted_run_time = Xy_N_6000_hm_mean_adjusted_run_time_plot_data_2_x_20_1000_x_150_1200_x_3.join(
    Xy_N_6000_hm_mean_adjusted_run_time_plot_data_2_x_20_1000_x_150_1200_x_6, how='left',  rsuffix='_S=6').join(
    Xy_N_6000_hm_mean_adjusted_run_time_plot_data_2_x_20_1000_x_150_1200_x_10, how='left', rsuffix='_S=10').join(
    Xy_N_6000_hm_mean_adjusted_run_time_plot_data_2_x_20_1000_x_150_1200_x_15, how='left', rsuffix='_S=15').join(
    Xy_N_6000_hm_mean_adjusted_run_time_plot_data_2_x_20_1000_x_150_1200_x_30, how='left', rsuffix='_S=30'
)
joined_mean_adjusted_run_time.set_index("index", inplace=True)
to_plot_mean_adjusted_run_time = joined_mean_adjusted_run_time[old_names]
to_plot_mean_adjusted_run_time.columns = new_names
plt.figure(figsize=(20,5))
sns.heatmap(to_plot_mean_adjusted_run_time[new_names], cmap=sns.color_palette("bone"),  annot=True)
plt.ylabel("Observations Per Epoch")
plt.xlabel("particle_count_Shard_count=S")
plt.title('Mean Run Time')

plt.show()

################################
#            Std
################################
path = "experiment_results/heat_map_data/Xy_N_6000_hm_std_adjusted_run_time_plot_data_2_x_20_1000_x_30_x_3.csv"
Xy_N_6000_hm_std_adjusted_run_time_plot_data_2_x_20_1000_x_30_x_3=pd.read_csv(path)

path = "experiment_results/heat_map_data/Xy_N_6000_hm_std_adjusted_run_time_plot_data_2_x_20_1000_x_30_x_6.csv"
Xy_N_6000_hm_std_adjusted_run_time_plot_data_2_x_20_1000_x_30_x_6=pd.read_csv(path)

path = "experiment_results/heat_map_data/Xy_N_6000_hm_std_adjusted_run_time_plot_data_2_x_20_1000_x_30_x_10.csv"
Xy_N_6000_hm_std_adjusted_run_time_plot_data_2_x_20_1000_x_30_x_10=pd.read_csv(path)

path = "experiment_results/heat_map_data/Xy_N_6000_hm_std_adjusted_run_time_plot_data_2_x_20_1000_x_30_x_15.csv"
Xy_N_6000_hm_std_adjusted_run_time_plot_data_2_x_20_1000_x_30_x_15=pd.read_csv(path)

path = "experiment_results/heat_map_data/Xy_N_6000_hm_std_plot_data_2_x_20_1000_x_30_x_30.csv"
Xy_N_6000_hm_std_adjusted_run_time_plot_data_2_x_20_1000_x_30_x_30=pd.read_csv(path)

Xy_N_6000_hm_std_adjusted_run_time_plot_data_2_x_20_1000_x_30_x_3_30 = Xy_N_6000_hm_std_adjusted_run_time_plot_data_2_x_20_1000_x_30_x_3.join(
    Xy_N_6000_hm_std_adjusted_run_time_plot_data_2_x_20_1000_x_30_x_6, how='left',  rsuffix='_S=6').join(
    Xy_N_6000_hm_std_adjusted_run_time_plot_data_2_x_20_1000_x_30_x_10, how='left', rsuffix='_S=10').join(
    Xy_N_6000_hm_std_adjusted_run_time_plot_data_2_x_20_1000_x_30_x_15, how='left', rsuffix='_S=15').join(
    Xy_N_6000_hm_std_adjusted_run_time_plot_data_2_x_20_1000_x_30_x_30, how='left', rsuffix='_S=30'
)

path = "experiment_results/heat_map_data/Xy_N_6000_hm_std_adjusted_run_time_plot_data_2_x_20_1000_x_150_1200_x_3.csv"
Xy_N_6000_hm_std_adjusted_run_time_plot_data_2_x_20_1000_x_150_1200_x_3=pd.read_csv(path)

path = "experiment_results/heat_map_data/Xy_N_6000_hm_std_adjusted_run_time_plot_data_2_x_20_1000_x_150_1200_x_6.csv"
Xy_N_6000_hm_std_adjusted_run_time_plot_data_2_x_20_1000_x_150_1200_x_6=pd.read_csv(path)

path = "experiment_results/heat_map_data/Xy_N_6000_hm_std_adjusted_run_time_plot_data_2_x_20_1000_x_150_1200_x_10.csv"
Xy_N_6000_hm_std_adjusted_run_time_plot_data_2_x_20_1000_x_150_1200_x_10=pd.read_csv(path)

path = "experiment_results/heat_map_data/Xy_N_6000_hm_std_adjusted_run_time_plot_data_2_x_20_1000_x_150_1200_x_15.csv"
Xy_N_6000_hm_std_adjusted_run_time_plot_data_2_x_20_1000_x_150_1200_x_15=pd.read_csv(path)

path = "experiment_results/heat_map_data/Xy_N_6000_hm_std_adjusted_run_time_plot_data_2_x_20_1000_x_150_1200_x_30.csv"
Xy_N_6000_hm_std_adjusted_run_time_plot_data_2_x_20_1000_x_150_1200_x_30=pd.read_csv(path)

joined_std_adjusted_run_time_err = Xy_N_6000_hm_std_adjusted_run_time_plot_data_2_x_20_1000_x_150_1200_x_3.join(
    Xy_N_6000_hm_std_adjusted_run_time_plot_data_2_x_20_1000_x_150_1200_x_6, how='left',  rsuffix='_S=6').join(
    Xy_N_6000_hm_std_adjusted_run_time_plot_data_2_x_20_1000_x_150_1200_x_10, how='left', rsuffix='_S=10').join(
    Xy_N_6000_hm_std_adjusted_run_time_plot_data_2_x_20_1000_x_150_1200_x_15, how='left', rsuffix='_S=15').join(
    Xy_N_6000_hm_std_adjusted_run_time_plot_data_2_x_20_1000_x_150_1200_x_30, how='left', rsuffix='_S=30'
)

joined_std_adjusted_run_time_err = pd.concat([Xy_N_6000_hm_std_adjusted_run_time_plot_data_2_x_20_1000_x_30_x_3_30, joined_std_adjusted_run_time_err])
joined_std_adjusted_run_time_err.set_index("index", inplace=True)
to_plot_std_adjusted_run_time_err = joined_std_adjusted_run_time_err[old_names]
to_plot_std_adjusted_run_time_err.columns = new_names
plt.figure(figsize=(20,5))

sns.heatmap(to_plot_std_adjusted_run_time_err[new_names], cmap=sns.color_palette("bone"),  annot=True)
plt.ylabel("Observations Per Epoch")
plt.xlabel("particle_count_Shard_count=S")
plt.title('Standard Error')
plt.show()

fig = plt.figure(figsize=(20,5))
ax1 = fig.add_subplot(1, 3, 1)
ax2 = fig.add_subplot(1, 3, 2)
ax3 = fig.add_subplot(1, 3, 3)

sns.heatmap(to_plot_mean_adjusted_run_time[names_part_num_20], cmap=sns.color_palette("bone"),  annot=True, ax=ax1)#, vmin=-0.01, vmax=2000)
plt.ylabel("Observations Per Epoch")
plt.xlabel("particle_count_Shard_count=S")

sns.heatmap(to_plot_mean_adjusted_run_time[names_part_num_100], cmap=sns.color_palette("bone"),  annot=True, ax=ax2)#, vmin=-0.01, vmax=2000)
plt.ylabel("Observations Per Epoch")
plt.xlabel("particle_count_Shard_count=S")

sns.heatmap(to_plot_mean_adjusted_run_time[names_part_num_1000], cmap=sns.color_palette("bone"),  annot=True, ax=ax3)#, vmin=-0.01, vmax=2000)
plt.ylabel("Observations Per Epoch")
plt.xlabel("particle_count_Shard_count=S")

plt.show()

fig = plt.figure(figsize=(20,5))
ax1 = fig.add_subplot(1, 3, 1)
ax2 = fig.add_subplot(1, 3, 2)
ax3 = fig.add_subplot(1, 3, 3)

sns.heatmap(to_plot_std_adjusted_run_time_err[names_part_num_20], cmap=sns.color_palette("bone"),  annot=True, ax=ax1)#, vmin=0.001, vmax=0.01)
plt.ylabel("Observations Per Epoch")
plt.xlabel("particle_count_Shard_count=S")

sns.heatmap(to_plot_std_adjusted_run_time_err[names_part_num_100], cmap=sns.color_palette("bone"),  annot=True, ax=ax2)#, vmin=0.001, vmax=0.01)
plt.ylabel("Observations Per Epoch")
plt.xlabel("particle_count_Shard_count=S")

sns.heatmap(to_plot_std_adjusted_run_time_err[names_part_num_1000], cmap=sns.color_palette("bone"),  annot=True, ax=ax3)#, vmin=0.001, vmax=0.01)
plt.ylabel("Observations Per Epoch")
plt.xlabel("particle_count_Shard_count=S")

plt.show()

# %% [markdown]
# ### p = 8

# %%
################################
#            Mean
################################
path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_adjusted_run_time_plot_data_8_x_20_1000_x_150_1200_x_3.csv"
Xy_N_6000_hm_mean_adjusted_run_time_plot_data_8_x_20_1000_x_150_1200_x_3=pd.read_csv(path)

path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_adjusted_run_time_plot_data_8_x_20_1000_x_150_1200_x_6.csv"
Xy_N_6000_hm_mean_adjusted_run_time_plot_data_8_x_20_1000_x_150_1200_x_6=pd.read_csv(path)

path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_adjusted_run_time_plot_data_8_x_20_1000_x_150_1200_x_10.csv"
Xy_N_6000_hm_mean_adjusted_run_time_plot_data_8_x_20_1000_x_150_1200_x_10=pd.read_csv(path)

path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_adjusted_run_time_plot_data_8_x_20_1000_x_150_1200_x_15.csv"
Xy_N_6000_hm_mean_adjusted_run_time_plot_data_8_x_20_1000_x_150_1200_x_15=pd.read_csv(path)

path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_adjusted_run_time_plot_data_8_x_20_1000_x_150_1200_x_30.csv"
Xy_N_6000_hm_mean_adjusted_run_time_plot_data_8_x_20_1000_x_150_1200_x_30=pd.read_csv(path)

joined_mean_adjusted_run_time = Xy_N_6000_hm_mean_adjusted_run_time_plot_data_8_x_20_1000_x_150_1200_x_3.join(
    Xy_N_6000_hm_mean_adjusted_run_time_plot_data_8_x_20_1000_x_150_1200_x_6, how='left',  rsuffix='_S=6').join(
    Xy_N_6000_hm_mean_adjusted_run_time_plot_data_8_x_20_1000_x_150_1200_x_10, how='left', rsuffix='_S=10').join(
    Xy_N_6000_hm_mean_adjusted_run_time_plot_data_8_x_20_1000_x_150_1200_x_15, how='left', rsuffix='_S=15').join(
    Xy_N_6000_hm_mean_adjusted_run_time_plot_data_8_x_20_1000_x_150_1200_x_30, how='left', rsuffix='_S=30'
)
joined_mean_adjusted_run_time.set_index("index", inplace=True)
to_plot_mean_adjusted_run_time = joined_mean_adjusted_run_time[old_names]
to_plot_mean_adjusted_run_time.columns = new_names
plt.figure(figsize=(20,5))
sns.heatmap(to_plot_mean_adjusted_run_time[new_names], cmap=sns.color_palette("bone"),  annot=True)
plt.ylabel("Observations Per Epoch")
plt.xlabel("particle_count_Shard_count=S")
plt.title('Mean Run Time')

plt.show()

################################
#            Std
################################

path = "experiment_results/heat_map_data/Xy_N_6000_hm_std_adjusted_run_time_plot_data_8_x_20_1000_x_150_1200_x_3.csv"
Xy_N_6000_hm_std_adjusted_run_time_plot_data_8_x_20_1000_x_150_1200_x_3=pd.read_csv(path)

path = "experiment_results/heat_map_data/Xy_N_6000_hm_std_adjusted_run_time_plot_data_8_x_20_1000_x_150_1200_x_6.csv"
Xy_N_6000_hm_std_adjusted_run_time_plot_data_8_x_20_1000_x_150_1200_x_6=pd.read_csv(path)

path = "experiment_results/heat_map_data/Xy_N_6000_hm_std_adjusted_run_time_plot_data_8_x_20_1000_x_150_1200_x_10.csv"
Xy_N_6000_hm_std_adjusted_run_time_plot_data_8_x_20_1000_x_150_1200_x_10=pd.read_csv(path)

path = "experiment_results/heat_map_data/Xy_N_6000_hm_std_adjusted_run_time_plot_data_8_x_20_1000_x_150_1200_x_15.csv"
Xy_N_6000_hm_std_adjusted_run_time_plot_data_8_x_20_1000_x_150_1200_x_15=pd.read_csv(path)

path = "experiment_results/heat_map_data/Xy_N_6000_hm_std_adjusted_run_time_plot_data_8_x_20_1000_x_150_1200_x_30.csv"
Xy_N_6000_hm_std_adjusted_run_time_plot_data_8_x_20_1000_x_150_1200_x_30=pd.read_csv(path)

joined_std_adjusted_run_time_err = Xy_N_6000_hm_std_adjusted_run_time_plot_data_8_x_20_1000_x_150_1200_x_3.join(
    Xy_N_6000_hm_std_adjusted_run_time_plot_data_8_x_20_1000_x_150_1200_x_6, how='left',  rsuffix='_S=6').join(
    Xy_N_6000_hm_std_adjusted_run_time_plot_data_8_x_20_1000_x_150_1200_x_10, how='left', rsuffix='_S=10').join(
    Xy_N_6000_hm_std_adjusted_run_time_plot_data_8_x_20_1000_x_150_1200_x_15, how='left', rsuffix='_S=15').join(
    Xy_N_6000_hm_std_adjusted_run_time_plot_data_8_x_20_1000_x_150_1200_x_30, how='left', rsuffix='_S=30'
)
joined_std_adjusted_run_time_err.set_index("index", inplace=True)
to_plot_std_adjusted_run_time_err = joined_std_adjusted_run_time_err[old_names]
to_plot_std_adjusted_run_time_err.columns = new_names
plt.figure(figsize=(20,5))

sns.heatmap(to_plot_std_adjusted_run_time_err[new_names], cmap=sns.color_palette("bone"),  annot=True)
plt.ylabel("Observations Per Epoch")
plt.xlabel("particle_count_Shard_count=S")
plt.title('Standard Error')
plt.show()

fig = plt.figure(figsize=(20,5))
ax1 = fig.add_subplot(1, 3, 1)
ax2 = fig.add_subplot(1, 3, 2)
ax3 = fig.add_subplot(1, 3, 3)

sns.heatmap(to_plot_mean_adjusted_run_time[names_part_num_20], cmap=sns.color_palette("bone"),  annot=True, ax=ax1,)# vmin=-0.01, vmax=0.03)
plt.ylabel("Observations Per Epoch")
plt.xlabel("particle_count_Shard_count=S")

sns.heatmap(to_plot_mean_adjusted_run_time[names_part_num_100], cmap=sns.color_palette("bone"),  annot=True, ax=ax2,)# vmin=-0.01, vmax=0.03)
plt.ylabel("Observations Per Epoch")
plt.xlabel("particle_count_Shard_count=S")

sns.heatmap(to_plot_mean_adjusted_run_time[names_part_num_1000], cmap=sns.color_palette("bone"),  annot=True, ax=ax3,)# vmin=-0.01, vmax=0.03)
plt.ylabel("Observations Per Epoch")
plt.xlabel("particle_count_Shard_count=S")

plt.show()

fig = plt.figure(figsize=(20,5))
ax1 = fig.add_subplot(1, 3, 1)
ax2 = fig.add_subplot(1, 3, 2)
ax3 = fig.add_subplot(1, 3, 3)

sns.heatmap(to_plot_std_adjusted_run_time_err[names_part_num_20], cmap=sns.color_palette("bone"),  annot=True, ax=ax1,)# vmin=0.001, vmax=0.01)
plt.ylabel("Observations Per Epoch")
plt.xlabel("particle_count_Shard_count=S")

sns.heatmap(to_plot_std_adjusted_run_time_err[names_part_num_100], cmap=sns.color_palette("bone"),  annot=True, ax=ax2,)# vmin=0.001, vmax=0.01)
plt.ylabel("Observations Per Epoch")
plt.xlabel("particle_count_Shard_count=S")

sns.heatmap(to_plot_std_adjusted_run_time_err[names_part_num_1000], cmap=sns.color_palette("bone"),  annot=True, ax=ax3,)# vmin=0.001, vmax=0.01)
plt.ylabel("Observations Per Epoch")
plt.xlabel("particle_count_Shard_count=S")

plt.show()

# %%
### p = 16

# %%
################################
#            Mean
################################
path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_adjusted_run_time_plot_data_16_x_20_1000_x_150_1200_x_3.csv"
Xy_N_6000_hm_mean_adjusted_run_time_plot_data_16_x_20_1000_x_150_1200_x_3=pd.read_csv(path)

path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_adjusted_run_time_plot_data_16_x_20_1000_x_150_1200_x_6.csv"
Xy_N_6000_hm_mean_adjusted_run_time_plot_data_16_x_20_1000_x_150_1200_x_6=pd.read_csv(path)

path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_adjusted_run_time_plot_data_16_x_20_1000_x_150_1200_x_10.csv"
Xy_N_6000_hm_mean_adjusted_run_time_plot_data_16_x_20_1000_x_150_1200_x_10=pd.read_csv(path)

path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_adjusted_run_time_plot_data_16_x_20_1000_x_150_1200_x_15.csv"
Xy_N_6000_hm_mean_adjusted_run_time_plot_data_16_x_20_1000_x_150_1200_x_15=pd.read_csv(path)

path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_adjusted_run_time_plot_data_16_x_20_1000_x_150_1200_x_30.csv"
Xy_N_6000_hm_mean_adjusted_run_time_plot_data_16_x_20_1000_x_150_1200_x_30=pd.read_csv(path)

joined_mean_adjusted_run_time = Xy_N_6000_hm_mean_adjusted_run_time_plot_data_16_x_20_1000_x_150_1200_x_3.join(
    Xy_N_6000_hm_mean_adjusted_run_time_plot_data_16_x_20_1000_x_150_1200_x_6, how='left',  rsuffix='_S=6').join(
    Xy_N_6000_hm_mean_adjusted_run_time_plot_data_16_x_20_1000_x_150_1200_x_10, how='left', rsuffix='_S=10').join(
    Xy_N_6000_hm_mean_adjusted_run_time_plot_data_16_x_20_1000_x_150_1200_x_15, how='left', rsuffix='_S=15').join(
    Xy_N_6000_hm_mean_adjusted_run_time_plot_data_16_x_20_1000_x_150_1200_x_30, how='left', rsuffix='_S=30'
)
joined_mean_adjusted_run_time.set_index("index", inplace=True)
to_plot_mean_adjusted_run_time = joined_mean_adjusted_run_time[old_names]
to_plot_mean_adjusted_run_time.columns = new_names
plt.figure(figsize=(20,5))
sns.heatmap(to_plot_mean_adjusted_run_time[new_names], cmap=sns.color_palette("bone"),  annot=True)
plt.ylabel("Observations Per Epoch")
plt.xlabel("particle_count_Shard_count=S")
plt.title('Mean Run Time')

plt.show()

################################
#            Std
################################

path = "experiment_results/heat_map_data/Xy_N_6000_hm_std_adjusted_run_time_plot_data_16_x_20_1000_x_150_1200_x_3.csv"
Xy_N_6000_hm_std_adjusted_run_time_plot_data_16_x_20_1000_x_150_1200_x_3=pd.read_csv(path)

path = "experiment_results/heat_map_data/Xy_N_6000_hm_std_adjusted_run_time_plot_data_16_x_20_1000_x_150_1200_x_6.csv"
Xy_N_6000_hm_std_adjusted_run_time_plot_data_16_x_20_1000_x_150_1200_x_6=pd.read_csv(path)

path = "experiment_results/heat_map_data/Xy_N_6000_hm_std_adjusted_run_time_plot_data_16_x_20_1000_x_150_1200_x_10.csv"
Xy_N_6000_hm_std_adjusted_run_time_plot_data_16_x_20_1000_x_150_1200_x_10=pd.read_csv(path)

path = "experiment_results/heat_map_data/Xy_N_6000_hm_std_adjusted_run_time_plot_data_16_x_20_1000_x_150_1200_x_15.csv"
Xy_N_6000_hm_std_adjusted_run_time_plot_data_16_x_20_1000_x_150_1200_x_15=pd.read_csv(path)

path = "experiment_results/heat_map_data/Xy_N_6000_hm_std_adjusted_run_time_plot_data_16_x_20_1000_x_150_1200_x_30.csv"
Xy_N_6000_hm_std_adjusted_run_time_plot_data_16_x_20_1000_x_150_1200_x_30=pd.read_csv(path)

joined_std_adjusted_run_time_err = Xy_N_6000_hm_std_adjusted_run_time_plot_data_16_x_20_1000_x_150_1200_x_3.join(
    Xy_N_6000_hm_std_adjusted_run_time_plot_data_16_x_20_1000_x_150_1200_x_6, how='left',  rsuffix='_S=6').join(
    Xy_N_6000_hm_std_adjusted_run_time_plot_data_16_x_20_1000_x_150_1200_x_10, how='left', rsuffix='_S=10').join(
    Xy_N_6000_hm_std_adjusted_run_time_plot_data_16_x_20_1000_x_150_1200_x_15, how='left', rsuffix='_S=15').join(
    Xy_N_6000_hm_std_adjusted_run_time_plot_data_16_x_20_1000_x_150_1200_x_30, how='left', rsuffix='_S=30'
)
joined_std_adjusted_run_time_err.set_index("index", inplace=True)
to_plot_std_adjusted_run_time_err = joined_std_adjusted_run_time_err[old_names]
to_plot_std_adjusted_run_time_err.columns = new_names
plt.figure(figsize=(20,5))

sns.heatmap(to_plot_std_adjusted_run_time_err[new_names], cmap=sns.color_palette("bone"),  annot=True)
plt.ylabel("Observations Per Epoch")
plt.xlabel("particle_count_Shard_count=S")
plt.title('Standard Error')
plt.show()

fig = plt.figure(figsize=(20,5))
ax1 = fig.add_subplot(1, 3, 1)
ax2 = fig.add_subplot(1, 3, 2)
ax3 = fig.add_subplot(1, 3, 3)

sns.heatmap(to_plot_mean_adjusted_run_time[names_part_num_20], cmap=sns.color_palette("bone"),  annot=True, ax=ax1,)# vmin=-0.01, vmax=0.03)
plt.ylabel("Observations Per Epoch")
plt.xlabel("particle_count_Shard_count=S")

sns.heatmap(to_plot_mean_adjusted_run_time[names_part_num_100], cmap=sns.color_palette("bone"),  annot=True, ax=ax2,)# vmin=-0.01, vmax=0.03)
plt.ylabel("Observations Per Epoch")
plt.xlabel("particle_count_Shard_count=S")

sns.heatmap(to_plot_mean_adjusted_run_time[names_part_num_1000], cmap=sns.color_palette("bone"),  annot=True, ax=ax3,)# vmin=-0.01, vmax=0.03)
plt.ylabel("Observations Per Epoch")
plt.xlabel("particle_count_Shard_count=S")

plt.show()

fig = plt.figure(figsize=(20,5))
ax1 = fig.add_subplot(1, 3, 1)
ax2 = fig.add_subplot(1, 3, 2)
ax3 = fig.add_subplot(1, 3, 3)

sns.heatmap(to_plot_std_adjusted_run_time_err[names_part_num_20], cmap=sns.color_palette("bone"),  annot=True, ax=ax1,)# vmin=0.001, vmax=0.01)
plt.ylabel("Observations Per Epoch")
plt.xlabel("particle_count_Shard_count=S")

sns.heatmap(to_plot_std_adjusted_run_time_err[names_part_num_100], cmap=sns.color_palette("bone"),  annot=True, ax=ax2,)# vmin=0.001, vmax=0.01)
plt.ylabel("Observations Per Epoch")
plt.xlabel("particle_count_Shard_count=S")

sns.heatmap(to_plot_std_adjusted_run_time_err[names_part_num_1000], cmap=sns.color_palette("bone"),  annot=True, ax=ax3,)# vmin=0.001, vmax=0.01)
plt.ylabel("Observations Per Epoch")
plt.xlabel("particle_count_Shard_count=S")

plt.show()

# %% [markdown]
# ### p = 32

# %%
################################
#            Mean
################################
path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_adjusted_run_time_plot_data_32_x_20_1000_x_150_1200_x_3.csv"
Xy_N_6000_hm_mean_adjusted_run_time_plot_data_32_x_20_1000_x_150_1200_x_3=pd.read_csv(path)

path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_adjusted_run_time_plot_data_32_x_20_1000_x_150_1200_x_6.csv"
Xy_N_6000_hm_mean_adjusted_run_time_plot_data_32_x_20_1000_x_150_1200_x_6=pd.read_csv(path)

path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_adjusted_run_time_plot_data_32_x_20_1000_x_150_1200_x_10.csv"
Xy_N_6000_hm_mean_adjusted_run_time_plot_data_32_x_20_1000_x_150_1200_x_10=pd.read_csv(path)

path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_adjusted_run_time_plot_data_32_x_20_1000_x_150_1200_x_15.csv"
Xy_N_6000_hm_mean_adjusted_run_time_plot_data_32_x_20_1000_x_150_1200_x_15=pd.read_csv(path)

path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_adjusted_run_time_plot_data_32_x_20_1000_x_150_1200_x_30.csv"
Xy_N_6000_hm_mean_adjusted_run_time_plot_data_32_x_20_1000_x_150_1200_x_30=pd.read_csv(path)

joined_mean_adjusted_run_time = Xy_N_6000_hm_mean_adjusted_run_time_plot_data_32_x_20_1000_x_150_1200_x_3.join(
    Xy_N_6000_hm_mean_adjusted_run_time_plot_data_32_x_20_1000_x_150_1200_x_6, how='left',  rsuffix='_S=6').join(
    Xy_N_6000_hm_mean_adjusted_run_time_plot_data_32_x_20_1000_x_150_1200_x_10, how='left', rsuffix='_S=10').join(
    Xy_N_6000_hm_mean_adjusted_run_time_plot_data_32_x_20_1000_x_150_1200_x_15, how='left', rsuffix='_S=15').join(
    Xy_N_6000_hm_mean_adjusted_run_time_plot_data_32_x_20_1000_x_150_1200_x_30, how='left', rsuffix='_S=30'
)
joined_mean_adjusted_run_time.set_index("index", inplace=True)
to_plot_mean_adjusted_run_time = joined_mean_adjusted_run_time[old_names]
to_plot_mean_adjusted_run_time.columns = new_names
plt.figure(figsize=(20,5))
sns.heatmap(to_plot_mean_adjusted_run_time[new_names], cmap=sns.color_palette("bone"),  annot=True)
plt.ylabel("Observations Per Epoch")
plt.xlabel("particle_count_Shard_count=S")
plt.title('Mean Run Time')

plt.show()

################################
#            Std
################################

path = "experiment_results/heat_map_data/Xy_N_6000_hm_std_adjusted_run_time_plot_data_32_x_20_1000_x_150_1200_x_3.csv"
Xy_N_6000_hm_std_adjusted_run_time_plot_data_32_x_20_1000_x_150_1200_x_3=pd.read_csv(path)

path = "experiment_results/heat_map_data/Xy_N_6000_hm_std_adjusted_run_time_plot_data_32_x_20_1000_x_150_1200_x_6.csv"
Xy_N_6000_hm_std_adjusted_run_time_plot_data_32_x_20_1000_x_150_1200_x_6=pd.read_csv(path)

path = "experiment_results/heat_map_data/Xy_N_6000_hm_std_adjusted_run_time_plot_data_32_x_20_1000_x_150_1200_x_10.csv"
Xy_N_6000_hm_std_adjusted_run_time_plot_data_32_x_20_1000_x_150_1200_x_10=pd.read_csv(path)

path = "experiment_results/heat_map_data/Xy_N_6000_hm_std_adjusted_run_time_plot_data_32_x_20_1000_x_150_1200_x_15.csv"
Xy_N_6000_hm_std_adjusted_run_time_plot_data_32_x_20_1000_x_150_1200_x_15=pd.read_csv(path)

path = "experiment_results/heat_map_data/Xy_N_6000_hm_std_adjusted_run_time_plot_data_32_x_20_1000_x_150_1200_x_30.csv"
Xy_N_6000_hm_std_adjusted_run_time_plot_data_32_x_20_1000_x_150_1200_x_30=pd.read_csv(path)

joined_std_adjusted_run_time_err = Xy_N_6000_hm_std_adjusted_run_time_plot_data_32_x_20_1000_x_150_1200_x_3.join(
    Xy_N_6000_hm_std_adjusted_run_time_plot_data_32_x_20_1000_x_150_1200_x_6, how='left',  rsuffix='_S=6').join(
    Xy_N_6000_hm_std_adjusted_run_time_plot_data_32_x_20_1000_x_150_1200_x_10, how='left', rsuffix='_S=10').join(
    Xy_N_6000_hm_std_adjusted_run_time_plot_data_32_x_20_1000_x_150_1200_x_15, how='left', rsuffix='_S=15').join(
    Xy_N_6000_hm_std_adjusted_run_time_plot_data_32_x_20_1000_x_150_1200_x_30, how='left', rsuffix='_S=30'
)
joined_std_adjusted_run_time_err.set_index("index", inplace=True)
to_plot_std_adjusted_run_time_err = joined_std_adjusted_run_time_err[old_names]
to_plot_std_adjusted_run_time_err.columns = new_names
plt.figure(figsize=(20,5))

sns.heatmap(to_plot_std_adjusted_run_time_err[new_names], cmap=sns.color_palette("bone"),  annot=True)
plt.ylabel("Observations Per Epoch")
plt.xlabel("particle_count_Shard_count=S")
plt.title('Standard Error')
plt.show()

fig = plt.figure(figsize=(20,5))
ax1 = fig.add_subplot(1, 3, 1)
ax2 = fig.add_subplot(1, 3, 2)
ax3 = fig.add_subplot(1, 3, 3)

sns.heatmap(to_plot_mean_adjusted_run_time[names_part_num_20], cmap=sns.color_palette("bone"),  annot=True, ax=ax1,)# vmin=0, vmax=8000)
plt.ylabel("Observations Per Epoch")
plt.xlabel("particle_count_Shard_count=S")

sns.heatmap(to_plot_mean_adjusted_run_time[names_part_num_100], cmap=sns.color_palette("bone"),  annot=True, ax=ax2,)# vmin=0, vmax=8000)
plt.ylabel("Observations Per Epoch")
plt.xlabel("particle_count_Shard_count=S")

sns.heatmap(to_plot_mean_adjusted_run_time[names_part_num_1000], cmap=sns.color_palette("bone"),  annot=True, ax=ax3,)# vmin=0, vmax=8000)
plt.ylabel("Observations Per Epoch")
plt.xlabel("particle_count_Shard_count=S")

plt.show()

fig = plt.figure(figsize=(20,5))
ax1 = fig.add_subplot(1, 3, 1)
ax2 = fig.add_subplot(1, 3, 2)
ax3 = fig.add_subplot(1, 3, 3)

sns.heatmap(to_plot_std_adjusted_run_time_err[names_part_num_20], cmap=sns.color_palette("bone"),  annot=True, ax=ax1,)# vmin=0.001, vmax=0.01)
plt.ylabel("Observations Per Epoch")
plt.xlabel("particle_count_Shard_count=S")

sns.heatmap(to_plot_std_adjusted_run_time_err[names_part_num_100], cmap=sns.color_palette("bone"),  annot=True, ax=ax2,)# vmin=0.001, vmax=0.01)
plt.ylabel("Observations Per Epoch")
plt.xlabel("particle_count_Shard_count=S")

sns.heatmap(to_plot_std_adjusted_run_time_err[names_part_num_1000], cmap=sns.color_palette("bone"),  annot=True, ax=ax3,)# vmin=0.001, vmax=0.01)
plt.ylabel("Observations Per Epoch")
plt.xlabel("particle_count_Shard_count=S")

plt.show()

# %%
path = "experiment_results/heat_map_data/Xy_N_6000_hm_std_adjusted_run_time_plot_data_32_x_20_1000_x_30_x_3.csv"
Xy_N_6000_hm_std_adjusted_run_time_plot_data_32_x_20_1000_x_30_x_3=pd.read_csv(path)

# %%
Xy_N_6000_hm_std_adjusted_run_time_plot_data_32_x_20_1000_x_30_x_3
# Out:
#    20  100  1000  index
# 0 NaN  NaN   NaN     30
