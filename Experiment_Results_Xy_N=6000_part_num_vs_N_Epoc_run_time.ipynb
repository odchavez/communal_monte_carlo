# %%
import analysis_functions as af
import pandas as pd
import numpy as np
import re
import pickle
import matplotlib.pyplot as plt
import seaborn as sns

# %%
old_names = [
    '20',
    '100',
    '1000',
    '20_S=6',
    '100_S=6',
    '1000_S=6',
    '20_S=10',
    '100_S=10',
    '1000_S=10',
    '20_S=15',
    '100_S=15',
    '1000_S=15',
    '20_S=30',
    '100_S=30',
    '1000_S=30',
]
new_names = [
    '20_S=3',
    '100_S=3',
    '1000_S=3',
    '20_S=6',
    '100_S=6',
    '1000_S=6',
    '20_S=10',
    '100_S=10',
    '1000_S=10',
    '20_S=15',
    '100_S=15',
    '1000_S=15',
    '20_S=30',
    '100_S=30',
    '1000_S=30',
]
names_part_num_20 = [
    '20_S=3',
    '20_S=6',
    '20_S=10',
    '20_S=15',
    '20_S=30',
    '20_S=60',
]
names_part_num_100 = [
    '100_S=3',
    '100_S=6',
    '100_S=10',
    '100_S=15',
    '100_S=30',
    '100_S=60',
]
names_part_num_1000 = [
    '1000_S=3',
    '1000_S=6',
    '1000_S=10',
    '1000_S=15',
    '1000_S=30',
    '1000_S=60',
]

# %% [markdown]
# ### p = 2

# %%
################################
#            Mean
################################
Xy_N_6000_hm_mean_run_time_plot_data_2_x_20_1000_x_30_x_3_30 = pd.DataFrame([np.zeros(15)], index = [30])
Xy_N_6000_hm_mean_run_time_plot_data_2_x_20_1000_x_30_x_3_30.columns = new_names


path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_run_time_plot_data_2_x_20_x_30_x_3.csv"
Xy_N_6000_hm_mean_run_time_plot_data_2_x_20_1000_x_30_x_3_30.loc[30,['20_S=3']]=pd.read_csv(path).loc[0,'20']
path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_run_time_plot_data_2_x_20_x_30_x_6.csv"
Xy_N_6000_hm_mean_run_time_plot_data_2_x_20_1000_x_30_x_3_30.loc[30,['20_S=6']]=pd.read_csv(path).loc[0,'20']
path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_run_time_plot_data_2_x_20_x_30_x_10.csv"
Xy_N_6000_hm_mean_run_time_plot_data_2_x_20_1000_x_30_x_3_30.loc[30,['20_S=10']]=pd.read_csv(path).loc[0,'20']
path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_run_time_plot_data_2_x_20_x_30_x_15.csv"
Xy_N_6000_hm_mean_run_time_plot_data_2_x_20_1000_x_30_x_3_30.loc[30,['20_S=15']]=pd.read_csv(path).loc[0,'20']
path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_run_time_plot_data_2_x_20_x_30_x_30.csv"
Xy_N_6000_hm_mean_run_time_plot_data_2_x_20_1000_x_30_x_3_30.loc[30,['20_S=30']]=pd.read_csv(path).loc[0,'20']

path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_run_time_plot_data_2_x_100_x_30_x_3.csv"
Xy_N_6000_hm_mean_run_time_plot_data_2_x_20_1000_x_30_x_3_30.loc[30,['100_S=3']]=pd.read_csv(path).loc[0,'100']
path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_run_time_plot_data_2_x_100_x_30_x_6.csv"
Xy_N_6000_hm_mean_run_time_plot_data_2_x_20_1000_x_30_x_3_30.loc[30,['100_S=6']]=pd.read_csv(path).loc[0,'100']
path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_run_time_plot_data_2_x_100_x_30_x_10.csv"
Xy_N_6000_hm_mean_run_time_plot_data_2_x_20_1000_x_30_x_3_30.loc[30,['100_S=10']]=pd.read_csv(path).loc[0,'100']
path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_run_time_plot_data_2_x_100_x_30_x_15.csv"
Xy_N_6000_hm_mean_run_time_plot_data_2_x_20_1000_x_30_x_3_30.loc[30,['100_S=15']]=pd.read_csv(path).loc[0,'100']
path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_run_time_plot_data_2_x_100_x_30_x_30.csv"
Xy_N_6000_hm_mean_run_time_plot_data_2_x_20_1000_x_30_x_3_30.loc[30,['100_S=30']]=pd.read_csv(path).loc[0,'100']

path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_run_time_plot_data_2_x_1000_x_30_x_3.csv"
Xy_N_6000_hm_mean_run_time_plot_data_2_x_20_1000_x_30_x_3_30.loc[30,['1000_S=3']]=pd.read_csv(path).loc[0,'1000']
path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_run_time_plot_data_2_x_1000_x_30_x_6.csv"
Xy_N_6000_hm_mean_run_time_plot_data_2_x_20_1000_x_30_x_3_30.loc[30,['1000_S=6']]=pd.read_csv(path).loc[0,'1000']
path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_run_time_plot_data_2_x_1000_x_30_x_10.csv"
Xy_N_6000_hm_mean_run_time_plot_data_2_x_20_1000_x_30_x_3_30.loc[30,['1000_S=10']]=pd.read_csv(path).loc[0,'1000']
path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_run_time_plot_data_2_x_1000_x_30_x_15.csv"
Xy_N_6000_hm_mean_run_time_plot_data_2_x_20_1000_x_30_x_3_30.loc[30,['1000_S=15']]=pd.read_csv(path).loc[0,'1000']
path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_run_time_plot_data_2_x_1000_x_30_x_30.csv"
Xy_N_6000_hm_mean_run_time_plot_data_2_x_20_1000_x_30_x_3_30.loc[30,['1000_S=30']]=pd.read_csv(path).loc[0,'1000']


path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_run_time_plot_data_2_x_20_1000_x_150_1200_x_3.csv"
Xy_N_6000_hm_mean_run_time_plot_data_2_x_20_1000_x_150_1200_x_3=pd.read_csv(path)

path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_run_time_plot_data_2_x_20_1000_x_150_1200_x_6.csv"
Xy_N_6000_hm_mean_run_time_plot_data_2_x_20_1000_x_150_1200_x_6=pd.read_csv(path)


path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_run_time_plot_data_2_x_20_1000_x_150_1200_x_10.csv"
Xy_N_6000_hm_mean_run_time_plot_data_2_x_20_1000_x_150_1200_x_10=pd.read_csv(path)


path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_run_time_plot_data_2_x_20_1000_x_150_1200_x_15.csv"
Xy_N_6000_hm_mean_run_time_plot_data_2_x_20_1000_x_150_1200_x_15=pd.read_csv(path)


path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_run_time_plot_data_2_x_20_1000_x_150_1200_x_30.csv"
Xy_N_6000_hm_mean_run_time_plot_data_2_x_20_1000_x_150_1200_x_30=pd.read_csv(path)

path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_total_run_time_plot_data_2_x_20_1000_x_30_1200_x_60.csv"
print(pd.read_csv(path))
Xy_N_6000_hm_mean_run_time_plot_data_2_x_20_1000_x_30_1200_x_60=pd.read_csv(path)
Xy_N_6000_hm_mean_run_time_plot_data_2_x_20_1000_x_30_1200_x_60.set_index("index", inplace=True)
Xy_N_6000_hm_mean_run_time_plot_data_2_x_20_1000_x_30_1200_x_60.columns = ['20_S=60','100_S=60','1000_S=60']

joined_mean_run_time = Xy_N_6000_hm_mean_run_time_plot_data_2_x_20_1000_x_150_1200_x_3.join(
    Xy_N_6000_hm_mean_run_time_plot_data_2_x_20_1000_x_150_1200_x_6, how='left',  rsuffix='_S=6').join(
    Xy_N_6000_hm_mean_run_time_plot_data_2_x_20_1000_x_150_1200_x_10, how='left', rsuffix='_S=10').join(
    Xy_N_6000_hm_mean_run_time_plot_data_2_x_20_1000_x_150_1200_x_15, how='left', rsuffix='_S=15').join(
    Xy_N_6000_hm_mean_run_time_plot_data_2_x_20_1000_x_150_1200_x_30, how='left', rsuffix='_S=30'
)
joined_mean_run_time.set_index("index", inplace=True)
to_plot_mean_run_time = joined_mean_run_time[old_names]
to_plot_mean_run_time.columns = new_names

to_plot_mean_run_time = pd.concat([Xy_N_6000_hm_mean_run_time_plot_data_2_x_20_1000_x_30_x_3_30, to_plot_mean_run_time])

to_plot_mean_run_time = to_plot_mean_run_time.join(Xy_N_6000_hm_mean_run_time_plot_data_2_x_20_1000_x_30_1200_x_60,  how='left')

plt.figure(figsize=(20,5))
sns.heatmap(
    to_plot_mean_run_time, 
    cmap=sns.color_palette("bone"),
    annot=True
)
plt.ylabel("Observations Per Epoch")
plt.xlabel("particle_count_Shard_count=S")
plt.title('Mean Run Time')

plt.show()

################################
#            Std
################################
path = "experiment_results/heat_map_data/Xy_N_6000_hm_std_run_time_plot_data_2_x_20_1000_x_30_x_3.csv"
Xy_N_6000_hm_std_run_time_plot_data_2_x_20_1000_x_30_x_3=pd.read_csv(path)

path = "experiment_results/heat_map_data/Xy_N_6000_hm_std_run_time_plot_data_2_x_20_1000_x_30_x_6.csv"
Xy_N_6000_hm_std_run_time_plot_data_2_x_20_1000_x_30_x_6=pd.read_csv(path)

path = "experiment_results/heat_map_data/Xy_N_6000_hm_std_run_time_plot_data_2_x_20_1000_x_30_x_10.csv"
Xy_N_6000_hm_std_run_time_plot_data_2_x_20_1000_x_30_x_10=pd.read_csv(path)

path = "experiment_results/heat_map_data/Xy_N_6000_hm_std_run_time_plot_data_2_x_20_1000_x_30_x_15.csv"
Xy_N_6000_hm_std_run_time_plot_data_2_x_20_1000_x_30_x_15=pd.read_csv(path)

path = "experiment_results/heat_map_data/Xy_N_6000_hm_std_plot_data_2_x_20_1000_x_30_x_30.csv"
Xy_N_6000_hm_std_run_time_plot_data_2_x_20_1000_x_30_x_30=pd.read_csv(path)

Xy_N_6000_hm_std_run_time_plot_data_2_x_20_1000_x_30_x_3_30 = Xy_N_6000_hm_std_run_time_plot_data_2_x_20_1000_x_30_x_3.join(
    Xy_N_6000_hm_std_run_time_plot_data_2_x_20_1000_x_30_x_6, how='left',  rsuffix='_S=6').join(
    Xy_N_6000_hm_std_run_time_plot_data_2_x_20_1000_x_30_x_10, how='left', rsuffix='_S=10').join(
    Xy_N_6000_hm_std_run_time_plot_data_2_x_20_1000_x_30_x_15, how='left', rsuffix='_S=15').join(
    Xy_N_6000_hm_std_run_time_plot_data_2_x_20_1000_x_30_x_30, how='left', rsuffix='_S=30'
)

path = "experiment_results/heat_map_data/Xy_N_6000_hm_std_run_time_plot_data_2_x_20_1000_x_150_1200_x_3.csv"
Xy_N_6000_hm_std_run_time_plot_data_2_x_20_1000_x_150_1200_x_3=pd.read_csv(path)

path = "experiment_results/heat_map_data/Xy_N_6000_hm_std_run_time_plot_data_2_x_20_1000_x_150_1200_x_6.csv"
Xy_N_6000_hm_std_run_time_plot_data_2_x_20_1000_x_150_1200_x_6=pd.read_csv(path)

path = "experiment_results/heat_map_data/Xy_N_6000_hm_std_run_time_plot_data_2_x_20_1000_x_150_1200_x_10.csv"
Xy_N_6000_hm_std_run_time_plot_data_2_x_20_1000_x_150_1200_x_10=pd.read_csv(path)

path = "experiment_results/heat_map_data/Xy_N_6000_hm_std_run_time_plot_data_2_x_20_1000_x_150_1200_x_15.csv"
Xy_N_6000_hm_std_run_time_plot_data_2_x_20_1000_x_150_1200_x_15=pd.read_csv(path)

path = "experiment_results/heat_map_data/Xy_N_6000_hm_std_run_time_plot_data_2_x_20_1000_x_150_1200_x_30.csv"
Xy_N_6000_hm_std_run_time_plot_data_2_x_20_1000_x_150_1200_x_30=pd.read_csv(path)

joined_std_run_time_err = Xy_N_6000_hm_std_run_time_plot_data_2_x_20_1000_x_150_1200_x_3.join(
    Xy_N_6000_hm_std_run_time_plot_data_2_x_20_1000_x_150_1200_x_6, how='left',  rsuffix='_S=6').join(
    Xy_N_6000_hm_std_run_time_plot_data_2_x_20_1000_x_150_1200_x_10, how='left', rsuffix='_S=10').join(
    Xy_N_6000_hm_std_run_time_plot_data_2_x_20_1000_x_150_1200_x_15, how='left', rsuffix='_S=15').join(
    Xy_N_6000_hm_std_run_time_plot_data_2_x_20_1000_x_150_1200_x_30, how='left', rsuffix='_S=30'
)

joined_std_run_time_err = pd.concat([Xy_N_6000_hm_std_run_time_plot_data_2_x_20_1000_x_30_x_3_30, joined_std_run_time_err])
joined_std_run_time_err.set_index("index", inplace=True)
to_plot_std_run_time_err = joined_std_run_time_err[old_names]
to_plot_std_run_time_err.columns = new_names
plt.figure(figsize=(20,5))

sns.heatmap(to_plot_std_run_time_err[new_names], cmap=sns.color_palette("bone"),  annot=True)
plt.ylabel("Observations Per Epoch")
plt.xlabel("particle_count_Shard_count=S")
plt.title('Standard Error')
plt.show()

fig = plt.figure(figsize=(20,5))
ax1 = fig.add_subplot(1, 3, 1)
ax2 = fig.add_subplot(1, 3, 2)
ax3 = fig.add_subplot(1, 3, 3)

sns.heatmap(to_plot_mean_run_time[names_part_num_20], cmap=sns.color_palette("bone"),  annot=True, ax=ax1,)# vmin=-0.01, vmax=0.03)
plt.ylabel("Observations Per Epoch")
plt.xlabel("particle_count_Shard_count=S")

sns.heatmap(to_plot_mean_run_time[names_part_num_100], cmap=sns.color_palette("bone"),  annot=True, ax=ax2,)# vmin=-0.01, vmax=0.03)
plt.ylabel("Observations Per Epoch")
plt.xlabel("particle_count_Shard_count=S")

sns.heatmap(to_plot_mean_run_time[names_part_num_1000], cmap=sns.color_palette("bone"),  annot=True, ax=ax3,)# vmin=-0.01, vmax=0.03)
plt.ylabel("Observations Per Epoch")
plt.xlabel("particle_count_Shard_count=S")

plt.show()

#fig = plt.figure(figsize=(20,5))
#ax1 = fig.add_subplot(1, 3, 1)
#ax2 = fig.add_subplot(1, 3, 2)
#ax3 = fig.add_subplot(1, 3, 3)
#
#sns.heatmap(to_plot_std_run_time_err[names_part_num_20], cmap=sns.color_palette("bone"),  annot=True, ax=ax1,)# vmin=0.001, vmax=0.01)
#plt.ylabel("Observations Per Epoch")
#plt.xlabel("particle_count_Shard_count=S")
#
#sns.heatmap(to_plot_std_run_time_err[names_part_num_100], cmap=sns.color_palette("bone"),  annot=True, ax=ax2,)# vmin=0.001, vmax=0.01)
#plt.ylabel("Observations Per Epoch")
#plt.xlabel("particle_count_Shard_count=S")
#
#sns.heatmap(to_plot_std_run_time_err[names_part_num_1000], cmap=sns.color_palette("bone"),  annot=True, ax=ax3,)# vmin=0.001, vmax=0.01)
#plt.ylabel("Observations Per Epoch")
#plt.xlabel("particle_count_Shard_count=S")
#
#plt.show()
# Out:
#            20         100         1000  index
# 0  264.642320  986.232467  9744.993174     30
# 1   75.642260  273.013331  2889.305797    150
# 2   50.270664  174.793030  1672.184985    300
# 3   37.389981  121.519337  1146.698633    600
# 4   29.965679   91.502118   872.599284   1200

# %% [markdown]
# ### p = 8

# %%
################################
#            Mean
################################
Xy_N_6000_hm_mean_run_time_plot_data_8_x_20_1000_x_30_x_3_30 = pd.DataFrame([np.zeros(15)], index = [30])
Xy_N_6000_hm_mean_run_time_plot_data_8_x_20_1000_x_30_x_3_30.columns = new_names


path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_run_time_plot_data_8_x_20_x_30_x_3.csv"
Xy_N_6000_hm_mean_run_time_plot_data_8_x_20_1000_x_30_x_3_30.loc[30,['20_S=3']]=pd.read_csv(path).loc[0,'20']
path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_run_time_plot_data_8_x_20_x_30_x_6.csv"
Xy_N_6000_hm_mean_run_time_plot_data_8_x_20_1000_x_30_x_3_30.loc[30,['20_S=6']]=pd.read_csv(path).loc[0,'20']
path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_run_time_plot_data_8_x_20_x_30_x_10.csv"
Xy_N_6000_hm_mean_run_time_plot_data_8_x_20_1000_x_30_x_3_30.loc[30,['20_S=10']]=pd.read_csv(path).loc[0,'20']
path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_run_time_plot_data_8_x_20_x_30_x_15.csv"
Xy_N_6000_hm_mean_run_time_plot_data_8_x_20_1000_x_30_x_3_30.loc[30,['20_S=15']]=pd.read_csv(path).loc[0,'20']
path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_run_time_plot_data_8_x_20_x_30_x_30.csv"
Xy_N_6000_hm_mean_run_time_plot_data_8_x_20_1000_x_30_x_3_30.loc[30,['20_S=30']]=pd.read_csv(path).loc[0,'20']

path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_run_time_plot_data_8_x_100_x_30_x_3.csv"
Xy_N_6000_hm_mean_run_time_plot_data_8_x_20_1000_x_30_x_3_30.loc[30,['100_S=3']]=pd.read_csv(path).loc[0,'100']
path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_run_time_plot_data_8_x_100_x_30_x_6.csv"
Xy_N_6000_hm_mean_run_time_plot_data_8_x_20_1000_x_30_x_3_30.loc[30,['100_S=6']]=pd.read_csv(path).loc[0,'100']
path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_run_time_plot_data_8_x_100_x_30_x_10.csv"
Xy_N_6000_hm_mean_run_time_plot_data_8_x_20_1000_x_30_x_3_30.loc[30,['100_S=10']]=pd.read_csv(path).loc[0,'100']
path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_run_time_plot_data_8_x_100_x_30_x_15.csv"
Xy_N_6000_hm_mean_run_time_plot_data_8_x_20_1000_x_30_x_3_30.loc[30,['100_S=15']]=pd.read_csv(path).loc[0,'100']
path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_run_time_plot_data_8_x_100_x_30_x_30.csv"
Xy_N_6000_hm_mean_run_time_plot_data_8_x_20_1000_x_30_x_3_30.loc[30,['100_S=30']]=pd.read_csv(path).loc[0,'100']

path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_run_time_plot_data_8_x_1000_x_30_x_3.csv"
Xy_N_6000_hm_mean_run_time_plot_data_8_x_20_1000_x_30_x_3_30.loc[30,['1000_S=3']]=pd.read_csv(path).loc[0,'1000']
path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_run_time_plot_data_8_x_1000_x_30_x_6.csv"
Xy_N_6000_hm_mean_run_time_plot_data_8_x_20_1000_x_30_x_3_30.loc[30,['1000_S=6']]=pd.read_csv(path).loc[0,'1000']
path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_run_time_plot_data_8_x_1000_x_30_x_10.csv"
Xy_N_6000_hm_mean_run_time_plot_data_8_x_20_1000_x_30_x_3_30.loc[30,['1000_S=10']]=pd.read_csv(path).loc[0,'1000']
path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_run_time_plot_data_8_x_1000_x_30_x_15.csv"
Xy_N_6000_hm_mean_run_time_plot_data_8_x_20_1000_x_30_x_3_30.loc[30,['1000_S=15']]=pd.read_csv(path).loc[0,'1000']
path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_run_time_plot_data_8_x_1000_x_30_x_30.csv"
Xy_N_6000_hm_mean_run_time_plot_data_8_x_20_1000_x_30_x_3_30.loc[30,['1000_S=30']]=pd.read_csv(path).loc[0,'1000']

path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_total_run_time_plot_data_8_x_20_1000_x_30_1200_x_60.csv"
print(pd.read_csv(path))
Xy_N_6000_hm_mean_run_time_plot_data_8_x_20_1000_x_30_1200_x_60=pd.read_csv(path)
Xy_N_6000_hm_mean_run_time_plot_data_8_x_20_1000_x_30_1200_x_60.set_index("index", inplace=True)
Xy_N_6000_hm_mean_run_time_plot_data_8_x_20_1000_x_30_1200_x_60.columns = ['20_S=60','100_S=60','1000_S=60']

path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_run_time_plot_data_8_x_20_1000_x_150_1200_x_3.csv"
Xy_N_6000_hm_mean_run_time_plot_data_8_x_20_1000_x_150_1200_x_3=pd.read_csv(path)

path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_run_time_plot_data_8_x_20_1000_x_150_1200_x_6.csv"
Xy_N_6000_hm_mean_run_time_plot_data_8_x_20_1000_x_150_1200_x_6=pd.read_csv(path)

path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_run_time_plot_data_8_x_20_1000_x_150_1200_x_10.csv"
Xy_N_6000_hm_mean_run_time_plot_data_8_x_20_1000_x_150_1200_x_10=pd.read_csv(path)

path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_run_time_plot_data_8_x_20_1000_x_150_1200_x_15.csv"
Xy_N_6000_hm_mean_run_time_plot_data_8_x_20_1000_x_150_1200_x_15=pd.read_csv(path)

path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_run_time_plot_data_8_x_20_1000_x_150_1200_x_30.csv"
Xy_N_6000_hm_mean_run_time_plot_data_8_x_20_1000_x_150_1200_x_30=pd.read_csv(path)

joined_mean_run_time = Xy_N_6000_hm_mean_run_time_plot_data_8_x_20_1000_x_150_1200_x_3.join(
    Xy_N_6000_hm_mean_run_time_plot_data_8_x_20_1000_x_150_1200_x_6, how='left',  rsuffix='_S=6').join(
    Xy_N_6000_hm_mean_run_time_plot_data_8_x_20_1000_x_150_1200_x_10, how='left', rsuffix='_S=10').join(
    Xy_N_6000_hm_mean_run_time_plot_data_8_x_20_1000_x_150_1200_x_15, how='left', rsuffix='_S=15').join(
    Xy_N_6000_hm_mean_run_time_plot_data_8_x_20_1000_x_150_1200_x_30, how='left', rsuffix='_S=30'
)
joined_mean_run_time.set_index("index", inplace=True)
to_plot_mean_run_time = joined_mean_run_time[old_names]
to_plot_mean_run_time.columns = new_names

to_plot_mean_run_time = pd.concat([Xy_N_6000_hm_mean_run_time_plot_data_8_x_20_1000_x_30_x_3_30, to_plot_mean_run_time])

to_plot_mean_run_time = to_plot_mean_run_time.join(Xy_N_6000_hm_mean_run_time_plot_data_8_x_20_1000_x_30_1200_x_60,  how='left')

plt.figure(figsize=(20,5))
sns.heatmap(
    to_plot_mean_run_time, 
    cmap=sns.color_palette("bone"),  
    annot=True
)
plt.ylabel("Observations Per Epoch")
plt.xlabel("particle_count_Shard_count=S")
plt.title('Mean Run Time')

plt.show()

################################
#            Std
################################

path = "experiment_results/heat_map_data/Xy_N_6000_hm_std_run_time_plot_data_8_x_20_1000_x_150_1200_x_3.csv"
Xy_N_6000_hm_std_run_time_plot_data_8_x_20_1000_x_150_1200_x_3=pd.read_csv(path)

path = "experiment_results/heat_map_data/Xy_N_6000_hm_std_run_time_plot_data_8_x_20_1000_x_150_1200_x_6.csv"
Xy_N_6000_hm_std_run_time_plot_data_8_x_20_1000_x_150_1200_x_6=pd.read_csv(path)

path = "experiment_results/heat_map_data/Xy_N_6000_hm_std_run_time_plot_data_8_x_20_1000_x_150_1200_x_10.csv"
Xy_N_6000_hm_std_run_time_plot_data_8_x_20_1000_x_150_1200_x_10=pd.read_csv(path)

path = "experiment_results/heat_map_data/Xy_N_6000_hm_std_run_time_plot_data_8_x_20_1000_x_150_1200_x_15.csv"
Xy_N_6000_hm_std_run_time_plot_data_8_x_20_1000_x_150_1200_x_15=pd.read_csv(path)

path = "experiment_results/heat_map_data/Xy_N_6000_hm_std_run_time_plot_data_8_x_20_1000_x_150_1200_x_30.csv"
Xy_N_6000_hm_std_run_time_plot_data_8_x_20_1000_x_150_1200_x_30=pd.read_csv(path)

joined_std_run_time_err = Xy_N_6000_hm_std_run_time_plot_data_8_x_20_1000_x_150_1200_x_3.join(
    Xy_N_6000_hm_std_run_time_plot_data_8_x_20_1000_x_150_1200_x_6, how='left',  rsuffix='_S=6').join(
    Xy_N_6000_hm_std_run_time_plot_data_8_x_20_1000_x_150_1200_x_10, how='left', rsuffix='_S=10').join(
    Xy_N_6000_hm_std_run_time_plot_data_8_x_20_1000_x_150_1200_x_15, how='left', rsuffix='_S=15').join(
    Xy_N_6000_hm_std_run_time_plot_data_8_x_20_1000_x_150_1200_x_30, how='left', rsuffix='_S=30'
)
joined_std_run_time_err.set_index("index", inplace=True)
to_plot_std_run_time_err = joined_std_run_time_err[old_names]
to_plot_std_run_time_err.columns = new_names

sns.heatmap(to_plot_std_run_time_err[new_names], cmap=sns.color_palette("bone"),  annot=True)

plt.figure(figsize=(20,5))
plt.ylabel("Observations Per Epoch")
plt.xlabel("particle_count_Shard_count=S")
plt.title('Standard Error')
plt.show()

fig = plt.figure(figsize=(20,5))
ax1 = fig.add_subplot(1, 3, 1)
ax2 = fig.add_subplot(1, 3, 2)
ax3 = fig.add_subplot(1, 3, 3)

sns.heatmap(to_plot_mean_run_time[names_part_num_20], cmap=sns.color_palette("bone"),  annot=True, ax=ax1,)# vmin=-0.01, vmax=0.03)
plt.ylabel("Observations Per Epoch")
plt.xlabel("particle_count_Shard_count=S")

sns.heatmap(to_plot_mean_run_time[names_part_num_100], cmap=sns.color_palette("bone"),  annot=True, ax=ax2,)# vmin=-0.01, vmax=0.03)
plt.ylabel("Observations Per Epoch")
plt.xlabel("particle_count_Shard_count=S")

sns.heatmap(to_plot_mean_run_time[names_part_num_1000], cmap=sns.color_palette("bone"),  annot=True, ax=ax3,)# vmin=-0.01, vmax=0.03)
plt.ylabel("Observations Per Epoch")
plt.xlabel("particle_count_Shard_count=S")

plt.show()

#fig = plt.figure(figsize=(20,5))
#ax1 = fig.add_subplot(1, 3, 1)
#ax2 = fig.add_subplot(1, 3, 2)
#ax3 = fig.add_subplot(1, 3, 3)
#
#sns.heatmap(to_plot_std_run_time_err[names_part_num_20], cmap=sns.color_palette("bone"),  annot=True, ax=ax1,)# vmin=0.001, vmax=0.01)
#plt.ylabel("Observations Per Epoch")
#plt.xlabel("particle_count_Shard_count=S")
#
#sns.heatmap(to_plot_std_run_time_err[names_part_num_100], cmap=sns.color_palette("bone"),  annot=True, ax=ax2,)# vmin=0.001, vmax=0.01)
#plt.ylabel("Observations Per Epoch")
#plt.xlabel("particle_count_Shard_count=S")
#
#sns.heatmap(to_plot_std_run_time_err[names_part_num_1000], cmap=sns.color_palette("bone"),  annot=True, ax=ax3,)# vmin=0.001, vmax=0.01)
#plt.ylabel("Observations Per Epoch")
#plt.xlabel("particle_count_Shard_count=S")
#
#plt.show()
# Out:
#            20          100          1000  index
# 0  499.107948  2229.790898  21887.038141     30
# 1  123.371846   509.238043   5417.922534    150
# 2   74.035675   293.213350   2954.763070    300
# 3   49.088230   182.043182   1793.685537    600
# 4   36.189444   123.256090           NaN   1200

# %% [markdown]
# ### p = 16

# %%
################################
#            Mean
################################
Xy_N_6000_hm_mean_run_time_plot_data_16_x_20_1000_x_30_x_3_30 = pd.DataFrame([np.zeros(15)], index = [30])
Xy_N_6000_hm_mean_run_time_plot_data_16_x_20_1000_x_30_x_3_30.columns = new_names


path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_run_time_plot_data_16_x_20_x_30_x_3.csv"
Xy_N_6000_hm_mean_run_time_plot_data_16_x_20_1000_x_30_x_3_30.loc[30,['20_S=3']]=pd.read_csv(path).loc[0,'20']
path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_run_time_plot_data_16_x_20_x_30_x_6.csv"
Xy_N_6000_hm_mean_run_time_plot_data_16_x_20_1000_x_30_x_3_30.loc[30,['20_S=6']]=pd.read_csv(path).loc[0,'20']
path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_run_time_plot_data_16_x_20_x_30_x_10.csv"
Xy_N_6000_hm_mean_run_time_plot_data_16_x_20_1000_x_30_x_3_30.loc[30,['20_S=10']]=pd.read_csv(path).loc[0,'20']
path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_run_time_plot_data_16_x_20_x_30_x_15.csv"
Xy_N_6000_hm_mean_run_time_plot_data_16_x_20_1000_x_30_x_3_30.loc[30,['20_S=15']]=pd.read_csv(path).loc[0,'20']
path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_run_time_plot_data_16_x_20_x_30_x_30.csv"
Xy_N_6000_hm_mean_run_time_plot_data_16_x_20_1000_x_30_x_3_30.loc[30,['20_S=30']]=pd.read_csv(path).loc[0,'20']

path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_run_time_plot_data_16_x_100_x_30_x_3.csv"
Xy_N_6000_hm_mean_run_time_plot_data_16_x_20_1000_x_30_x_3_30.loc[30,['100_S=3']]=pd.read_csv(path).loc[0,'100']
path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_run_time_plot_data_16_x_100_x_30_x_6.csv"
Xy_N_6000_hm_mean_run_time_plot_data_16_x_20_1000_x_30_x_3_30.loc[30,['100_S=6']]=pd.read_csv(path).loc[0,'100']
path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_run_time_plot_data_16_x_100_x_30_x_10.csv"
Xy_N_6000_hm_mean_run_time_plot_data_16_x_20_1000_x_30_x_3_30.loc[30,['100_S=10']]=pd.read_csv(path).loc[0,'100']
path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_run_time_plot_data_16_x_100_x_30_x_15.csv"
Xy_N_6000_hm_mean_run_time_plot_data_16_x_20_1000_x_30_x_3_30.loc[30,['100_S=15']]=pd.read_csv(path).loc[0,'100']
path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_run_time_plot_data_16_x_100_x_30_x_30.csv"
Xy_N_6000_hm_mean_run_time_plot_data_16_x_20_1000_x_30_x_3_30.loc[30,['100_S=30']]=pd.read_csv(path).loc[0,'100']

path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_run_time_plot_data_16_x_1000_x_30_x_3.csv"
Xy_N_6000_hm_mean_run_time_plot_data_16_x_20_1000_x_30_x_3_30.loc[30,['1000_S=3']]=pd.read_csv(path).loc[0,'1000']
path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_run_time_plot_data_16_x_1000_x_30_x_6.csv"
Xy_N_6000_hm_mean_run_time_plot_data_16_x_20_1000_x_30_x_3_30.loc[30,['1000_S=6']]=pd.read_csv(path).loc[0,'1000']
path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_run_time_plot_data_16_x_1000_x_30_x_10.csv"
Xy_N_6000_hm_mean_run_time_plot_data_16_x_20_1000_x_30_x_3_30.loc[30,['1000_S=10']]=pd.read_csv(path).loc[0,'1000']
path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_run_time_plot_data_16_x_1000_x_30_x_15.csv"
Xy_N_6000_hm_mean_run_time_plot_data_16_x_20_1000_x_30_x_3_30.loc[30,['1000_S=15']]=pd.read_csv(path).loc[0,'1000']
path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_run_time_plot_data_16_x_1000_x_30_x_30.csv"
Xy_N_6000_hm_mean_run_time_plot_data_16_x_20_1000_x_30_x_3_30.loc[30,['1000_S=30']]=pd.read_csv(path).loc[0,'1000']
print(pd.read_csv(path))

path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_total_run_time_plot_data_16_x_20_1000_x_30_1200_x_60.csv"
print(pd.read_csv(path))
Xy_N_6000_hm_mean_run_time_plot_data_16_x_20_1000_x_30_1200_x_60=pd.read_csv(path)
Xy_N_6000_hm_mean_run_time_plot_data_16_x_20_1000_x_30_1200_x_60.set_index("index", inplace=True)
Xy_N_6000_hm_mean_run_time_plot_data_16_x_20_1000_x_30_1200_x_60.columns = ['20_S=60','100_S=60','1000_S=60']

path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_run_time_plot_data_16_x_20_1000_x_150_1200_x_3.csv"
Xy_N_6000_hm_mean_run_time_plot_data_16_x_20_1000_x_150_1200_x_3=pd.read_csv(path)

path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_run_time_plot_data_16_x_20_1000_x_150_1200_x_6.csv"
Xy_N_6000_hm_mean_run_time_plot_data_16_x_20_1000_x_150_1200_x_6=pd.read_csv(path)

path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_run_time_plot_data_16_x_20_1000_x_150_1200_x_10.csv"
Xy_N_6000_hm_mean_run_time_plot_data_16_x_20_1000_x_150_1200_x_10=pd.read_csv(path)

path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_run_time_plot_data_16_x_20_1000_x_150_1200_x_15.csv"
Xy_N_6000_hm_mean_run_time_plot_data_16_x_20_1000_x_150_1200_x_15=pd.read_csv(path)

path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_run_time_plot_data_16_x_20_1000_x_150_1200_x_30.csv"
Xy_N_6000_hm_mean_run_time_plot_data_16_x_20_1000_x_150_1200_x_30=pd.read_csv(path)

joined_mean_run_time = Xy_N_6000_hm_mean_run_time_plot_data_16_x_20_1000_x_150_1200_x_3.join(
    Xy_N_6000_hm_mean_run_time_plot_data_16_x_20_1000_x_150_1200_x_6, how='left',  rsuffix='_S=6').join(
    Xy_N_6000_hm_mean_run_time_plot_data_16_x_20_1000_x_150_1200_x_10, how='left', rsuffix='_S=10').join(
    Xy_N_6000_hm_mean_run_time_plot_data_16_x_20_1000_x_150_1200_x_15, how='left', rsuffix='_S=15').join(
    Xy_N_6000_hm_mean_run_time_plot_data_16_x_20_1000_x_150_1200_x_30, how='left', rsuffix='_S=30'
)
joined_mean_run_time.set_index("index", inplace=True)
to_plot_mean_run_time = joined_mean_run_time[old_names]
to_plot_mean_run_time.columns = new_names

to_plot_mean_run_time = pd.concat([Xy_N_6000_hm_mean_run_time_plot_data_16_x_20_1000_x_30_x_3_30, to_plot_mean_run_time])

to_plot_mean_run_time = to_plot_mean_run_time.join(Xy_N_6000_hm_mean_run_time_plot_data_16_x_20_1000_x_30_1200_x_60,  how='left')

plt.figure(figsize=(20,5))
sns.heatmap(
    to_plot_mean_run_time,
    cmap=sns.color_palette("bone"), 
    annot=True
)
plt.ylabel("Observations Per Epoch")
plt.xlabel("particle_count_Shard_count=S")
plt.title('Mean Run Time')

plt.show()

################################
#            Std
################################

path = "experiment_results/heat_map_data/Xy_N_6000_hm_std_run_time_plot_data_16_x_20_1000_x_150_1200_x_3.csv"
Xy_N_6000_hm_std_run_time_plot_data_16_x_20_1000_x_150_1200_x_3=pd.read_csv(path)

path = "experiment_results/heat_map_data/Xy_N_6000_hm_std_run_time_plot_data_16_x_20_1000_x_150_1200_x_6.csv"
Xy_N_6000_hm_std_run_time_plot_data_16_x_20_1000_x_150_1200_x_6=pd.read_csv(path)

path = "experiment_results/heat_map_data/Xy_N_6000_hm_std_run_time_plot_data_16_x_20_1000_x_150_1200_x_10.csv"
Xy_N_6000_hm_std_run_time_plot_data_16_x_20_1000_x_150_1200_x_10=pd.read_csv(path)

path = "experiment_results/heat_map_data/Xy_N_6000_hm_std_run_time_plot_data_16_x_20_1000_x_150_1200_x_15.csv"
Xy_N_6000_hm_std_run_time_plot_data_16_x_20_1000_x_150_1200_x_15=pd.read_csv(path)

path = "experiment_results/heat_map_data/Xy_N_6000_hm_std_run_time_plot_data_16_x_20_1000_x_150_1200_x_30.csv"
Xy_N_6000_hm_std_run_time_plot_data_16_x_20_1000_x_150_1200_x_30=pd.read_csv(path)

joined_std_run_time_err = Xy_N_6000_hm_std_run_time_plot_data_16_x_20_1000_x_150_1200_x_3.join(
    Xy_N_6000_hm_std_run_time_plot_data_16_x_20_1000_x_150_1200_x_6, how='left',  rsuffix='_S=6').join(
    Xy_N_6000_hm_std_run_time_plot_data_16_x_20_1000_x_150_1200_x_10, how='left', rsuffix='_S=10').join(
    Xy_N_6000_hm_std_run_time_plot_data_16_x_20_1000_x_150_1200_x_15, how='left', rsuffix='_S=15').join(
    Xy_N_6000_hm_std_run_time_plot_data_16_x_20_1000_x_150_1200_x_30, how='left', rsuffix='_S=30'
)
joined_std_run_time_err.set_index("index", inplace=True)
to_plot_std_run_time_err = joined_std_run_time_err[old_names]
to_plot_std_run_time_err.columns = new_names
plt.figure(figsize=(20,5))

sns.heatmap(to_plot_std_run_time_err[new_names], cmap=sns.color_palette("bone"),  annot=True)
plt.ylabel("Observations Per Epoch")
plt.xlabel("particle_count_Shard_count=S")
plt.title('Standard Error')
plt.show()

fig = plt.figure(figsize=(20,5))
ax1 = fig.add_subplot(1, 3, 1)
ax2 = fig.add_subplot(1, 3, 2)
ax3 = fig.add_subplot(1, 3, 3)

sns.heatmap(to_plot_mean_run_time[names_part_num_20], cmap=sns.color_palette("bone"),  annot=True, ax=ax1,)# vmin=-0.01, vmax=0.03)
plt.ylabel("Observations Per Epoch")
plt.xlabel("particle_count_Shard_count=S")

sns.heatmap(to_plot_mean_run_time[names_part_num_100], cmap=sns.color_palette("bone"),  annot=True, ax=ax2,)# vmin=-0.01, vmax=0.03)
plt.ylabel("Observations Per Epoch")
plt.xlabel("particle_count_Shard_count=S")

sns.heatmap(to_plot_mean_run_time[names_part_num_1000], cmap=sns.color_palette("bone"),  annot=True, ax=ax3,)# vmin=-0.01, vmax=0.03)
plt.ylabel("Observations Per Epoch")
plt.xlabel("particle_count_Shard_count=S")

plt.show()

#fig = plt.figure(figsize=(20,5))
#ax1 = fig.add_subplot(1, 3, 1)
#ax2 = fig.add_subplot(1, 3, 2)
#ax3 = fig.add_subplot(1, 3, 3)
#
#sns.heatmap(to_plot_std_run_time_err[names_part_num_20], cmap=sns.color_palette("bone"),  annot=True, ax=ax1,)# vmin=0.001, vmax=0.01)
#plt.ylabel("Observations Per Epoch")
#plt.xlabel("particle_count_Shard_count=S")
#
#sns.heatmap(to_plot_std_run_time_err[names_part_num_100], cmap=sns.color_palette("bone"),  annot=True, ax=ax2,)# vmin=0.001, vmax=0.01)
#plt.ylabel("Observations Per Epoch")
#plt.xlabel("particle_count_Shard_count=S")
#
#sns.heatmap(to_plot_std_run_time_err[names_part_num_1000], cmap=sns.color_palette("bone"),  annot=True, ax=ax3,)# vmin=0.001, vmax=0.01)
#plt.ylabel("Observations Per Epoch")
#plt.xlabel("particle_count_Shard_count=S")
#
#plt.show()
# Out:
#            1000  index
# 0  19834.635959     30
#            20          100          1000  index
# 0  816.526169  3809.966409  38331.264295     30
# 1  185.521094   828.800154   8526.599670    150
# 2  105.738559   452.028328   4824.836364    300
# 3   64.643042   261.336871   2622.485434    600
# 4   44.166411   163.893013   1620.152522   1200

# %% [markdown]
# ### p = 32

# %%
################################
#            Mean
################################
Xy_N_6000_hm_mean_run_time_plot_data_32_x_20_1000_x_30_x_3_30 = pd.DataFrame([np.zeros(15)], index = [30])
Xy_N_6000_hm_mean_run_time_plot_data_32_x_20_1000_x_30_x_3_30.columns = new_names


path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_run_time_plot_data_32_x_20_x_30_x_3.csv"
Xy_N_6000_hm_mean_run_time_plot_data_32_x_20_1000_x_30_x_3_30.loc[30,['20_S=3']]=pd.read_csv(path).loc[0,'20']
print(pd.read_csv(path))
#print(Xy_N_6000_hm_mean_run_time_plot_data_32_x_20_1000_x_30_x_3_30)
path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_run_time_plot_data_32_x_20_x_30_x_6.csv"
Xy_N_6000_hm_mean_run_time_plot_data_32_x_20_1000_x_30_x_3_30.loc[30,['20_S=6']]=pd.read_csv(path).loc[0,'20']
path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_run_time_plot_data_32_x_20_x_30_x_10.csv"
Xy_N_6000_hm_mean_run_time_plot_data_32_x_20_1000_x_30_x_3_30.loc[30,['20_S=10']]=pd.read_csv(path).loc[0,'20']
path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_run_time_plot_data_32_x_20_x_30_x_15.csv"
Xy_N_6000_hm_mean_run_time_plot_data_32_x_20_1000_x_30_x_3_30.loc[30,['20_S=15']]=pd.read_csv(path).loc[0,'20']
path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_run_time_plot_data_32_x_20_x_30_x_30.csv"
Xy_N_6000_hm_mean_run_time_plot_data_32_x_20_1000_x_30_x_3_30.loc[30,['20_S=30']]=pd.read_csv(path).loc[0,'20']
        
path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_run_time_plot_data_32_x_100_x_30_x_3.csv"
Xy_N_6000_hm_mean_run_time_plot_data_32_x_20_1000_x_30_x_3_30.loc[30,['100_S=3']]=pd.read_csv(path).loc[0,'100']
path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_run_time_plot_data_32_x_100_x_30_x_6.csv"
Xy_N_6000_hm_mean_run_time_plot_data_32_x_20_1000_x_30_x_3_30.loc[30,['100_S=6']]=pd.read_csv(path).loc[0,'100']
path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_run_time_plot_data_32_x_100_x_30_x_10.csv"
Xy_N_6000_hm_mean_run_time_plot_data_32_x_20_1000_x_30_x_3_30.loc[30,['100_S=10']]=pd.read_csv(path).loc[0,'100']
path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_run_time_plot_data_32_x_100_x_30_x_15.csv"
Xy_N_6000_hm_mean_run_time_plot_data_32_x_20_1000_x_30_x_3_30.loc[30,['100_S=15']]=pd.read_csv(path).loc[0,'100']
path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_run_time_plot_data_32_x_100_x_30_x_30.csv"
Xy_N_6000_hm_mean_run_time_plot_data_32_x_20_1000_x_30_x_3_30.loc[30,['100_S=30']]=pd.read_csv(path).loc[0,'100']

path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_run_time_plot_data_32_x_1000_x_30_x_3.csv"
Xy_N_6000_hm_mean_run_time_plot_data_32_x_20_1000_x_30_x_3_30.loc[30,['1000_S=3']]=pd.read_csv(path).loc[0,'1000']
path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_run_time_plot_data_32_x_1000_x_30_x_6.csv"
Xy_N_6000_hm_mean_run_time_plot_data_32_x_20_1000_x_30_x_3_30.loc[30,['1000_S=6']]=pd.read_csv(path).loc[0,'1000']
path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_run_time_plot_data_32_x_1000_x_30_x_10.csv"
Xy_N_6000_hm_mean_run_time_plot_data_32_x_20_1000_x_30_x_3_30.loc[30,['1000_S=10']]=pd.read_csv(path).loc[0,'1000']
path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_run_time_plot_data_32_x_1000_x_30_x_15.csv"
Xy_N_6000_hm_mean_run_time_plot_data_32_x_20_1000_x_30_x_3_30.loc[30,['1000_S=15']]=pd.read_csv(path).loc[0,'1000']
path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_run_time_plot_data_32_x_1000_x_30_x_30.csv"
Xy_N_6000_hm_mean_run_time_plot_data_32_x_20_1000_x_30_x_3_30.loc[30,['1000_S=30']]=pd.read_csv(path).loc[0,'1000']

path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_total_run_time_plot_data_32_x_20_1000_x_30_1200_x_60.csv"
print(pd.read_csv(path))
Xy_N_6000_hm_mean_run_time_plot_data_32_x_20_1000_x_30_1200_x_60=pd.read_csv(path)
Xy_N_6000_hm_mean_run_time_plot_data_32_x_20_1000_x_30_1200_x_60.set_index("index", inplace=True)
Xy_N_6000_hm_mean_run_time_plot_data_32_x_20_1000_x_30_1200_x_60.columns = ['20_S=60','100_S=60','1000_S=60']

path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_run_time_plot_data_32_x_20_1000_x_150_1200_x_3.csv"
Xy_N_6000_hm_mean_run_time_plot_data_32_x_20_1000_x_150_1200_x_3=pd.read_csv(path)

path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_run_time_plot_data_32_x_20_1000_x_150_1200_x_6.csv"
Xy_N_6000_hm_mean_run_time_plot_data_32_x_20_1000_x_150_1200_x_6=pd.read_csv(path)

path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_run_time_plot_data_32_x_20_1000_x_150_1200_x_10.csv"
Xy_N_6000_hm_mean_run_time_plot_data_32_x_20_1000_x_150_1200_x_10=pd.read_csv(path)

path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_run_time_plot_data_32_x_20_1000_x_150_1200_x_15.csv"
Xy_N_6000_hm_mean_run_time_plot_data_32_x_20_1000_x_150_1200_x_15=pd.read_csv(path)

path = "experiment_results/heat_map_data/Xy_N_6000_hm_mean_run_time_plot_data_32_x_20_1000_x_150_1200_x_30.csv"
Xy_N_6000_hm_mean_run_time_plot_data_32_x_20_1000_x_150_1200_x_30=pd.read_csv(path)

joined_mean_run_time = Xy_N_6000_hm_mean_run_time_plot_data_32_x_20_1000_x_150_1200_x_3.join(
    Xy_N_6000_hm_mean_run_time_plot_data_32_x_20_1000_x_150_1200_x_6, how='left',  rsuffix='_S=6').join(
    Xy_N_6000_hm_mean_run_time_plot_data_32_x_20_1000_x_150_1200_x_10, how='left', rsuffix='_S=10').join(
    Xy_N_6000_hm_mean_run_time_plot_data_32_x_20_1000_x_150_1200_x_15, how='left', rsuffix='_S=15').join(
    Xy_N_6000_hm_mean_run_time_plot_data_32_x_20_1000_x_150_1200_x_30, how='left', rsuffix='_S=30'
)

joined_mean_run_time.set_index("index", inplace=True)
to_plot_mean_run_time = joined_mean_run_time[old_names]
to_plot_mean_run_time.columns = new_names

to_plot_mean_run_time = pd.concat([Xy_N_6000_hm_mean_run_time_plot_data_32_x_20_1000_x_30_x_3_30, to_plot_mean_run_time])

to_plot_mean_run_time = to_plot_mean_run_time.join(Xy_N_6000_hm_mean_run_time_plot_data_32_x_20_1000_x_30_1200_x_60,  how='left')

plt.figure(figsize=(20,5))
sns.heatmap(
    to_plot_mean_run_time, 
    cmap=sns.color_palette("bone"),
    annot=True
)
plt.ylabel("Observations Per Epoch")
plt.xlabel("particle_count_Shard_count=S")
plt.title('Mean Run Time')

plt.show()
to_plot_mean_run_time.to_csv('experiment_results/heat_map_data/full_heat_map_mean_run_time_p=32.csv', index=True)

################################
#            Std
################################
#
#path = "experiment_results/heat_map_data/Xy_N_6000_hm_std_run_time_plot_data_32_x_20_1000_x_150_1200_x_3.csv"
#Xy_N_6000_hm_std_run_time_plot_data_32_x_20_1000_x_150_1200_x_3=pd.read_csv(path)
#
#path = "experiment_results/heat_map_data/Xy_N_6000_hm_std_run_time_plot_data_32_x_20_1000_x_150_1200_x_6.csv"
#Xy_N_6000_hm_std_run_time_plot_data_32_x_20_1000_x_150_1200_x_6=pd.read_csv(path)
#
#path = "experiment_results/heat_map_data/Xy_N_6000_hm_std_run_time_plot_data_32_x_20_1000_x_150_1200_x_10.csv"
#Xy_N_6000_hm_std_run_time_plot_data_32_x_20_1000_x_150_1200_x_10=pd.read_csv(path)
#
#path = "experiment_results/heat_map_data/Xy_N_6000_hm_std_run_time_plot_data_32_x_20_1000_x_150_1200_x_15.csv"
#Xy_N_6000_hm_std_run_time_plot_data_32_x_20_1000_x_150_1200_x_15=pd.read_csv(path)
#
#path = "experiment_results/heat_map_data/Xy_N_6000_hm_std_run_time_plot_data_32_x_20_1000_x_150_1200_x_30.csv"
#Xy_N_6000_hm_std_run_time_plot_data_32_x_20_1000_x_150_1200_x_30=pd.read_csv(path)
#
#joined_std_run_time_err = Xy_N_6000_hm_std_run_time_plot_data_32_x_20_1000_x_150_1200_x_3.join(
#    Xy_N_6000_hm_std_run_time_plot_data_32_x_20_1000_x_150_1200_x_6, how='left',  rsuffix='_S=6').join(
#    Xy_N_6000_hm_std_run_time_plot_data_32_x_20_1000_x_150_1200_x_10, how='left', rsuffix='_S=10').join(
#    Xy_N_6000_hm_std_run_time_plot_data_32_x_20_1000_x_150_1200_x_15, how='left', rsuffix='_S=15').join(
#    Xy_N_6000_hm_std_run_time_plot_data_32_x_20_1000_x_150_1200_x_30, how='left', rsuffix='_S=30'
#)
#joined_std_run_time_err.set_index("index", inplace=True)
#to_plot_std_run_time_err = joined_std_run_time_err[old_names]
#to_plot_std_run_time_err.columns = new_names
#plt.figure(figsize=(20,5))
#
#sns.heatmap(to_plot_std_run_time_err[new_names], cmap=sns.color_palette("bone"),  annot=True)
#plt.ylabel("Observations Per Epoch")
#plt.xlabel("particle_count_Shard_count=S")
#plt.title('Standard Error')
#plt.show()
#
fig = plt.figure(figsize=(20,5))
ax1 = fig.add_subplot(1, 3, 1)
ax2 = fig.add_subplot(1, 3, 2)
ax3 = fig.add_subplot(1, 3, 3)

sns.heatmap(to_plot_mean_run_time[names_part_num_20], cmap=sns.color_palette("bone"),  annot=True, ax=ax1,)# vmin=0, vmax=8000)
plt.ylabel("Observations Per Epoch")
plt.xlabel("particle_count_Shard_count=S")

sns.heatmap(to_plot_mean_run_time[names_part_num_100], cmap=sns.color_palette("bone"),  annot=True, ax=ax2,)# vmin=0, vmax=8000)
plt.ylabel("Observations Per Epoch")
plt.xlabel("particle_count_Shard_count=S")

sns.heatmap(to_plot_mean_run_time[names_part_num_1000], cmap=sns.color_palette("bone"),  annot=True, ax=ax3,)# vmin=0, vmax=8000)
plt.ylabel("Observations Per Epoch")
plt.xlabel("particle_count_Shard_count=S")

plt.show()

#fig = plt.figure(figsize=(20,5))
#ax1 = fig.add_subplot(1, 3, 1)
#ax2 = fig.add_subplot(1, 3, 2)
#ax3 = fig.add_subplot(1, 3, 3)
#
#sns.heatmap(to_plot_std_run_time_err[names_part_num_20], cmap=sns.color_palette("bone"),  annot=True, ax=ax1,)# vmin=0.001, vmax=0.01)
#plt.ylabel("Observations Per Epoch")
#plt.xlabel("particle_count_Shard_count=S")
#
#sns.heatmap(to_plot_std_run_time_err[names_part_num_100], cmap=sns.color_palette("bone"),  annot=True, ax=ax2,)# vmin=0.001, vmax=0.01)
#plt.ylabel("Observations Per Epoch")
#plt.xlabel("particle_count_Shard_count=S")
#
#sns.heatmap(to_plot_std_run_time_err[names_part_num_1000], cmap=sns.color_palette("bone"),  annot=True, ax=ax3,)# vmin=0.001, vmax=0.01)
#plt.ylabel("Observations Per Epoch")
#plt.xlabel("particle_count_Shard_count=S")
#
#plt.show()
# Out:
#    20  index
# 0 NaN     30
#             20          100          1000  index
# 0  1451.316458  7006.803753  71866.597357     30
# 1   314.811658  1483.092873  15413.032493    150
# 2   170.424765   779.852957   7997.152999    300
# 3    97.437468   425.956057   4345.170660    600
# 4    61.106761   246.256818   2681.336723   1200
