# %%
import analysis_functions as af
import pandas as pd
import numpy as np
import re
import pickle

# %%
# format = sn_en_nt_p_gpv_
shard_number = [30]#[3,6, 10,15,30, 60]
Xy_N=6000
N_Epoch = [30,150,300,600,1200, 6000]
Nt = [30]
p = [32]
GP_version = list(range(10))
part_num = [1000]
predictors = [
    'B_0','B_1','B_2','B_3','B_4','B_5','B_6','B_7','B_8','B_9',
    'B_10','B_11','B_12','B_13','B_14','B_15','B_16','B_17','B_18','B_19',
    'B_20','B_21','B_22','B_23','B_24','B_25','B_26','B_27','B_28','B_29',
    'B_30','B_31'
]

exp_num = 99

# %%
big_results_dict = af.prep_big_results_dict_v2(
    f_shard_number = shard_number,
    f_Xy_N = Xy_N,
    f_N_Epoch = N_Epoch,
    f_Nt = Nt,
    f_p = p ,
    f_GP_version = GP_version,
    f_part_num = part_num,
    f_predictors = predictors,
    f_exp_num = exp_num,
    f_comm = True
)
# Out:
# CHECK POINT...
# SUCCESS WITH  synth_data_shard_num=30_Xy_N=6000_Epoch_N=30_Nt=30_p=32_part_num=1000_  GP_version_item =  0
# SUCCESS WITH  synth_data_shard_num=30_Xy_N=6000_Epoch_N=30_Nt=30_p=32_part_num=1000_  GP_version_item =  0
# CHECK POINT...
# SUCCESS WITH  synth_data_shard_num=30_Xy_N=6000_Epoch_N=30_Nt=30_p=32_part_num=1000_  GP_version_item =  1
# SUCCESS WITH  synth_data_shard_num=30_Xy_N=6000_Epoch_N=30_Nt=30_p=32_part_num=1000_  GP_version_item =  1
# CHECK POINT...
# SUCCESS WITH  synth_data_shard_num=30_Xy_N=6000_Epoch_N=30_Nt=30_p=32_part_num=1000_  GP_version_item =  2
# SUCCESS WITH  synth_data_shard_num=30_Xy_N=6000_Epoch_N=30_Nt=30_p=32_part_num=1000_  GP_version_item =  2
# CHECK POINT...
# SUCCESS WITH  synth_data_shard_num=30_Xy_N=6000_Epoch_N=30_Nt=30_p=32_part_num=1000_  GP_version_item =  3
# SUCCESS WITH  synth_data_shard_num=30_Xy_N=6000_Epoch_N=30_Nt=30_p=32_part_num=1000_  GP_version_item =  3
# CHECK POINT...
# ...

# %%
###########################
#          p=32
###########################

Xy_N_6000_hm_mean_plot_data_32_x_1000_x_30_x_30 = af.heat_map_data_prep_mean(
    pred_num=32, part_num=part_num, N_Epoch = N_Epoch, shard_num=30, big_results_dict=big_results_dict
)
Xy_N_6000_hm_mean_plot_data_32_x_1000_x_30_x_30
#Xy_N_6000_hm_plot_data_2_x_20_1000_x_30_1200_x_3.to_csv(
#    'experiment_results/heat_map_data/Xy_N_6000_hm_mean_plot_data_2_x_20_1000_x_30_1200_x_3.csv',
#    index = False,
#)
# Out:
#           1000  index
# 30   -0.000332     30
# 150  -0.000307    150
# 300   0.000014    300
# 600   0.000052    600
# 1200 -0.000133   1200
# 6000  0.000168   6000

# %%
Xy_N_6000_hm_std_plot_data_32_x_1000_x_30_x_30 = af.heat_map_data_prep_std(
    pred_num=32, part_num=part_num, N_Epoch = N_Epoch, shard_num=30, big_results_dict=big_results_dict
)
Xy_N_6000_hm_std_plot_data_32_x_1000_x_30_x_30
# Out:
# in heat_map_data_prep_std
#           1000  index
# 30    0.000321     30
# 150   0.000418    150
# 300   0.000390    300
# 600   0.000438    600
# 1200  0.000238   1200
# 6000  0.000324   6000

# %%
Xy_N_6000_hm_adj_run_time_plot_data_32_x_1000_x_30_x_30 = af.heat_map_data_prep_adjusted_run_time_mean(
    pred_num=32, part_num=part_num, N_Epoch = N_Epoch, shard_num=30, big_results_dict=big_results_dict
)
Xy_N_6000_hm_adj_run_time_plot_data_32_x_1000_x_30_x_30
# Out:
#              1000  index
# 30    2370.645095     30
# 150   2261.379429    150
# 300   2413.060311    300
# 600   2708.754493    600
# 1200  1957.338053   1200
# 6000  1970.179522   6000

# %%
Xy_N_6000_hm_adj_run_time_std_plot_data_32_x_1000_x_30_x_30 = af.heat_map_data_prep_adjusted_run_time_std(
    pred_num=32, part_num=part_num, N_Epoch = N_Epoch, shard_num=30, big_results_dict=big_results_dict
)
Xy_N_6000_hm_adj_run_time_std_plot_data_32_x_1000_x_30_x_30
# Out:
#           1000  index
# 30    4.591527     30
# 150   3.399693    150
# 300   3.718412    300
# 600   3.066973    600
# 1200  2.731437   1200
# 6000  3.997349   6000

# %%
Xy_N_6000_hm_run_time_plot_data_32_x_1000_x_30_x_30 = af.heat_map_data_prep_total_run_time_mean(
    pred_num=32, part_num=part_num, N_Epoch = N_Epoch, shard_num=30, big_results_dict=big_results_dict
)
Xy_N_6000_hm_run_time_plot_data_32_x_1000_x_30_x_30
# Out:
#              1000  index
# 30    2810.809337     30
# 150   2475.809795    150
# 300   2592.176786    300
# 600   2944.526969    600
# 1200  2652.469247   1200
# 6000  2106.662926   6000

# %%
Xy_N_6000_hm_run_time_std_plot_data_32_x_1000_x_30_x_30 = af.heat_map_data_prep_total_run_time_std(
    pred_num=32, part_num=part_num, N_Epoch = N_Epoch, shard_num=30, big_results_dict=big_results_dict
)
Xy_N_6000_hm_run_time_std_plot_data_32_x_1000_x_30_x_30
# Out:
#            1000  index
# 30    14.388248     30
# 150   17.989902    150
# 300   16.587413    300
# 600   31.641614    600
# 1200  60.637301   1200
# 6000  12.570850   6000

# %%
Xy_N_6000_hm_pf_run_time_plot_data_32_x_1000_x_30_x_30 = af.heat_map_data_prep_pf_run_time_mean(
    pred_num=32, part_num=part_num, N_Epoch = N_Epoch, shard_num=30, big_results_dict=big_results_dict
)
Xy_N_6000_hm_pf_run_time_plot_data_32_x_1000_x_30_x_30
# Out:
#              1000  index
# 30    2091.506886     30
# 150   2209.466980    150
# 300   2389.521541    300
# 600   2700.742881    600
# 1200  1972.600775   1200
# 6000  1971.776869   6000

# %%
Xy_N_6000_hm_pf_run_time_std_plot_data_32_x_1000_x_30_x_30 = af.heat_map_data_prep_pf_run_time_std(
    pred_num=32, part_num=part_num, N_Epoch = N_Epoch, shard_num=30, big_results_dict=big_results_dict
)
Xy_N_6000_hm_pf_run_time_std_plot_data_32_x_1000_x_30_x_30
# Out:
#           1000  index
# 30    4.288895     30
# 150   3.222030    150
# 300   3.868664    300
# 600   3.182692    600
# 1200  3.297051   1200
# 6000  3.993493   6000

# %%
Xy_N_6000_hm_particle_comm_time_plot_data_32_x_1000_x_30_x_30 = af.heat_map_data_prep_particle_comm_time_mean(
    pred_num=32, part_num=part_num, N_Epoch = N_Epoch, shard_num=30, big_results_dict=big_results_dict
)
Xy_N_6000_hm_particle_comm_time_plot_data_32_x_1000_x_30_x_30
# Out:
#             1000  index
# 30    407.138532     30
# 150   207.152125    150
# 300   175.104996    300
# 600   233.341870    600
# 1200  693.658899   1200
# 6000  135.697858   6000

# %%
Xy_N_6000_hm_particle_comm_time_std_plot_data_32_x_1000_x_30_x_30 = af.heat_map_data_prep_particle_comm_time_std(
    pred_num=32, part_num=part_num, N_Epoch = N_Epoch, shard_num=30, big_results_dict=big_results_dict
)
Xy_N_6000_hm_particle_comm_time_std_plot_data_32_x_1000_x_30_x_30
# Out:
#            1000  index
# 30    14.808284     30
# 150   18.719758    150
# 300   15.426515    300
# 600   31.787269    600
# 1200  60.995754   1200
# 6000  12.681131   6000

# %%
shard_number = [10]#[3,6, 10,15,30, 60]
Xy_N=6000
N_Epoch = [30]
Nt = [30]
p = [32]
GP_version = list(range(10))
part_num = [1000]
predictors = [
    'B_0','B_1','B_2','B_3','B_4','B_5','B_6','B_7','B_8','B_9',
    'B_10','B_11','B_12','B_13','B_14','B_15','B_16','B_17','B_18','B_19',
    'B_20','B_21','B_22','B_23','B_24','B_25','B_26','B_27','B_28','B_29',
    'B_30','B_31'
]

exp_num = 1

big_results_dict_30 = af.prep_big_results_dict_v2(
    f_shard_number = shard_number,
    f_Xy_N = Xy_N,
    f_N_Epoch = N_Epoch,
    f_Nt = Nt,
    f_p = p ,
    f_GP_version = GP_version,
    f_part_num = part_num,
    f_predictors = predictors,
    f_exp_num = exp_num,
    f_comm = True
)
# Out:
# 6
# self.true_lik= [0.8434072283720765]
# self.esti_lik= [0.5707408199143804]
# 7
# 6
# self.true_lik= [0.8450029990840268]
# self.esti_lik= [0.4763257542471104]
# 7
# SUCCESS WITH  synth_data_shard_num=10_Xy_N=6000_Epoch_N=30_Nt=30_p=32_part_num=1000_  GP_version_item =  0
# SUCCESS WITH  synth_data_shard_num=10_Xy_N=6000_Epoch_N=30_Nt=30_p=32_part_num=1000_  GP_version_item =  0
# 6
# self.true_lik= [0.8220924883841924]
# self.esti_lik= [0.5130786243311418]
# 7
# 6
# self.true_lik= [0.8211545531390091]
# self.esti_lik= [0.4869318309887132]
# 7
# SUCCESS WITH  synth_data_shard_num=10_Xy_N=6000_Epoch_N=30_Nt=30_p=32_part_num=1000_  GP_version_item =  1
# SUCCESS WITH  synth_data_shard_num=10_Xy_N=6000_Epoch_N=30_Nt=30_p=32_part_num=1000_  GP_version_item =  1
# 6
# self.true_lik= [0.8277858669327255]
# self.esti_lik= [0.5171064687912504]
# 7
# 6
# self.true_lik= [0.8282924861418878]
# self.esti_lik= [0.5433758899071608]
# 7
# ...

# %%
Xy_N_6000_hm_mean_plot_data_32_x_1000_x_30_x_10 = af.heat_map_data_prep_mean(
    pred_num=32, part_num=part_num, N_Epoch = N_Epoch, shard_num=10, big_results_dict=big_results_dict_30
)
print(Xy_N_6000_hm_mean_plot_data_32_x_1000_x_30_x_10)

Xy_N_6000_hm_std_plot_data_32_x_1000_x_30_x_10 = af.heat_map_data_prep_std(
    pred_num=32, part_num=part_num, N_Epoch = N_Epoch, shard_num=10, big_results_dict=big_results_dict_30
)
Xy_N_6000_hm_std_plot_data_32_x_1000_x_30_x_10
# Out:
#  in heat_map_data_prep_mean(pred_num, part_num, N_Epoch, shard_num, big_results_dict)
# cond_1= True
# cond_2= True
# cond_3= True
# cond_4= True
# big_results_dict[dict_keys[k]].last_avg_lik_diff = 0.011716986968072796
#         1000  index
# 30  0.011717     30
# in heat_map_data_prep_std
#         1000  index
# 30  0.014994     30

# %%
shard_number = [15]#[3,6, 10,15,30, 60]
Xy_N=6000
N_Epoch = [30]
Nt = [30]
p = [32]
GP_version = list(range(10))
part_num = [1000]
predictors = [
    'B_0','B_1','B_2','B_3','B_4','B_5','B_6','B_7','B_8','B_9',
    'B_10','B_11','B_12','B_13','B_14','B_15','B_16','B_17','B_18','B_19',
    'B_20','B_21','B_22','B_23','B_24','B_25','B_26','B_27','B_28','B_29',
    'B_30','B_31'
]

exp_num = 1

big_results_dict_6000 = af.prep_big_results_dict_v2(
    f_shard_number = shard_number,
    f_Xy_N = Xy_N,
    f_N_Epoch = N_Epoch,
    f_Nt = Nt,
    f_p = p ,
    f_GP_version = GP_version,
    f_part_num = part_num,
    f_predictors = predictors,
    f_exp_num = exp_num,
    f_comm = True
)
# Out:
# 6
# self.true_lik= [0.8440047185344025]
# self.esti_lik= [0.47762518982933644]
# 7
# 6
# self.true_lik= [0.8438163183490397]
# self.esti_lik= [0.5138047571332499]
# 7
# SUCCESS WITH  synth_data_shard_num=15_Xy_N=6000_Epoch_N=30_Nt=30_p=32_part_num=1000_  GP_version_item =  0
# SUCCESS WITH  synth_data_shard_num=15_Xy_N=6000_Epoch_N=30_Nt=30_p=32_part_num=1000_  GP_version_item =  0
# 6
# self.true_lik= [0.8224448576109211]
# self.esti_lik= [0.5245416880286001]
# 7
# 6
# self.true_lik= [0.8217164527337528]
# self.esti_lik= [0.47588851174865837]
# 7
# SUCCESS WITH  synth_data_shard_num=15_Xy_N=6000_Epoch_N=30_Nt=30_p=32_part_num=1000_  GP_version_item =  1
# SUCCESS WITH  synth_data_shard_num=15_Xy_N=6000_Epoch_N=30_Nt=30_p=32_part_num=1000_  GP_version_item =  1
# 6
# self.true_lik= [0.828045448905645]
# self.esti_lik= [0.4791779608047668]
# 7
# 6
# self.true_lik= [0.827452185741487]
# self.esti_lik= [0.4679021979246208]
# 7
# ...

# %%
Xy_N_6000_hm_mean_plot_data_32_x_1000_x_30_x_15 = af.heat_map_data_prep_mean(
    pred_num=32, part_num=part_num, N_Epoch = N_Epoch, shard_num=15, big_results_dict=big_results_dict_6000
)
print(Xy_N_6000_hm_mean_plot_data_32_x_1000_x_30_x_15)

Xy_N_6000_hm_std_plot_data_32_x_1000_x_30_x_15 = af.heat_map_data_prep_std(
    pred_num=32, part_num=part_num, N_Epoch = N_Epoch, shard_num=15, big_results_dict=big_results_dict_6000
)
Xy_N_6000_hm_std_plot_data_32_x_1000_x_30_x_15
# Out:
#  in heat_map_data_prep_mean(pred_num, part_num, N_Epoch, shard_num, big_results_dict)
# cond_1= True
# cond_2= True
# cond_3= True
# cond_4= True
# big_results_dict[dict_keys[k]].last_avg_lik_diff = 0.003817612984788038
#         1000  index
# 30  0.003818     30
# in heat_map_data_prep_std
#         1000  index
# 30  0.010668     30
